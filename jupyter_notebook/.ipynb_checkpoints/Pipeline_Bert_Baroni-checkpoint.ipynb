# %%
import torch
from typing import List
from collections import Counter
import pickle5 as pickle 
from tqdm import trange

import numpy as np
import pandas as pd
from tqdm import tqdm
from sklearn.metrics import average_precision_score

from transformers import (DistilBertTokenizerFast, DistilBertModel)

# %% [markdown]
# ### CLASSES

# %%
class Vocab:

    def __init__(self):
        self._tok_counts = Counter()
        self._id_to_tok = {}

    def fit(self, data, word_list):
        for sequence in data:
            self._tok_counts.update([tok for tok in sequence if tok in word_list])

        self._toks = (["</s>", "<unk>"] +
                      [tok for tok, _ in self._tok_counts.most_common()])
        self._tok_to_id = {tok: i for i, tok in enumerate(self._toks)}

    def __len__(self):
        return len(self._toks)
    
class Tokenizer:

    def __init__(self):
        self._t = DistilBertTokenizerFast.from_pretrained("distilbert-base-uncased")
    def words(self, sequences: List[str]):
        return [s.split() for s in sequences]

    def __call__(self, sequences: List[str]):
        words = self.words(sequences)
        subw = self._t.batch_encode_plus(words,
                                         is_split_into_words=True,
                                         padding=True)
        return words, subw

class EmbedAverages(torch.nn.Module):
    def __init__(self, n_words, dim):
        super().__init__()
        # matrix of wordvector sums
        self.register_buffer("_sum", torch.zeros(n_words, dim))
        self.register_buffer("_counts", torch.zeros(n_words, dtype=torch.long))
        self.register_buffer("_cov", torch.zeros(n_words, dim, dim))
    
    def add(self, ix, vec):
        self._counts[ix] += 1
        self._sum[ix] += vec
        self._cov[ix] += vec.reshape([len(vec), 1]) @ vec.reshape([1, len(vec)])
    
    def get_mean_covariance(self, ix):
        mean = self._sum[ix] / self._counts[ix]
        d = len(mean)
        cov = self._cov[ix] / self._counts[ix] - mean.reshape([d, 1])  @ mean.reshape([1, d])
        cov = .001 * torch.eye(d) + cov
        return mean, cov

# %%
def calculate_kl(wordpair):
    # Get the mean vectors and covariance matrices for the two words in the word pair
    mean1, covariance_matrix1 = embavg.get_mean_covariance(vocab._tok_to_id.get(wordpair[0])) 
    mean2, covariance_matrix2 = embavg.get_mean_covariance(vocab._tok_to_id.get(wordpair[1])) 
    
    # Create PyTorch multivariate normal distributions using the mean vectors and covariance matrices
    p = torch.distributions.multivariate_normal.MultivariateNormal(mean1, covariance_matrix=covariance_matrix1)
    q = torch.distributions.multivariate_normal.MultivariateNormal(mean2, covariance_matrix=covariance_matrix2)

    # Calculate the KL divergence between the two distributions
    kl = torch.distributions.kl.kl_divergence(p, q)

    return kl.item()

# %%
def cosine_similarity(a, b):
    nominator = torch.dot(a, b)
    
    a_norm = torch.sqrt(torch.sum(a**2))
    b_norm = torch.sqrt(torch.sum(b**2))
    
    denominator = a_norm * b_norm
    
    cosine_similarity = nominator / denominator
    
    return cosine_similarity

# %%
file = "../data_shared/hyperlex-data/hyperlex-all.txt"

results = []
with open(file) as f:
    line = f.readline()
    while line:
        results.append(line.strip().split(" "))
        line = f.readline()
f.close()

HyperLex = pd.DataFrame(results)
HyperLex.columns = HyperLex.iloc[0]
HyperLex = HyperLex.iloc[1:].reset_index(drop=True)

HyperLex.head()
# Out:
# 0     WORD1         WORD2 POS     TYPE AVG_SCORE AVG_SCORE_0_10   STD  \
# 0  conflict  disagreement   N  r-hyp-1      5.20           8.67  1.25
# 1   advance          take   V   no-rel      1.42           2.37  1.66
# 2     trail        follow   V    hyp-2      4.31           7.18  1.86
# 3     mason        worker   N    hyp-3      4.50            7.5  1.76
# 4      aura         light   N    hyp-1      3.69           6.15  1.86
#
# 0 SCORES.. NaN NaN  ... NaN NaN NaN NaN NaN NaN   NaN   NaN   NaN   NaN
# 0        5   6   6  ...   6   5   2   6   4   6  None  None  None  None
# 1        3   0   3  ...   0   5   0   0   1   2     3     0  None  None
# 2        4   4   6  ...   6   6   6   3   0   4     3     6     6  None
# 3        6   6   4  ...   6   3   6   3   5   0     5     6  None  None
# 4        4   5   3  ...   6   0   3   6   3   0     4     5     5  None
#
# [5 rows x 21 columns]

# %%
results_neg_file, results_pos_file, baroni, baroni_set

HyperLex["WORD1"].values.tolist()
HyperLex["WORD2"].values.tolist()

HyperLex_set = set(HyperLex["WORD1"].values.tolist() + HyperLex["WORD2"].values.tolist())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-aa6d43f0cfa5> in <module>
# ----> 1 results_neg_file, results_pos_file, baroni, baroni_set
#       2
#       3 HyperLex["WORD1"].values.tolist()
#       4 HyperLex["WORD2"].values.tolist()
#       5
#
# NameError: name 'results_neg_file' is not defined

# %%
with open('../data_shared/hyperlex_output/curated/df_curated150_diag_False_new.pickle', 'rb') as f:
    df_curated10_diag_False = pickle.load(f)

df_curated10_diag_False
# Out:
# 0         WORD1         WORD2 POS     TYPE AVG_SCORE AVG_SCORE_0_10   STD  \
# 0      conflict  disagreement   N  r-hyp-1      5.20           8.67  1.25
# 1       advance          take   V   no-rel      1.42           2.37  1.66
# 2         trail        follow   V    hyp-2      4.31           7.18  1.86
# 3         mason        worker   N    hyp-3      4.50            7.5  1.76
# 4          aura         light   N    hyp-1      3.69           6.15  1.86
# ...         ...           ...  ..      ...       ...            ...   ...
# 2611  newspaper        medium   N    hyp-3      4.08            6.8  1.59
# 2612    concert         event   N    hyp-4      5.73           9.55  0.45
# 2613       food           pie   N  r-hyp-3      0.92           1.53  1.49
# 2614      ledge         shelf   N      syn      4.30           7.17  1.00
# 2615     avenue          road   N    hyp-3      4.83           8.05  1.99
#
# 0    SCORES.. NaN NaN  ... NaN NaN   NaN   NaN   NaN   NaN bert KL score  \
# 0           5   6   6  ...   4   6  None  None  None  None  12985.447266
# 1           3   0   3  ...   1   2     3     0  None  None   2353.950684
# 2           4   4   6  ...   0   4     3     6     6  None   9127.589844
# 3           6   6   4  ...   5   0     5     6  None  None  15273.080078
# 4           4   5   3  ...   3   0     4     5     5  None   2506.369385
# ...       ...  ..  ..  ...  ..  ..   ...   ...   ...   ...           ...
# 2611        3   3   4  ...   6   6     0     4     6  None  14804.804688
# 2612        6   6   5  ...   6   6     6  None  None  None   3286.998535
# 2613        0   1   0  ...   0   0     0     3     5  None  10345.702148
# 2614        5   4   6  ...   4   3  None  None  None  None  10489.830078
# 2615        6   5   6  ...   1   6     6     0  None  None   3176.965332
#
# 0     bert COS score empirical KL score empirical COS score
# 0     tensor(0.8226)          31.253380            0.608640
# 1     tensor(0.7400)          35.989449            0.569970
# 2     tensor(0.6607)         134.298996            0.287112
# 3     tensor(0.6449)         219.604095            0.479686
# 4     tensor(0.7034)         239.516418            0.476924
# ...              ...                ...                 ...
# 2611  tensor(0.6138)          49.050156            0.152536
# 2612  tensor(0.7296)          60.091927            0.606520
# 2613  tensor(0.7378)         163.204697            0.513506
# 2614  tensor(0.7211)         133.598404            0.416172
# 2615  tensor(0.7758)         103.549454            0.379787
#
# [2616 rows x 25 columns]

# %%
print(df_curated10_diag_False['bert COS score'].astype(float).corr(df_curated10_diag_False['AVG_SCORE_0_10'].astype(float), method="spearman"))

print(-df_curated10_diag_False['bert KL score'].astype(float).corr(df_curated10_diag_False['AVG_SCORE_0_10'].astype(float), method="spearman"))

print(df_curated10_diag_False['empirical COS score'].astype(float).corr(df_curated10_diag_False['AVG_SCORE_0_10'].astype(float), method="spearman"))

print(-df_curated10_diag_False['empirical KL score'].astype(float).corr(df_curated10_diag_False['AVG_SCORE_0_10'].astype(float), method="spearman"))
# Out:
# 0.17604051881199495
# 0.2654763364935746
# 0.17255994439299785
# -0.01949548905086448

# %%
with open('../data_shared/hyperlex_output/curated/df_curated10_diag_False_new.pickle', 'rb') as f:
    df_curated10_diag_False = pickle.load(f)

df_curated10_diag_False
# Out:
# 0         WORD1         WORD2 POS     TYPE AVG_SCORE AVG_SCORE_0_10   STD  \
# 0      conflict  disagreement   N  r-hyp-1      5.20           8.67  1.25
# 1       advance          take   V   no-rel      1.42           2.37  1.66
# 2         trail        follow   V    hyp-2      4.31           7.18  1.86
# 3         mason        worker   N    hyp-3      4.50            7.5  1.76
# 4          aura         light   N    hyp-1      3.69           6.15  1.86
# ...         ...           ...  ..      ...       ...            ...   ...
# 2611  newspaper        medium   N    hyp-3      4.08            6.8  1.59
# 2612    concert         event   N    hyp-4      5.73           9.55  0.45
# 2613       food           pie   N  r-hyp-3      0.92           1.53  1.49
# 2614      ledge         shelf   N      syn      4.30           7.17  1.00
# 2615     avenue          road   N    hyp-3      4.83           8.05  1.99
#
# 0    SCORES.. NaN NaN  ... NaN NaN   NaN   NaN   NaN   NaN bert KL score  \
# 0           5   6   6  ...   4   6  None  None  None  None  27791.152344
# 1           3   0   3  ...   1   2     3     0  None  None  26103.863281
# 2           4   4   6  ...   0   4     3     6     6  None  35560.683594
# 3           6   6   4  ...   5   0     5     6  None  None  41889.355469
# 4           4   5   3  ...   3   0     4     5     5  None  19859.097656
# ...       ...  ..  ..  ...  ..  ..   ...   ...   ...   ...           ...
# 2611        3   3   4  ...   6   6     0     4     6  None  39881.554688
# 2612        6   6   5  ...   6   6     6  None  None  None  25099.994141
# 2613        0   1   0  ...   0   0     0     3     5  None  30256.830078
# 2614        5   4   6  ...   4   3  None  None  None  None  23158.416016
# 2615        6   5   6  ...   1   6     6     0  None  None  20084.181641
#
# 0     bert COS score empirical KL score empirical COS score
# 0     tensor(0.8348)          46.789955            0.608640
# 1     tensor(0.7453)          46.788940            0.569970
# 2     tensor(0.6117)         181.149597            0.287112
# 3     tensor(0.5939)         321.340332            0.479686
# 4     tensor(0.6823)         261.286438            0.476924
# ...              ...                ...                 ...
# 2611  tensor(0.5786)          77.645660            0.152536
# 2612  tensor(0.7239)          71.526077            0.606520
# 2613  tensor(0.7417)         224.229675            0.513506
# 2614  tensor(0.7025)         202.426727            0.416172
# 2615  tensor(0.7565)         116.753113            0.379787
#
# [2616 rows x 25 columns]

# %%
print(df_curated10_diag_False['bert COS score'].astype(float).corr(df_curated10_diag_False['AVG_SCORE_0_10'].astype(float), method="spearman"))

print(-df_curated10_diag_False['bert KL score'].astype(float).corr(df_curated10_diag_False['AVG_SCORE_0_10'].astype(float), method="spearman"))

print(df_curated10_diag_False['empirical COS score'].astype(float).corr(df_curated10_diag_False['AVG_SCORE_0_10'].astype(float), method="spearman"))

print(-df_curated10_diag_False['empirical KL score'].astype(float).corr(df_curated10_diag_False['AVG_SCORE_0_10'].astype(float), method="spearman"))
# Out:
# 0.1690315193922307
# 0.22318115453266124
# 0.17255994439299785
# -0.00034625736133829836

# %%
with open('../data_shared/fixed/curated100.pickle', 'rb') as f:
    df_curated10_diag_False = pickle.load(f)

df_curated10_diag_False
# Out:
# ['civil marriage so far as its validity in law is concerned is a civil contract between two persons to which the consent of the parties capable in law of contracting is essential',
#  'on july the hoover school board voted to not renew bishop s contract after one year of service',
#  'turpan has the turpan water museum a protected area of the people s republic of china dedicated to demonstrating its karez water system as well as exhibiting other historical artifacts',
#  'scientific recognition robotic governance was first mentioned in the scientific community within a dissertation project at the technical university of munich supervised by professor dr',
#  'gilbert served as president of the armidale and district historical society and has been honored with freedom of the city of armidale',
#  'esau said that he had enough but jacob pressed him to accept his present saying that seeing esau s face was like seeing the face of god and esau took the gifts',
#  'michiko kakutani s review in the new york times was favorable calling the book dynamic and dubbing it franzen s most intimate novel yet',
#  'michiko kakutani s review in the new york times was favorable calling the book dynamic and dubbing it franzen s most intimate novel yet',
#  'big brother all stars james came into the season house with his former big brother housemates janelle howie and kaysar and reluctantly forms a season six alliance with them',
#  'the somerset patriots are a professional baseball team who plays at the seat td bank ballpark located on the border of bridgewater and bound brook',
#  'the somerset patriots are a professional baseball team who plays at the seat td bank ballpark located on the border of bridgewater and bound brook',
#  '– town of hull orders no more tours for summer in the tower',
#  'in a statue of giuseppe garibaldi was unveiled in lincoln park to a crowd of italian americans',
#  'category evidence category health informatics category health care quality category clinical research',
#  'category evidence category health informatics category health care quality category clinical research',
#  'i must say though that frankly it never occurred to me that keith s engine would be anything other than a tremendous success',
#  '– gram is usually sufficient to produce a mild effect –',
#  'in the final the united states was beaten by mexico – surrendering its match unbeaten streak against concacaf opponents on u',
#  'payment model like other online publications there are a variety of payment models used for webtoons',
#  'after finishing suidobata art academy and graduating from funabashi art school in subsequently yuki itoda started exhibiting his work in art galleries in tokyo and was represented by zenshi gallery',
#  'after finishing suidobata art academy and graduating from funabashi art school in subsequently yuki itoda started exhibiting his work in art galleries in tokyo and was represented by zenshi gallery',
#  'the embedded osteoid osteocyte must do two functions simultaneously regulate mineralization and form connective dendritic processes which requires cleavage of collagen and other matrix molecules',
#  'the cylinders were coated with wax which was then coated with black lead to make it electrically conductive and copper plated',
#  'afterwards he explained that he caught the virus whilst in the united states on stoke s pre season tour',
#  'afterwards he explained that he caught the virus whilst in the united states on stoke s pre season tour',
#  'president aquino iii led the first day of the meeting where he said that the asean will continue to fight against transnational crimes',
#  'president aquino iii led the first day of the meeting where he said that the asean will continue to fight against transnational crimes',
#  'on april ball left the club by mutual consent prior to the end of the season',
#  'on april ball left the club by mutual consent prior to the end of the season',
#  'the ornamental domes of box were planted in the',
#  'she was re elected to a second term in the general elections',
#  'playing career club a product of dundee united s scouting and coaching network in the west of scotland glasgow born mckinlay was signed from hamilton thistle in',
#  'peter and olivia shut down the dream equipment before nayak kills another victim but the doctor dies in the process',
#  'peter and olivia shut down the dream equipment before nayak kills another victim but the doctor dies in the process',
#  'the company has an asset base of inr crore and net worth of inr crore',
#  'rudolf s record is unique in that his personal best preceding his record setting competition was',
#  'rudolf s record is unique in that his personal best preceding his record setting competition was',
#  'among her best paintings were those she completed in skagen where she spent her summers with her husband every year from to often in the company of laurits tuxen and viggo johansen',
#  'among her best paintings were those she completed in skagen where she spent her summers with her husband every year from to often in the company of laurits tuxen and viggo johansen',
#  'dwight garner wrote that the narrators contradict one another as if they were talking heads in an early spike lee movie',
#  'the tempo of the acting often seems to be outrunning the movie itself',
#  'when winnie the pooh and his friends realize their oversight they prepare a huge celebration with chocolate cake and a birthday game',
#  'when winnie the pooh and his friends realize their oversight they prepare a huge celebration with chocolate cake and a birthday game',
#  'when winnie the pooh and his friends realize their oversight they prepare a huge celebration with chocolate cake and a birthday game',
#  'following each election they would gather at this square in order to find out what the election results were in case of victory of a party other than the one that hired them they would lament their impending unemployment',
#  'one of these three versions of the cadet even featured a wind shield',
#  'in ryki had a wooden church of st',
#  'the entire company of strider the stor',
#  'the float is lifted upward by inertia closing the fuel inlet valve as if the fuel bowl was full of fuel',
#  'the float is lifted upward by inertia closing the fuel inlet valve as if the fuel bowl was full of fuel',
#  'the float is lifted upward by inertia closing the fuel inlet valve as if the fuel bowl was full of fuel',
#  'the deportation policies of the tsarist era was continued in some areas bolstered by the participation of whole german speaking communities on the side of the white russians against the bolsheviks in the russian civil war',
#  'it is the warmest and almost the most arid area in the czech republic and therefore vines are cultivated here',
#  'crime and illicit activity many auto camps were used as havens and hide outs for criminals of the bonnie and clyde had a shootout in the infamous red crown tourist court near kansas city on july',
#  'in europe the berlin adler won the efaf cup a second tier competition against the parma panthers of italy the clubs first international title',
#  'transplantation as with almost all non weedy wild plants is a delicate process and in many cases results in the death of the plant',
#  'in comparison with the sound and lyrical content of sinclair s debut album perfectionist trouble has a heavier atmosphere driven by electric guitars and strong percussion',
#  'the magazine discovered through investigation that mclaren had installed a second brake pedal selectable by the driver to act on any one of the rear wheels at the driver s control',
#  'the magazine discovered through investigation that mclaren had installed a second brake pedal selectable by the driver to act on any one of the rear wheels at the driver s control',
#  'canberra heat volleyball club men is an australian national league volleyball club based in canberra australia',
#  'canberra heat volleyball club men is an australian national league volleyball club based in canberra australia',
#  'lyrical content lyrically the song outlines events in the lives of several children but someone playing an important role in their lives—possibly a parent or an ex lover—is not with them to witness their victories and tragedies living far away',
#  'lyrical content lyrically the song outlines events in the lives of several children but someone playing an important role in their lives—possibly a parent or an ex lover—is not with them to witness their victories and tragedies living far away',
#  'lyrical content lyrically the song outlines events in the lives of several children but someone playing an important role in their lives—possibly a parent or an ex lover—is not with them to witness their victories and tragedies living far away',
#  'the people of the region stopped paying taxes to the british and followed tipu shah s rulings',
#  'while most movie theaters at the time generated profit by selling concessions anthony cacchio jr',
#  'released as his first compact disc in it features in excess of minutes of palestine forcefully playing two notes in rapid alternation slowly expanding into clusters with the sustain pedal depressed throughout',
#  'karen walton vice president of academics at desales university was the host',
#  'the sunshine kitchens relocated to the newly purchased facility',
#  'in addition to being the final kwisatz haderach of the humans duncan becomes the new evermind of the thinking machines guiding their joint future',
#  'biography andrews an indian fighter joined the texian army at the beginning of the texas revolution',
#  'it was renamed kingsmead technology college when it became a specialist school in',
#  'he also has a passion for bit atari computers and is actively researching the history of the bit atari platform',
#  'he also has a passion for bit atari computers and is actively researching the history of the bit atari platform',
#  'he arranges a meeting at a remote automobile wrecking yard and insists that boyle come alone',
#  'he arranges a meeting at a remote automobile wrecking yard and insists that boyle come alone',
#  'the council chose the new district boundaries in june a controversial vote that drew accusations of gerrymandering to favor two of the incumbents',
#  'the council chose the new district boundaries in june a controversial vote that drew accusations of gerrymandering to favor two of the incumbents',
#  'after they have decided they sing another song doing the same movement and announce the person they want',
#  'the twentieth century saw significant population growth in the redlands preceded by the construction of the cleveland railway line',
#  'although evidence exists of a major settlement during antiquity at the village of paleopoli agios dimitrios was the only major exception to this lack of civilization',
#  'lead poisoning would be a significant factor standing against their survival',
#  'the asian hockey federation is the governing body for the sport of field hockey in asia',
#  'the asian hockey federation is the governing body for the sport of field hockey in asia',
#  'he is also the owner of the music label epitaph records and a number of sister labels',
#  'moreover the turkish community received the solidarity of bulgarian intellectuals and opponents of the regime',
#  'gallibacterium bacteria are pathogens for chicken',
#  'wr denotes world record',
#  'holsapple american professor of engine',
#  'million project in barangay pasa a joint undertaking between the south korean government through korea international cooperation agency koica and the philippines through the national irrigation administration and the local government of isabela',
#  'million project in barangay pasa a joint undertaking between the south korean government through korea international cooperation agency koica and the philippines through the national irrigation administration and the local government of isabela',
#  'he and erlich have frequent disagreements and after finding out how difficult it is for a landowner to evict a tenant jian yang decides to take advantage of this and live rent free in erlich s house for a year',
#  'the funding covered state and local government costs for debris removal and emergency services related to the hurricane',
#  'notable people with the surname include gerald oshita – american musician composer and sound recordist japanese baseball player and manager rod oshita born american handball player japanese water polo player category japanese language surnames',
#  'notable people with the surname include gerald oshita – american musician composer and sound recordist japanese baseball player and manager rod oshita born american handball player japanese water polo player category japanese language surnames',
#  'notable people with the surname include gerald oshita – american musician composer and sound recordist japanese baseball player and manager rod oshita born american handball player japanese water polo player category japanese language surnames',
#  'notable people with the surname include gerald oshita – american musician composer and sound recordist japanese baseball player and manager rod oshita born american handball player japanese water polo player category japanese language surnames',
#  'notable people with the surname include gerald oshita – american musician composer and sound recordist japanese baseball player and manager rod oshita born american handball player japanese water polo player category japanese language surnames',
#  'notable people with the surname include gerald oshita – american musician composer and sound recordist japanese baseball player and manager rod oshita born american handball player japanese water polo player category japanese language surnames',
#  'morse s opinion that his daughter had died from pancreatitis robinson had been consulting doctors on the matter who had advised him that this was an unlikely cause of death',
#  'he joined brother tim who was the top scorer in the – magners league',
#  'that idea does not however offer explanation for the moments when hamlet does act impulsively and violently',
#  'that idea does not however offer explanation for the moments when hamlet does act impulsively and violently',
#  'on january he scored his first professional goal at the age of',
#  'he is the toughest and physically strongest of the rangers though will show signs of higher intelligence occasionally',
#  'the balls are said to be reddish and to range in size from smaller sparkles up to the size of basketballs',
#  'the balls are said to be reddish and to range in size from smaller sparkles up to the size of basketballs',
#  'the balls are said to be reddish and to range in size from smaller sparkles up to the size of basketballs',
#  'the building was added to the national register of historic places on march',
#  'but louis mountbatten withdrew all his assurances regarding maintaining travancore s sovereignty and another round of discussion started between sree chithira thirunal and indian representative v',
#  'his preliminary discourse which advocated an inductive approach to scientific experiment and theory building was an important contribution to the philosophy of science',
#  'his preliminary discourse which advocated an inductive approach to scientific experiment and theory building was an important contribution to the philosophy of science',
#  'had a female householder with no husband present and',
#  'had a female householder with no husband present and',
#  'in response to an interviewer who asked schnitzler what he thought about the critical view that his works all seemed to treat the same subjects he replied i write of love and death',
#  'the nave was added in the second half of the century possibly in connection with an early tower',
#  'investments over the years jackson invested his earnings from music and celebrity endorsements in an array of privately controlled companies real estate and stocks and bonds',
#  'references further reading external links boca raton news archive category mass media in the miami metropolitan area category boca raton florida category defunct newspapers of florida category establishments in florida category disestablishments in florida category publications established in category publications disestablished in',
#  'louis rams coaches category san francisco coaches category smu mustangs football coaches category ucla bruins football coaches category sportspeople from altoona pennsylvania category players of american football from pennsylvania category burials at the united states naval academy cemetery',
#  'louis rams coaches category san francisco coaches category smu mustangs football coaches category ucla bruins football coaches category sportspeople from altoona pennsylvania category players of american football from pennsylvania category burials at the united states naval academy cemetery',
#  'louis rams coaches category san francisco coaches category smu mustangs football coaches category ucla bruins football coaches category sportspeople from altoona pennsylvania category players of american football from pennsylvania category burials at the united states naval academy cemetery',
#  'however the song was not released elsewhere until the following year',
#  'in april yatsenyuk was officially chosen as party leader of front for change by that time the public initiative had become a political party also',
#  'he was the player of argentana of – serie d located in argenta romagna region',
#  'band characteristics quirks they are known for utilizing an elaborate light show at all of their concerts',
#  'band characteristics quirks they are known for utilizing an elaborate light show at all of their concerts',
#  'in past years community halls functioned in broader educational and cultural roles than today often serving as literary institutes and schools of arts before the introduction of council administered libraries or when travel to the main centres was time consuming or difficult',
#  'in past years community halls functioned in broader educational and cultural roles than today often serving as literary institutes and schools of arts before the introduction of council administered libraries or when travel to the main centres was time consuming or difficult',
#  'there is a collective meal and from to people come up to participate in free activities related to ecology activism and self sufficiency',
#  'there is a collective meal and from to people come up to participate in free activities related to ecology activism and self sufficiency',
#  'a group is a number of people or things that are located gathered or classed together',
#  'last february he was a guest at the formal opening of the bangsamoro transition commission representing the department of national defense',
#  'in they returned to work with stephen stewart and geoffrey chung on the album committed',
#  'rusty is also portrayed as an adult with a wife and daughter in hotel hell vacation',
#  'rusty is also portrayed as an adult with a wife and daughter in hotel hell vacation',
#  'rusty is also portrayed as an adult with a wife and daughter in hotel hell vacation',
#  'biography as the son of long time sports sedan racer and kerrick sports sedan series winner des wall he started in sedan cars rather the conventional formula cars',
#  'biography as the son of long time sports sedan racer and kerrick sports sedan series winner des wall he started in sedan cars rather the conventional formula cars',
#  'biography as the son of long time sports sedan racer and kerrick sports sedan series winner des wall he started in sedan cars rather the conventional formula cars',
#  'army believes awesom o is a new secret weapon',
#  'army believes awesom o is a new secret weapon',
#  'according to family legend he was able to trace his ancestry to the important torah scholar of the middle ages moses maimonides through his father and to the writer sarah trimmer through his mother',
#  'according to family legend he was able to trace his ancestry to the important torah scholar of the middle ages moses maimonides through his father and to the writer sarah trimmer through his mother',
#  'according to family legend he was able to trace his ancestry to the important torah scholar of the middle ages moses maimonides through his father and to the writer sarah trimmer through his mother',
#  'he is also a board member for ingersoll rand and vulcan materials company',
#  'the memorial is constructed of portland stone with a bronze inlay depicting interpretive artwork of the damaged train and text detailing the incident',
#  'the memorial is constructed of portland stone with a bronze inlay depicting interpretive artwork of the damaged train and text detailing the incident',
#  'the memorial is constructed of portland stone with a bronze inlay depicting interpretive artwork of the damaged train and text detailing the incident',
#  'noel informs mabel that gerald has bet the other members of his club that she will stop answering letters',
#  'thenkurissi ii is a village in palakkad district in the state of kerala india',
#  'james paul gee former professor of education from – and chair of the department of developmental studies and counseling',
#  'archer spent almost a year in this prison and some weeks once eligible working in the local theatre',
#  'in the race was won by fabian ca',
#  'on january bristol city announced that orr had signed a two and a half year contract at the club',
#  'on january bristol city announced that orr had signed a two and a half year contract at the club',
#  'a british aircraft of the ma',
#  'the scalex range expanded to include six cars the mg tf austin healey aston martin jaguar',
#  'linalool refers to two enantiomers of a naturally occurring terpene alcohol found in many flowers and spice plants',
#  'jaitapur is on the arabian sea coast in ratnagiri district in the southwestern part of maharashtra india',
#  'he was a member of the māori battalion during world war ii in north africa and italy',
#  'and the average family size was',
#  's ploem presented a paper on the creation of computer graphics with mathematical morphology using for the first time the transforming algorithms from the fontainebleau group for the creation of digital art',
#  's ploem presented a paper on the creation of computer graphics with mathematical morphology using for the first time the transforming algorithms from the fontainebleau group for the creation of digital art',
#  'that evening he interrogated drobnjak for three hours in the presence of state prosecutor veselin vučković',
#  'testing sequences and procedures are defined by various international standards many of them set by astm',
#  'after that smith warned the government will be obliged to repurchase the very oil that it has practically given away',
#  'external links the alpha pi mu achs webpage alpha pi mu s national webpage category lists of chapters of united states student societies by society',
#  'there she meets the doctor and together they discover the secret mission the airship is on',
#  'anna s unique sense of humour and incredible capacity for painstaking detail makes her work inimitable',
#  'notable people john cook bennett',
#  'in the plan for the facility had grown to integrating a production area for cheese',
#  'in the plan for the facility had grown to integrating a production area for cheese',
#  'in the plan for the facility had grown to integrating a production area for cheese',
#  'in it is possible to climb to the tower and view the mechanism',
#  'the lake is stocked with game fish and officially opened for sport fishing in july',
#  'the lake is stocked with game fish and officially opened for sport fishing in july',
#  'the lake is stocked with game fish and officially opened for sport fishing in july',
#  'the lake is stocked with game fish and officially opened for sport fishing in july',
#  'it is an official journal of the international medical informatics association the european federation for medical informatics and the german association for medical informatics biometry and epidemiology',
#  'and the average family size was',
#  'captain atom s abilities are largely nuclear in nature and involve tapping into the strong nuclear force the energy that binds protons and neutrons in the nucleus',
#  'see also list of icelandic writers icelandic literature references bjarki karlsson bjarki karlsson bjarki karlsson bjarki karlsson category living people category births bjarki karlsson category neopagan poets',
#  'the village was isolated from sydney by swamps and sandhills and although a horse bus was operated by a man named grice from the late the journey was more a test of nerves than a pleasure jaunt',
#  'the village was isolated from sydney by swamps and sandhills and although a horse bus was operated by a man named grice from the late the journey was more a test of nerves than a pleasure jaunt',
#  'finally the storage of gags in the brain can lead to delayed development with subsequent intellectual disability and progressive loss of function',
#  'of the other ferry terminal buildings on the brisbane river most were built much later and none are as ornate as the brisbane and hawthorne ferry houses',
#  'of the other ferry terminal buildings on the brisbane river most were built much later and none are as ornate as the brisbane and hawthorne ferry houses',
#  'of the other ferry terminal buildings on the brisbane river most were built much later and none are as ornate as the brisbane and hawthorne ferry houses',
#  'santa maria formosa is a church in venice northern italy',
#  'these people were the opponents of the california oregon and washington volunteers and u',
#  'it was used as insert song in the tv drama ashita ga aru sa in which she also starred',
#  'washington has three discreet food pantries',
#  'following the tornado wright moved the restaurant to its current location at and locust street because r',
#  'references category births category living people category socialist left party norway politicians',
#  'in he took part in the reality tv show kings of comedy alongside stan boardman janey godley andrew maxwell boothby graffoe and david copperfield',
#  'they started digging through the records stored there and found an envelope of the girls’ travel visas a list of properties zack owned and his dummy corporations',
#  'they started digging through the records stored there and found an envelope of the girls’ travel visas a list of properties zack owned and his dummy corporations',
#  'manley throws the child into the fire which causes the fire to grow rapidly as demonic roars emanate',
#  'the canterbury mounted rifles now occupied the post and fought off several turkish attacks',
#  'infectious disease and epidemiology conducts disease surveillance responds to outbreaks and provides health education',
#  'state of nebraska a grade of magnet with a maximum energy product bhmax of megagauss oersteds',
#  'pontville homestead on the mullum mullum creek near the yarra river is a site of state historic significance for its associations with early european settlement and it is a known site of conflict between european and wurundjeri cultures',
#  'pontville homestead on the mullum mullum creek near the yarra river is a site of state historic significance for its associations with early european settlement and it is a known site of conflict between european and wurundjeri cultures',
#  'pontville homestead on the mullum mullum creek near the yarra river is a site of state historic significance for its associations with early european settlement and it is a known site of conflict between european and wurundjeri cultures',
#  'his recording is similar to the jobim recording in inflection rhythm and evocation of the song',
#  'robusta may refer to rhodospatha robusta a plant species endemic to ecuador rosenblattia robusta a deepwater cardinalfish species see also robusta disambiguation',
#  'apart from the official name the square was also regularly called the geuzenhofkes by local citizens referring to the many plants functioning as decoration on the square',
#  'apart from the official name the square was also regularly called the geuzenhofkes by local citizens referring to the many plants functioning as decoration on the square',
#  'category american male journalists category american male writers category chicago tribune people category writers from cincinnati category living people category century american biographers category journalists from ohio category year of birth missing living people',
#  'category american male journalists category american male writers category chicago tribune people category writers from cincinnati category living people category century american biographers category journalists from ohio category year of birth missing living people',
#  'category american male journalists category american male writers category chicago tribune people category writers from cincinnati category living people category century american biographers category journalists from ohio category year of birth missing living people',
#  'category american male journalists category american male writers category chicago tribune people category writers from cincinnati category living people category century american biographers category journalists from ohio category year of birth missing living people',
#  'the union formed the third largest city in virginia at the time with a area',
#  'architecture the architectural style of the mosque is influenced by design elements from the sultanate of deli kingdom from north sumatera indonesia',
#  'the whole leaf is downy pubescent and a somewhat brighter yellower green than many other tree leaves',
#  'the whole leaf is downy pubescent and a somewhat brighter yellower green than many other tree leaves',
#  'the whole leaf is downy pubescent and a somewhat brighter yellower green than many other tree leaves',
#  'this section to lowood a place that scarcely existed before the railway opened on june',
#  'kirsten ned s ex and the mother of his child mickey fletcher o leary witnesses this',
#  'kirsten ned s ex and the mother of his child mickey fletcher o leary witnesses this',
#  'he was the brother of carlos posadas who also excelled in the local industry',
#  'ian mcdonnell – for services to the community in the ards peninsula northern ireland',
#  'he came off the bench and had a rough start going – from the field in the first half',
#  'living at the edge of bangkok s chinatown wilson observed sino thai business families major market areas of the city the prostitution industry and the class gender sexual dimensions of professional identities in transnational corporations',
#  'living at the edge of bangkok s chinatown wilson observed sino thai business families major market areas of the city the prostitution industry and the class gender sexual dimensions of professional identities in transnational corporations',
#  'living at the edge of bangkok s chinatown wilson observed sino thai business families major market areas of the city the prostitution industry and the class gender sexual dimensions of professional identities in transnational corporations',
#  'at kolberg spotted the light cruiser and several destroyers from the harwich force',
#  'however some parts of the macropædia were written by the editorial staff of the britannica such editorial articles are identified by the initials ed',
#  'however some parts of the macropædia were written by the editorial staff of the britannica such editorial articles are identified by the initials ed',
#  'there was a drought and people resorted to cannibalism',
#  'lee hyun hangul 이현 born november is a south korean singer',
#  'in addition to hands on learning and community service work digital connectors are also given the opportunity to learn about career paths through sponsored visits to technology companies job shadowing programs and campus tours',
#  'according to the section of the german red cross dealing with tracing the captives the ultimate fate of german pows in allied custody is still unknown they are still officially listed as missing',
#  'playing amateur mcghee spent at least one season – playing alongside his brother bart on the front line of wolfenden shore of the allied american football association',
#  'playing amateur mcghee spent at least one season – playing alongside his brother bart on the front line of wolfenden shore of the allied american football association',
#  'his son colonel simon perkins while living in akron during the same time as abolitionist john brown went into business with brown',
#  'history the old red brick station building can still be seen near the bus stops where it has been converted to residential flats',
#  'history the old red brick station building can still be seen near the bus stops where it has been converted to residential flats',
#  'release and background promotion duffy performed the song on various tv shows and broadcast festivals in order to promote the release',
#  'his cousin bryan fairfax lord fairfax of cameron visited london in and claimed the title although he never actually used the title once it was granted to him',
#  'his cousin bryan fairfax lord fairfax of cameron visited london in and claimed the title although he never actually used the title once it was granted to him',
#  'the juniata heavy repair shop complex originally built by the prr is the primary repair and maintenance facility on ns',
#  'she eventually joined the second department of the chinese people s liberation army general staff headquarters responsible for collecting military intelligence',
#  'it was the breed s ability to hunt bears that earned the breed its name',
#  'it was the breed s ability to hunt bears that earned the breed its name',
#  'career she won gold at the world championships where she threw a russian and championship record of',
#  'ottó szigeti december – april was a hungarian amateur tennis player in the and',
#  'the last to use this title was henry ii',
#  'the initial perturbation or push back of the grounding line might be caused by high water temperatures at the base of ice shelves so that melt increases basal melt',
#  'the initial perturbation or push back of the grounding line might be caused by high water temperatures at the base of ice shelves so that melt increases basal melt',
#  'the athletic training floors include a swimming pool basketball courts boxing rings a fencing and wrestling room judo floor and squash courts',
#  'the athletic training floors include a swimming pool basketball courts boxing rings a fencing and wrestling room judo floor and squash courts',
#  'the athletic training floors include a swimming pool basketball courts boxing rings a fencing and wrestling room judo floor and squash courts',
#  'it debuted at number seven on the billboard music album charts shipping an estimated copies in its first week of release',
#  'he officially joined the company in december',
#  'history the name all boys reflected the youthfulness of its founders and followed the argentine tradition of naming football clubs in english such as newell s old boys boca juniors river plate and racing club had done before',
#  'history the name all boys reflected the youthfulness of its founders and followed the argentine tradition of naming football clubs in english such as newell s old boys boca juniors river plate and racing club had done before',
#  'one magazine in january one inc',
#  'this enabled them to make their first professional recordings in the studio of radio lodz',
#  'this enabled them to make their first professional recordings in the studio of radio lodz',
#  'inspired and sung by the composer s wife the ballad quickly became a hit song in vaudeville',
#  'dumped gregg for tayo a lesbian bass player',
#  'galls act as both the habitat and food source for the maker of the gall',
#  'galls act as both the habitat and food source for the maker of the gall',
#  'galls act as both the habitat and food source for the maker of the gall',
#  'the less torquey but more powerful marathon engine remained available as an option on all models',
#  'totally open and delivering instantly profound effect on stage he was one of the very few of whom it could be said that their performances were paid by their very heart s own blood according to the theatre historian inna solovyova',
#  'when it revealed its mouth to character jack sparrow it resembled a sarlacc the interior is lined with over six sets of spiked teeth and its breath emits a reeking odour of a thousand rotting corpses',
#  'the number of people involved will vary widely depending on the size of the institution',
#  'the number of people involved will vary widely depending on the size of the institution',
#  'the number of people involved will vary widely depending on the size of the institution',
#  'notable are also the large wooden organ late century the chapel of madonna della pace and early stories of the virgin in the left transept',
#  'myers high school shooting just eight days after columbine when a year old canadian student went into his school at lunchtime with a sawed off',
#  'myers high school shooting just eight days after columbine when a year old canadian student went into his school at lunchtime with a sawed off',
#  'historic district east of sorrento flo',
#  'million contribution to the foundation s campaign that established the cameco chair in aboriginal health at the university of saskatchewan',
#  'cadams is an unincorporated community in nuckolls county nebraska in the united states',
#  'however zagreb mayor većeslav holjevac was not interested until kelemen threatened to organize the festival in belgrade instead even then holjevac could provide funding in domestic currency only leaving the would be organizers unable to pay any compensation to foreign participants',
#  'it suffered significant damage in the february christchurch earthquake with the top floor collapsing one employee died several people were seriously injured and many staff were trapped in the rubble',
#  'it suffered significant damage in the february christchurch earthquake with the top floor collapsing one employee died several people were seriously injured and many staff were trapped in the rubble',
#  'it suffered significant damage in the february christchurch earthquake with the top floor collapsing one employee died several people were seriously injured and many staff were trapped in the rubble',
#  'the increase in quinolinic acid correlates with the early activation of microglia and increased cerebral hydroxykynurenine hk levels',
#  'when the area was evacuated in late tyler returned to west point as commander of fort tyler a small square earthwork with two field guns and a large pounder gun',
#  'when the area was evacuated in late tyler returned to west point as commander of fort tyler a small square earthwork with two field guns and a large pounder gun',
#  'meanwhile her father who sent a telegram to nancy to pick him up on a certain day at the station for their meeting disembarks to find nathan gombet waiting for him',
#  'in a california mining engineer james stetson had an idea to solve the water problem',
#  'in a california mining engineer james stetson had an idea to solve the water problem',
#  'kragmont is an unincorporated community in richmond county in the u',
#  'in jones voted to increase judicial pay and for lifetime concealed carry gun permits',
#  'operators have a suite of management and reporting tools to allow them to track customer behaviour and reward customers with game specific bonuses or promotions',
#  'the first full season of racing was held at prp in',
#  'the idea is comparable to other similar conceptions such as the greek megali idea greater hungary great yugoslavia as well as greater italy',
#  'this unpressurised variant was fitted with one caproni dorsal turret one breda in the ventral turret and two flank machine guns all of',
#  'in filipino americans made up one quarter of all foreign born residents of the area',
#  'the and brigades did not reactivate as part of an army wide elimination of brigade commands within its divisions',
#  'the battalion was mobilised at the drill hall in august before being deployed to the western front',
#  'it took over to complete building the football field and it took over to complete the basketball court',
#  'it took over to complete building the football field and it took over to complete the basketball court',
#  'it took over to complete building the football field and it took over to complete the basketball court',
#  'cook left his entire estate to the michigan law school',
#  'by a separate comedy accolade was established and the name changed to the current one',
#  'in ashraf succeeded his father khoshal khan in the chieftaincy of the khattak tribe',
#  'the u boat had a total length of a pressure hull length of a beam of a height of and a draught of',
#  'the organization s stated aim was to carve alabama georgia louisiana mississippi and south carolina out of the united states and establish an independent black nation from these five states',
#  'similarly functional magnetic resonance imaging fmri has been used to investigate the neurological mechanisms of pharmacological drug addiction the neurological mechanisms of mood and anxiety disorders in elderly populations and the neurological mechanisms of disorders such as schizophrenia',
#  'william carries on is the twenty fourth book in the just william series by richmal crompton',
#  'loxandra herself was a successful broodmare who also produced the prix jean de chaudenay winner loxias',
#  'in many of these larger reserves large animals ranging from several antelope species to elephant cape buffalo and hippopotamus can be found',
#  'the album moved up one position to number on the chart in its fifth week of release',
#  'the school is affiliated to the central board of secondary education new delhi',
#  'there are four ibm forms products ibm forms server serves e forms to web browsers and provides an api and platform to integrate e forms with other business processes',
#  'there are four ibm forms products ibm forms server serves e forms to web browsers and provides an api and platform to integrate e forms with other business processes',
#  'starting with matchday ajax won every single match until the end of the season',
#  'kireet joshi education advisor to the chief minister of gujarat shri girish patel post graduate from harvard law school senior counsel at the high court of gujarat and a social activist',
#  'snack bars a or snack for short refers to a kind of hostess bar an alcohol serving bar that employs female staff who are paid to serve and flirt with male customers',
#  'snack bars a or snack for short refers to a kind of hostess bar an alcohol serving bar that employs female staff who are paid to serve and flirt with male customers',
#  'snack bars a or snack for short refers to a kind of hostess bar an alcohol serving bar that employs female staff who are paid to serve and flirt with male customers',
#  'it also has enormous pitch dimensions of m x m as requested by warrington s head coach of the time paul cullen due to his desire to play expansive rugby',
#  'it also has enormous pitch dimensions of m x m as requested by warrington s head coach of the time paul cullen due to his desire to play expansive rugby',
#  'it also has enormous pitch dimensions of m x m as requested by warrington s head coach of the time paul cullen due to his desire to play expansive rugby',
#  'kalache has researched written and spoken in the field of ageing issues as an academic an international civil servant and an advocate',
#  'kalache has researched written and spoken in the field of ageing issues as an academic an international civil servant and an advocate',
#  'he married secondly by june mary the daughter of sir john sydenham of brinton somerset and the widow of john fitz of fitzford devon',
#  'the kyle and its surrounding area forms part of the oldshoremore cape wrath and durness special landscape area',
#  'there is a letter written by juan de mata terreforte which gives credit to marin',
#  'instead chaney returns don to his talking horse family in the countryside and claims his place as partner at the firm',
#  'instead chaney returns don to his talking horse family in the countryside and claims his place as partner at the firm',
#  'annie s boyfriend vaughn eric christian olsen tells her he s been recruited for a hacky sack team in delaware',
#  'at hours and minutes the final table of the horse event was the second longest final table in wsop history',
#  'at hours and minutes the final table of the horse event was the second longest final table in wsop history',
#  'its sole kiva stands alone with no residential or support structures whatsoever it did once have a passageway leading from the underground kiva to several above ground levels',
#  'the lower right figure which is recognized as the holy spirit by the dove over its head has its hands crossed a gesture associated with the annunciation the revelation that mary will give birth to christ',
#  'the lower right figure which is recognized as the holy spirit by the dove over its head has its hands crossed a gesture associated with the annunciation the revelation that mary will give birth to christ',
#  'the highway was originally part of ssh from to and sr after the highway renumbering and was created in after sr was realigned onto a new divided highway',
#  'the highway was originally part of ssh from to and sr after the highway renumbering and was created in after sr was realigned onto a new divided highway',
#  'the highway was originally part of ssh from to and sr after the highway renumbering and was created in after sr was realigned onto a new divided highway',
#  'com category maxwell musician concert tours category concert tours',
#  'com category maxwell musician concert tours category concert tours',
#  'often pv would lead b bomber formations since they were equipped with radar',
#  'often pv would lead b bomber formations since they were equipped with radar',
#  'he broke giacomo agostini s record for victories in one season with wins',
#  'she finished fifth in the individual championship test grade ii and in the dressage individual team test grade ii and member of the australian team that finished ninth in the team competition',
#  'these so called ambonese or belanda hitam english black dutch as they were called by other indonesians consequently retaliated against any provocation or attack by pemuda',
#  'it completed a million renovation and addition in the summer of adding a new classroom wing and a performing arts building',
#  'it completed a million renovation and addition in the summer of adding a new classroom wing and a performing arts building',
#  'michalski officially ended his sporting career in to concentrate on his work as a doctor',
#  'michalski officially ended his sporting career in to concentrate on his work as a doctor',
#  'agroiconota is a genus of tortoise beetles in the family chrysomelidae',
#  'the acronym zisc alludes to reduced instruction set computer risc',
#  'the acronym zisc alludes to reduced instruction set computer risc',
#  'corpses were then either dumped at the nearest cemetery or left to be collected by municipal services later though in the largest case of paracuellos de jarama they were buried in shallow common graves',
#  'career born in scottsdale arizona tanner s interest in acting began at the age of three after a visit to the local community theater to see peter pan',
#  'career born in scottsdale arizona tanner s interest in acting began at the age of three after a visit to the local community theater to see peter pan',
#  'there is also a hair salon coffee shop as well as a gym and physiotherapy specialist',
#  'there is also a hair salon coffee shop as well as a gym and physiotherapy specialist',
#  'there is also a hair salon coffee shop as well as a gym and physiotherapy specialist',
#  'there is also a hair salon coffee shop as well as a gym and physiotherapy specialist',
# ...
#  'the banner then references bingham s ideas of slavery by using the connection of the temperance movement and the anti slavery movement to show that bingham thought negatively about slavery and shared that view with intemperance',
#  'after serving in the canadian parliament helme did not seek another federal term in the election',
#  'after serving in the canadian parliament helme did not seek another federal term in the election',
#  'his father was a physician ob gyn and his mother was a dietician',
#  'his father was a physician ob gyn and his mother was a dietician',
#  'his father was a physician ob gyn and his mother was a dietician',
#  'anticipating a naval attack following s',
#  'the water between two steep hills remains so cold that even during summer it has been known to have caused heart attacks',
#  'devika too regrets about her love life and advises gg to forget the past',
#  'in the school underwent additional construction to alleviate crowded hallways and rebuild deteriorating parts of the building',
#  'in the school underwent additional construction to alleviate crowded hallways and rebuild deteriorating parts of the building',
#  'all these private radio stations air exclusively tamil based programs including film music',
#  'history an electorate based on the nelson has been contested at every election since the first parliament in',
#  'schenck sent out a company to probe the confederate positions after dark but after a brief skirmish the company withdrew and no other engagements took place',
#  'schenck sent out a company to probe the confederate positions after dark but after a brief skirmish the company withdrew and no other engagements took place',
#  'other specialties within medicine are closely affiliated to anesthesiology',
#  'in this power plant was replaced with a larger one as power demands increased',
#  'about of a mile long it links the spa town of matlock bath with the heights of abraham a tourist attraction above',
#  'he was appointed a member of the order of the british empire mbe military at the end of',
#  'the club won its first national title in and club members have competed internationally',
#  'the club won its first national title in and club members have competed internationally',
#  'the club won its first national title in and club members have competed internationally',
#  'current squad as of april out on loan external links official website category football clubs in the netherlands category association football clubs established in sv spakenburg sv spakenburg',
#  'in she and her husband moved to hollywood returning briefly to australia in and then permanently in',
#  'in the first woman to swim the english channel year old gertrude ederle made landfall at kingsdown after a mile crossing the direct distance is miles in record time',
#  'in the first woman to swim the english channel year old gertrude ederle made landfall at kingsdown after a mile crossing the direct distance is miles in record time',
#  'the isaurian survivors took refuge in the mountain strongholds of their country and kept waging war',
#  'capacity the clyde iron works model de crane can lift using the main hoist on a boom at any point in the crane s revolution capacity rises to when using the main hoist oriented astern',
#  'the resulting rough and slimes were separated out on large wooden frames buddling and framing respectively to extract the tin ore from the surrounding dust and grit',
#  'ahmed saifi is a pakistani cricketer',
#  'the gianchetti of a red colour ruscetti rossetti are tougher and scaly to the palate they are largely used to flavour fish based sauces',
#  'get drunk and be somebody is a song co written and recorded by american country music artist toby keith',
#  'get drunk and be somebody is a song co written and recorded by american country music artist toby keith',
#  'get drunk and be somebody is a song co written and recorded by american country music artist toby keith',
#  'get drunk and be somebody is a song co written and recorded by american country music artist toby keith',
#  'the foundress female then lays her eggs and feeds on the phyllodes until her brood hatches and ecloses',
#  'major highway work for the t rex project ended on august',
#  'major highway work for the t rex project ended on august',
#  'the piece is called last supper and the man who s dying has requested a meal of all of his favorite foods after which he s going to kill himself',
#  'the piece is called last supper and the man who s dying has requested a meal of all of his favorite foods after which he s going to kill himself',
#  'the piece is called last supper and the man who s dying has requested a meal of all of his favorite foods after which he s going to kill himself',
#  'the performer state is the interpretation motivation and stage presence of the performer',
#  'the performer state is the interpretation motivation and stage presence of the performer',
#  'jin then releases emily to attack ryder forcing him to kill her and jin in retaliation',
#  'milngavie is a town in east dunbartonshire scotland and a suburb of glasgow',
#  'references category births category deaths category players of american football from california category american football tackles category sportspeople from san francisco category american football fullbacks category all southern college football players category georgia tech yellow jackets football players category georgia tech yellow jackets baseball players category engineers from california',
#  'references category births category deaths category players of american football from california category american football tackles category sportspeople from san francisco category american football fullbacks category all southern college football players category georgia tech yellow jackets football players category georgia tech yellow jackets baseball players category engineers from california',
#  'references category births category deaths category players of american football from california category american football tackles category sportspeople from san francisco category american football fullbacks category all southern college football players category georgia tech yellow jackets football players category georgia tech yellow jackets baseball players category engineers from california',
#  'references category births category deaths category players of american football from california category american football tackles category sportspeople from san francisco category american football fullbacks category all southern college football players category georgia tech yellow jackets football players category georgia tech yellow jackets baseball players category engineers from california',
#  'references category births category deaths category players of american football from california category american football tackles category sportspeople from san francisco category american football fullbacks category all southern college football players category georgia tech yellow jackets football players category georgia tech yellow jackets baseball players category engineers from california',
#  'there were housing units at an average density of',
#  'vance brown who had sold the stone house lot to fuchs in may have been among those suspected by the paper as exerting their influence',
#  'in pal territories the word zero in ace combat zero the belkan war was removed making it the first game since the series introduction to not have a significant name change in pal territories',
#  'in pal territories the word zero in ace combat zero the belkan war was removed making it the first game since the series introduction to not have a significant name change in pal territories',
#  'in pal territories the word zero in ace combat zero the belkan war was removed making it the first game since the series introduction to not have a significant name change in pal territories',
#  'in pal territories the word zero in ace combat zero the belkan war was removed making it the first game since the series introduction to not have a significant name change in pal territories',
#  'the car s nose compartment was nearly filled by a fuel tank',
#  'the car s nose compartment was nearly filled by a fuel tank',
#  'he served on the county council and was a captain in the local militia',
#  'he served on the county council and was a captain in the local militia',
#  'magazine for two years',
#  'here he finds karl schäfer an ss officer who had led an ahnenerbe expedition to shambhala though he had killed them all to stop the nazis from obtaining the power in the city',
#  'rodolfo castera served as host of shows and events',
#  'boniface gambila adagbila born june is a ghanaian politician and member of the sixth parliament of the fourth republic of ghana representing the nabdam constituency in the upper east region on the ticket of the new patriotic party',
#  'boniface gambila adagbila born june is a ghanaian politician and member of the sixth parliament of the fourth republic of ghana representing the nabdam constituency in the upper east region on the ticket of the new patriotic party',
#  'boniface gambila adagbila born june is a ghanaian politician and member of the sixth parliament of the fourth republic of ghana representing the nabdam constituency in the upper east region on the ticket of the new patriotic party',
#  'mizutani s s voice actor is kenichirō sumi while jean luc hester provides his voice in english',
#  'mizutani s s voice actor is kenichirō sumi while jean luc hester provides his voice in english',
#  'he capped his debut against uganda being fielded from the start and playing the entire match',
#  'in holz received a recognition in honor of her career as an internet pioneer in uruguay in the framework of the ceibal project s tenth anniversary celebration',
#  'children get angry when they are forced to take a bath or clean their room',
#  'first the most fundamental measure is to create more good jobs for high wage which young people prefer',
#  'vikas tokas born october is an indian cricketer who plays for delhi cricket team in domestic cricket',
#  'vikas tokas born october is an indian cricketer who plays for delhi cricket team in domestic cricket',
#  'vikas tokas born october is an indian cricketer who plays for delhi cricket team in domestic cricket',
#  'an gold rush brought miners through the area',
#  'the attacker was shot in the chest by a victoria police officer and died in hospital',
#  'the attacker was shot in the chest by a victoria police officer and died in hospital',
#  'he also served as a member of the sree moolam popular assembly of travancore',
#  'the platform has stairs leading down to what is now the henry hudson parkway which was once riverside drive',
#  'ibrahim metwaly hegazy is an egyptian lawyer and human rights activist and a member of the egyptian commission for rights and freedoms',
#  'ibrahim metwaly hegazy is an egyptian lawyer and human rights activist and a member of the egyptian commission for rights and freedoms',
#  'the martin of the title refers to mascis s martin guitar',
#  'as the ming dynasty progressed living and working conditions for palace women began to deteriorate',
#  'the link pivots on either a bushing or a ball joint at each attachment point',
#  'the link pivots on either a bushing or a ball joint at each attachment point',
#  'he began his entertainment career as a stage actor but in moved into the film industry and worked for several years as a film salesman',
#  'he began his entertainment career as a stage actor but in moved into the film industry and worked for several years as a film salesman',
#  'by running out of process they do not run the same risk to the database or the engine as they run in their own process space with their own resources',
#  'strong waves generated by the storm caused tides above average slightly damaging coastal resorts',
#  'it then became a hurricane',
#  'intervention methods the bank has set six levels of promotional incentives for energy efficiency refurbishment activities expressed as efficiency house standards and monument”',
#  'intervention methods the bank has set six levels of promotional incentives for energy efficiency refurbishment activities expressed as efficiency house standards and monument”',
#  'the parish council meets once per month',
#  'the kiosks and stalls are set up while many sellers sit wherever they like spreading their earthenwares handicrafts toys etc',
#  'on december the rams defeated the tennessee titans – to clinch their first nfc west title since and their first in los angeles since they finished the regular season with an – record',
#  'on december the rams defeated the tennessee titans – to clinch their first nfc west title since and their first in los angeles since they finished the regular season with an – record',
#  'her father keeps interrupting her and tells her how much he loves who she is and how he knows vince will be a great husband',
#  'her father keeps interrupting her and tells her how much he loves who she is and how he knows vince will be a great husband',
#  'in the company was purchased by french holding company infogrames for £ million and was later merged into atari in',
#  'in the company was purchased by french holding company infogrames for £ million and was later merged into atari in',
#  'suppressor mutations also occur in genes that code for virus structural proteins',
#  'the work was commissioned by the new york philharmonic for its principal trombonist joseph alessi',
#  'stenson s theatre work has included london west end theatre appearances as princess fiona in shrek the musical elle woods in legally blonde the musical and as the lady of the lake in spamalot',
#  'stenson s theatre work has included london west end theatre appearances as princess fiona in shrek the musical elle woods in legally blonde the musical and as the lady of the lake in spamalot',
#  'stenson s theatre work has included london west end theatre appearances as princess fiona in shrek the musical elle woods in legally blonde the musical and as the lady of the lake in spamalot',
#  'in tribute to abdelaziz salem the first trophy from to of the african cup of nations football is called trophy abdelaziz abdallah salem',
#  'the following list is ordered by number',
#  'we have abused notation slightly strictly speaking j e∗ → h∗ but since h is a hilbert space it is isometrically isomorphic to its dual space h∗ by the riesz representation theorem',
#  'brian regal in pseudoscience a critical encyclopedia has written a case can be made for the idea that many evps are artifacts of the recording process itself with which the operators are unfamiliar',
#  'biography early career born in in tokyo itō became well known in the for a series of dramatic collections of poetry that described sexuality pregnancy and feminine erotic desire in dramatically direct language',
#  'it also occurs and is protected in los katíos national park bordering darién in panama paramillo national park sanquianga national park and in southwest of the country in farallones de cali national park',
#  'the open hematology journal is an open access peer reviewed medical journal covering ecology',
#  'she pursued further studies during summers at other universities and during travel abroad',
#  'mr innes s name is still revered in bernera today',
#  'he was made london correspondent of the leeds mercury in becoming its editor three years later',
#  'the dog is not required to retrieve the toy for the jump to count',
#  'by january the iranians launched a new attack from the west of the jasim river breaking through the fourth line',
#  'see also bore evacuator bore snake c',
#  'is a work for orchestra by french composer darius milhaud',
#  'his last playing stint in malaysia with t team will also be beneficial towards his understanding of the local game',
#  'his last playing stint in malaysia with t team will also be beneficial towards his understanding of the local game',
#  'heinlein s editor for many of his books from red planet to have space suit—will travel',
#  ...]

# %%
import ast
import nltk
import random
with open('../Data_shared/wiki_subset.txt') as f:
    data = f.read()
baroni_set = {'fallacy', 'subcontractor', 'declaration', 'colt', 'cabbage' ,'people'}
wikidata = ast.literal_eval(data)
wikidata = wikidata["text"]   
max_length = 100
max_context = 2

wikidata = [sentence[:max_length].strip() if len(sentence.split()) > max_length else sentence.strip()
            for seq in wikidata
            for sentence in seq.split(".")]



collected_sentences = []
sentence_counter = {word: int(0) for word in baroni_set}
# Shuffle the order of the sentences in wikidata
random.shuffle(wikidata)
# Iterate through the shuffled list of sentences
for sentence in tqdm(wikidata):
    words = sentence.split()
    for word in words:
        if word in baroni_set and sentence_counter[word] < int(max_context):

                collected_sentences.append(text_preprocessing(sentence))
                sentence_counter[word] += 1
                break
# Out:
#   0%|          | 0/250065 [00:00<?, ?it/s]
#   5%|▍         | 11840/250065 [00:00<00:02, 118287.59it/s]
#   9%|▉         | 23669/250065 [00:00<00:02, 106261.70it/s]
#  16%|█▌        | 40229/250065 [00:00<00:01, 131776.71it/s]
#  23%|██▎       | 56738/250065 [00:00<00:01, 144452.13it/s]
#  30%|███       | 75316/250065 [00:00<00:01, 159006.01it/s]
#  37%|███▋      | 91406/250065 [00:00<00:00, 159636.32it/s]
#  44%|████▎     | 109080/250065 [00:00<00:00, 165165.77it/s]
#  51%|█████     | 127030/250065 [00:00<00:00, 169691.75it/s]
#  58%|█████▊    | 144051/250065 [00:00<00:00, 168252.60it/s]
#  65%|██████▍   | 161322/250065 [00:01<00:00, 169611.31it/s]
#  71%|███████▏  | 178311/250065 [00:01<00:00, 169232.65it/s]
#  78%|███████▊  | 195254/250065 [00:01<00:00, 167459.95it/s]
#  85%|████████▌ | 212773/250065 [00:01<00:00, 169768.39it/s]
#  92%|█████████▏| 231059/250065 [00:01<00:00, 173684.98it/s]
# 100%|██████████| 250065/250065 [00:01<00:00, 162146.64it/s]

# %%
collected_sentences
# Out:
# ['see also world organization of the scout movement references external links missoni website world organisation of the scout movement official biography comments about the end of his wosm mandate category world scout committee members category births category living people category people from rome category bocconi university alumni',
#  'sloane nominee references external links category births category living people category american theatre directors category american male stage actors category american people of german-jewish descent',
#  'form this is a statutory declaration of compliance with all the legal requirements relating to the incorporation of a company',
#  'resolutions were passed including a signed declaration by the pakistani and indian delegates supporting a negotiated settlement to any differences and the resolution of the kashmir question by the people of the kashmir',
#  'in fact much of the work on the p- was farmed out to goodyear which had been a subcontractor for production of black widow components',
#  'this fallacy stemmed from the apocryphal origin story of a folk song known as son de má teodora',
#  'a pooh-pooh also styled as poo-poo is a fallacy in informal logic that consists of dismissing an argument as being unworthy of serious consideration',
#  'cosden he was sired by negofol a french colt owned by american william k',
#  'it may then be hard to work with that subcontractor to complete the work',
#  'they also added their kitten s joy son real solution to their stallion roster in after that colt won races that included the premio botticelli in italy the arlington million and the manhattan stakes in the us and retired with winnings over',
#  'trancam is a typical dish of central java which is similar to urap consisting of bean sprouts long beans lemon basil leaves and finely sliced napa cabbage',
#  'the restaurant in the hotel was well known described by one new york paper in as celebrated for its toothsome terrapin its canvasback ducks its turtle soup its oyster and tripe stews no less than for its more plebeian corned beef and cabbage']

# %%
# Out:
# {'instrument', 'glacier', 'dress', 'pepper', 'shoe', 'achievement', 'time', 'statue', 'boil', 'puberty', 'blaze', 'grasp', 'movement', 'rap', 'state', 'friend', 'shatter', 'difficulty', 'nose', 'construction', 'gem', 'lodge', 'society', 'reflection', 'ear', 'sheep', 'fruit', 'hammock', 'existence', 'slay', 'ozone', 'scribble', 'art', 'argument', 'fail', 'bury', 'bandage', 'mascara', 'leopard', 'rooster', 'hell', 'wisdom', 'plant', 'rib', 'villain', 'complain', 'shame', 'inform', 'evict', 'colt', 'spirit', 'superstition', 'formula', 'leak', 'intellect', 'noon', 'sunrise', 'custom', 'duck', 'eagle', 'geometry', 'reptile', 'mosquito', 'turnip', 'force', 'lesson', 'hour', 'shell', 'boat', 'racquetball', 'sleeve', 'blast', 'decline', 'tragedy', 'pitcher', 'poison', 'hate', 'trip', 'kidnap', 'sum', 'connect', 'tissue', 'paradise', 'deteriorate', 'recruit', 'knit', 'ask', 'bother', 'balcony', 'oregano', 'call', 'designer', 'kidney', 'theme', 'plaything', 'pail', 'rinse', 'depart', 'haystack', 'increase', 'tug', 'hog', 'bend', 'airplane', 'elm', 'ceremony', 'worth', 'sunset', 'gravel', 'parade', 'bath', 'activity', 'cougar', 'chance', 'candy', 'nap', 'calculator', 'shine', 'examine', 'ponder', 'pedal', 'weakness', 'bronze', 'gas', 'shadow', 'doughnut', 'grocery', 'harm', 'picture', 'conversation', 'organization', 'horse', 'illness', 'calf', 'line', 'leave', 'rat', 'insult', 'hamburger', 'iron', 'aspirin', 'yellow', 'cookie', 'nag', 'forehead', 'brand', 'exercise', 'tax', 'organ', 'surgery', 'song', 'comfort', 'dungeon', 'triangle', 'star', 'chamber', 'salary', 'comment', 'stand', 'acid', 'cod', 'corn', 'mussel', 'quill', 'headache', 'count', 'warehouse', 'solution', 'construct', 'dunk', 'daughter', 'bourbon', 'blackberry', 'amateur', 'wood', 'south', 'almanac', 'sit', 'conclusion', 'cop', 'alley', 'number', 'shield', 'grass', 'cone', 'marrow', 'harp', 'obstacle', 'gain', 'fate', 'body', 'zero', 'blade', 'hole', 'crook', 'rocket', 'accelerate', 'silver', 'laugh', 'amount', 'magnify', 'bridge', 'stretch', 'throw', 'discover', 'teach', 'pencil', 'hint', 'territory', 'foe', 'cupboard', 'freedom', 'bathroom', 'appeal', 'rodent', 'knitting', 'sidewalk', 'instance', 'math', 'medium', 'squash', 'motorcycle', 'analysis', 'dawn', 'crave', 'pub', 'heart', 'describe', 'movie', 'reappear', 'boot', 'refuse', 'mower', 'cap', 'stay', 'aim', 'authority', 'rectangle', 'suggestion', 'purple', 'pancake', 'point', 'appliance', 'inability', 'path', 'oasis', 'pollution', 'company', 'court', 'screw', 'pronoun', 'width', 'idea', 'chair', 'inch', 'breakfast', 'mission', 'obligation', 'frog', 'joke', 'cuff', 'defense', 'language', 'domain', 'worker', 'galosh', 'steel', 'coffee', 'humiliate', 'pound', 'harbor', 'pike', 'department', 'autumn', 'war', 'committee', 'burst', 'paddy', 'tote', 'diminish', 'cover', 'theory', 'outside', 'director', 'cleaner', 'witch', 'lion', 'package', 'husband', 'cigar', 'pause', 'cent', 'jug', 'chorus', 'shrimp', 'mansion', 'barrel', 'acknowledge', 'cobra', 'kettle', 'pain', 'pane', 'mushroom', 'garlic', 'rose', 'government', 'confusion', 'honesty', 'yell', 'washer', 'beam', 'meat', 'puddle', 'sofa', 'pill', 'differ', 'vessel', 'palace', 'error', 'billboard', 'symphony', 'hesitate', 'mail', 'yarn', 'part', 'destiny', 'task', 'sickness', 'shiver', 'cue', 'jaw', 'drawing', 'fit', 'soil', 'technology', 'tub', 'mug', 'remark', 'hurricane', 'plum', 'grime', 'leather', 'gene', 'rim', 'inside', 'shake', 'floor', 'crane', 'brook', 'pupil', 'asia', 'vanish', 'string', 'marsh', 'bond', 'flea', 'bucket', 'ascent', 'boundary', 'meaning', 'penguin', 'remedy', 'rung', 'officer', 'bicycle', 'spy', 'hypothesis', 'act', 'doorway', 'sausage', 'lace', 'separate', 'swear', 'persuade', 'pantyhose', 'antidote', 'refrigerator', 'bush', 'stage', 'repress', 'scalpel', 'wallet', 'starboard', 'ritual', 'elimination', 'sister', 'bit', 'stalk', 'popcorn', 'abdomen', 'wrestling', 'sport', 'shift', 'assault', 'presence', 'maroon', 'trumpet', 'judge', 'rice', 'frat ...

# %%
# Iterate through the shuffled list of sentences
max_context = 0
counter = 0 
for sentence in wikidata:

    words = sentence.split()
    for word in words:
        if word in baroni_set and sentence_counter[word] < int(max_context):

                collected_sentences.append(text_preprocessing(sentence))
                sentence_counter[word] += 1
                break

    if all(val == max_context for val in sentence_counter.values()):
        print("All keys have reached their max context.")
        with open(f'../data_shared/curated1-10/curated{max_context}num{counter}.pickle', 'wb') as handle:
            pickle.dump(collected_sentences, handle, protocol=pickle.HIGHEST_PROTOCOL)

        counter += 1

    if counter == 5:
        counter = 0
        max_context += 5
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-396-fc40f8766059> in <module>
#       6     words = sentence.split()
#       7     for word in words:
# ----> 8         if word in baroni_set and sentence_counter[word] < int(max_context):
#       9
#      10                 collected_sentences.append(text_preprocessing(sentence))
#
# KeyError: 'declaration'

# %%
# collected_sentences

# %%
def import_baroni(neg_file, pos_file):
    filenames = ["neg_file", "pos_file"]

    for i, file in enumerate([neg_file, pos_file]):
        globals()['results_{}'.format(filenames[i])] = []
        
        with open(file) as f:
            line = f.readline()
            while line:
                globals()['results_{}'.format(filenames[i])].append(line.replace("-n", "").replace("\n", "").strip("").split("\t"))
                line = f.readline()
        f.close()

    baroni = sum(results_neg_file, []) + sum(results_pos_file, [])
    baroni_set = set(baroni)

    return results_neg_file, results_pos_file, baroni, baroni_set

# %%
with open(f'../data_shared/difflayer/df_AP10_layer-1.pickle', "rb") as f:
    # Read the contents of the file
    df1 = pickle.load(f)

# %%
# df_AP10_layer-1.pickle
# df_AP10_layer-2.pickle
# df_AP10_layer-3.pickle
# df_AP10_layer123.pickle

import pickle5 as pickle
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt

# Initialize an empty dataframe to store the merged data
df = pd.DataFrame()

# Open the file in read mode
for j in range(1, 4):
    with open(f'../data_shared/difflayer/df_AP10_layer-{j}.pickle', "rb") as f:
        # Read the contents of the file
        df1 = pickle.load(f)
        df1["layer"] = -j
    df = pd.concat([df, df1])
    
# prints the contents of the file

with open(f'../data_shared/difflayer/df_AP10_layer123.pickle', "rb") as f:
    # Read the contents of the file
    df1 = pickle.load(f)
    df1["layer"] = "-123"
df = pd.concat([df, df1])

result_df= df.loc[df['Max Context']=="BERT10"]

print(result_df)
# Out:
#   Max Context  KL Score AP  COS Score AP layer
# 0      BERT10     0.756196      0.711123    -1
# 0      BERT10     0.769181      0.692565    -2
# 0      BERT10     0.747315      0.689565    -3
# 0      BERT10     0.757551      0.680599  -123

# %%
embavg = torch.load('../data_distrembed/onetenth_vocab.embavg.pt')

# %%
pd.__version__
# Out:
# '1.3.5'

# %%
with open(f'../data_shared/fixed/ramdom_curated0-25/curated10num2.pickle', 'rb') as f:
    df1test = pickle.load(f)

for sentence in df1test:
    for word in sentence.split():
        if word == "cold":
            print(sentence)
# Out:
# in early two helicopters will be tested in cold weather in yellowknife canada as a third prototype will validate performance in snowy north continental us
# new york cyclonic flow and cold air around the backside of this system led to significant lake effect snows for areas downwind of the great lakes
# rogen benastra is the chief seismologist at streeling university who helps dors find hari after he becomes lost in the cold upperside
# in the data center shown the rooms serve as cold corridors there is a raised floor but there are no perforated tiles
# in air as cold as shapes become plate like again often with branched or dendritic features
# playoffs the rams ventured into a cold weather venue bloomington minnesota just as they had in when they dropped a – game to the packers in milwaukee
# on july reeve was flying radar equipment and four technicians from cold bay to amchitka when he ran into zero zero visibility conditions
# the soviet navy towards the end of the cold war is another example of a blue water navy that had minimal carrier aviation relying instead on submarines missile carrying surface ships and long range bombers based on land
# this facility has a four stand continuous cold rolling strip mill annealing furnaces two skin pass finishing mills and other ancillary equipment for further processing of cold rolled steel coils
# this facility has a four stand continuous cold rolling strip mill annealing furnaces two skin pass finishing mills and other ancillary equipment for further processing of cold rolled steel coils
# as built the initial design of the stock was unwelcoming with a cold steel appearance seats covered in a rexine type material and roof to floor grab poles for standing commuters
# uses the paiute people of eastern california and the great basin used a decoction as a cold remedy and pulmonary aid
# common cold in when a cluster of nurses developed a mild respiratory illness price took nasal passage samples and isolated the first rhinovirus which he called the jh virus named after johns hopkins
# their principal advantage is in allowing finer particles of ice to be delivered to the applicator as the late combination of warm air with cold ice results in less sublimation in the hose
# nevus anemicus is a congenital disorder characterized by macules of varying size and shape that are paler than the surrounding skin and cannot be made red by trauma cold or heat
# she harshly berates him for coming alone only offers him hard bread and cold water for his efforts and does not shelter him from the cold on her sledge
# she harshly berates him for coming alone only offers him hard bread and cold water for his efforts and does not shelter him from the cold on her sledge
# factors known to trigger episodes are stress cold environment or hypothermia carbohydrate load infection glucose infusion metabolic alkalosis alcohol strenuous exercise and steroids
# the wine heated in a combination with pepper is used as a prevention from flu or cold
# while edible cold when circumstances permit the ideal method of preparation is to cook the entrees either in a pressure cooker heated on the standard issue coleman stove or by simply boiling the rations in its package in water
# romanian president traian băsescu said romania s approach to the relationship with russia was to leave behind the cold war logic
# like typical hydrothermal vents the endeavour hydrothermal vents form when cold seawater seeps into cracks and crevices in the endeavour segment where it becomes heated by magma that lies beneath the seafloor
# it may also form from the very slow reaction of finely divided cupric oxide with cold hydrogen peroxide
# worried about the lab rabbits being cold in the lab s lowered temperature sandy surreptitiously turns up the thermostat
# cheese spreads include benedictine cold pack cheese and cup cheese
# in the same year the pcd erected its own cold stores at gladstone with storage capacity for of butter
# ernest haycox s historical novel alder gulch depicts plummer as handsome and well spoken but a cold and calculating murderer and thief without conscience
# but after barry allen s death during the crisis on infinite earths captain cold became a bounty hunter with his sister lisa the golden glider
# pour cooked fruit into a jelly bag which has been wrung out of cold water
# hsv can in rare cases be transmitted to newborn babies by family members or hospital staff who have cold sores this can cause a severe disease called neonatal herpes simplex
# on friday espn s cold pizza morning show was broadcast from in front of the bryce jordan center across from the stadium with some of the cast walking through paternoville interviewing students and taping their activities despite the constant drizzle

# %% [markdown]
# # diff plot

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Initialize an empty dataframe to store the merged data
df = pd.DataFrame()

# Loop through the pickled files and merge them
for j in range(1,6):
    for i in range(5,51,5):
        with open(f'../data_shared/ma31jan/df_AP{i}_Falsenum{j}.pickle', 'rb') as f:
            df1 = pickle.load(f)
        df = pd.concat([df, df1])
        
# Split the dataframe into separate dataframes for BERT and EMP scores
df_bert = df[df['Max Context'].str.contains("BERT")]
df_emp = df[df['Max Context'].str.contains("EMP")]

# KL Score AP BERT
df_kl_bert = df_bert.melt(id_vars='Max Context', value_vars=['KL Score AP'], value_name='Score')
df_kl_bert['Model'] = 'BERT'
df_kl_bert['Max Context'] = df_kl_bert['Max Context'].apply(lambda x: int(x.split("BERT")[1]))

# KL Score AP EMP
df_kl_emp = df_emp.melt(id_vars='Max Context', value_vars=['KL Score AP'], value_name='Score')
df_kl_emp['Model'] = 'EMP'
df_kl_emp['Max Context'] = df_kl_emp['Max Context'].apply(lambda x: int(x.split("EMP")[1]))

# Combine KL Score AP BERT and KL Score AP EMP
df_kl = pd.concat([df_kl_bert, df_kl_emp])

# COS Score AP BERT
df_cos_bert = df_bert.melt(id_vars='Max Context', value_vars=['COS Score AP'], value_name='Score')
df_cos_bert['Model'] = 'BERT'
df_cos_bert['Max Context'] = df_cos_bert['Max Context'].apply(lambda x: int(x.split("BERT")[1]))

# COS Score AP EMP
df_cos_emp = df_emp.melt(id_vars='Max Context', value_vars=['COS Score AP'], value_name='Score')
df_cos_emp['Model'] = 'EMP'
df_cos_emp['Max Context'] = df_cos_emp['Max Context'].apply(lambda x: int(x.split("EMP")[1]))

# Combine COS Score AP BERT and COS Score AP EMP
df_cos = pd.concat([df_cos_bert, df_cos_emp])

fig, ax = plt.subplots(figsize=(10, 5))

# Plot the KL Score AP and COS Score AP in the same plot
for var, data in zip(['KL Score AP', 'COS Score AP'], [df_kl, df_cos]):
    for model, group in data.groupby('Model'):
        group.plot(kind='errorbar', x='Max Context', y='Score', yerr=group['Score'].std(), label=model, ax=ax)

        
    
ax.set_title(var)
ax.set_xlabel('Max Context')
ax.set_ylabel('Score')
ax.legend()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-a18a1d071404> in <module>
#      47 for var, data in zip(['KL Score AP', 'COS Score AP'], [df_kl, df_cos]):
#      48     for model, group in data.groupby('Model'):
# ---> 49         group.plot(kind='errorbar', x='Max Context', y='Score', yerr=group['Score'].std(), label=model, ax=ax)
#      50
#      51
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     903
#     904         if kind not in self._all_kinds:
# --> 905             raise ValueError(f"{kind} is not a valid plot kind")
#     906
#     907         # The original data structured can be transformed before passed to the
#
# ValueError: errorbar is not a valid plot kind

# %%
import pickle5 as pickle 
import pandas as pd
import matplotlib.pyplot as plt

# Initialize an empty dataframe to store the merged data
df = pd.DataFrame()

# Loop through the pickled files and merge them
for j in range(1,6):
    for i in range(5,51,5):
        with open(f'../data_shared/ma31jan/df_AP{i}_Falsenum{j}.pickle', 'rb') as f:
            df1 = pickle.load(f)
        df = pd.concat([df, df1])

# Split the dataframe into separate dataframes for BERT and EMP scores
df_bert = df[df['Max Context'].str.contains("BERT")]
df_emp = df[df['Max Context'].str.contains("EMP")]

# KL Score AP BERT
df_kl_bert = df_bert.melt(id_vars='Max Context', value_vars=['KL Score AP'], value_name='Score')
df_kl_bert['Model'] = df_kl_bert['variable'].apply(lambda x: x.split()[0])
df_kl_bert['Max Context'] = df_kl_bert['Max Context'].apply(lambda x: int(x.split("BERT")[1]))

x = df_kl_bert['Max Context'].unique()
y = df_kl_bert.groupby('Max Context')['Score'].mean()
yerr = df_kl_bert.groupby('Max Context')['Score'].std()

plt.errorbar(x, y, yerr, fmt='o', capsize=5, label='KL AP BERT')

# COS Score AP BERT
df_cos_bert = df_bert.melt(id_vars='Max Context', value_vars=['COS Score AP'], value_name='Score')
df_cos_bert['Model'] = df_cos_bert['variable'].apply(lambda x: x.split()[0])
df_cos_bert['Max Context'] = df_cos_bert['Max Context'].apply(lambda x: int(x.split("BERT")[1]))

x = df_cos_bert['Max Context'].unique()
y = df_cos_bert.groupby('Max Context')['Score'].mean()
yerr = df_cos_bert.groupby('Max Context')['Score'].std()

plt.errorbar(x, y, yerr, fmt='v', capsize=5, label='COS AP BERT')
# axes[0, 0].set_xlabel('Max Context')
# axes[0, 0].set_ylabel('Score')

# COS Score AP EMP
df_cos_emp = df_emp.melt(id_vars='Max Context', value_vars=['COS Score AP'], value_name='Score')
df_cos_emp['Model'] = df_cos_emp['variable'].apply(lambda x: x.split()[0])
df_cos_emp['Max Context'] = df_cos_emp['Max Context'].apply(lambda x: int(x.split("EMP")[1]))

x = df_cos_emp['Max Context'].unique()
y = df_cos_emp.groupby('Max Context')['Score'].mean()
yerr = df_cos_emp.groupby('Max Context')['Score'].std()

plt.errorbar(x, y, yerr, label='COS AP FastText')

plt.xlabel("Context Sentences")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# # ma31jan

# %%
import pickle5 as pickle



with open(f'../data_shared/ma31jan/df_curated5_diag_Falsenum3.pickle', 'rb') as f:
    df1test = pickle.load(f)




# CALCULATE KL and COS


print("----------BERT RESULTS-----------")
print("COS AP               : ", average_precision_score(df1test["True label"], df1test["bert COS score"]))
print("KL AP                : ", average_precision_score(df1test["True label"], -df1test["bert KL score"]))

result_df1= df1test.loc[df1test['True label']==1]
result_df1.nlargest(5, 'bert KL score')
# Out:
# ----------BERT RESULTS-----------
# COS AP               :  0.7040445780116693
# KL AP                :  0.7369305553534669
#                        Wordpair  True label  bert KL score  bert COS score  \
# 514   [gastropod, invertebrate]           1  113205.976562  tensor(0.4600)
# 1144            [snail, animal]           1   97935.875000  tensor(0.3683)
# 798           [mollusc, animal]           1   97565.203125  tensor(0.3834)
# 71            [asp, vertebrate]           1   95695.375000  tensor(0.2726)
# 1064        [robin, vertebrate]           1   94977.695312  tensor(0.4528)
#
#       empirical KL score  empirical COS score
# 514           249.709015             0.435568
# 1144          166.141815             0.633497
# 798           168.957169             0.439421
# 71           1920.617188             0.201955
# 1064          313.854889             0.355079

# %%
import pickle5 as pickle



with open(f'../data_shared/ma31jan/df_curated30_diag_Falsenum3.pickle', 'rb') as f:
    df1test = pickle.load(f)




# CALCULATE KL and COS


print("----------BERT RESULTS-----------")
print("COS AP               : ", average_precision_score(df1test["True label"], df1test["bert COS score"]))
print("KL AP                : ", average_precision_score(df1test["True label"], -df1test["bert KL score"]))

result_df1= df1test.loc[df1test['True label']==1]
result_df1.nsmallest(5, 'bert KL score')
# Out:
# ----------BERT RESULTS-----------
# COS AP               :  0.7098869015126141
# KL AP                :  0.7511684999374009
#                 Wordpair  True label  bert KL score  bert COS score  \
# 565  [gymnasium, school]           1    3919.816895  tensor(0.7518)
# 456   [farmhouse, house]           1    3947.557129  tensor(0.8029)
# 840     [nickname, name]           1    3956.209961  tensor(0.8401)
# 309     [cottage, house]           1    4215.772949  tensor(0.8139)
# 522     [gentry, people]           1    4475.296387  tensor(0.6241)
#
#      empirical KL score  empirical COS score
# 565           43.375290             0.688927
# 456           39.856094             0.745853
# 840           46.959503             0.701906
# 309           57.420044             0.729299
# 522          211.490814             0.347461

# %%
df1test.loc[1144]
# Out:
# Wordpair               [snail, animal]
# True label                           1
# bert KL score             36243.890625
# bert COS score          tensor(0.4507)
# empirical KL score          141.942169
# empirical COS score           0.633497
# Name: 1144, dtype: object

# %%
with open(f'../data_shared/ma31jan/curated30num3.pickle', 'rb') as f:
    df1test = pickle.load(f)

for sentence in df1test:
    for word in sentence.split():
        if word == "snail":
            print("/item", sentence)
# Out:
# /item etymology the specific name is derived from the hawaiian pūpū meaning snail and moehewa meaning nightmare and refers to the unique feeding habits of the caterpillars
# /item cystiscus pardus is a species of very small sea snail a marine gastropod mollusk or micromollusk in the family cystiscidae
# /item pleurofusia phasma is an extinct species of sea snail a marine gastropod mollusk in the family drilliidae
# /item luria lurida is a species of sea snail a cowry a marine gastropod mollusk in the family cypraeidae the cowries
# /item muricopsis muricopsis caribbaea is a species of sea snail a marine gastropod mollusk in the family muricidae the murex snails or rock snails
# /item when the caterpillar is repaired the track is cleared the race begins but it is run at a snail s pace
# /item trochoidea trochoides is a species of air breathing land snail a terrestrial pulmonate gastropod mollusk in the family hygromiidae the hairy snails and their allies
# /item pseudorhaphitoma pyramidalis is a small sea snail a marine gastropod mollusk in the family mangeliidae
# /item gibbula magus common name the great top shell is a species of small sea snail a marine gastropod mollusc in the family trochidae the top snails
# /item turbonilla gloriosa is a species of sea snail a marine gastropod mollusk in the family pyramidellidae the pyrams and their allies
# /item raphitoma gabusogana is an extinct species of sea snail a marine gastropod mollusc in the family raphitomidae
# /item cranopsis cumingii is a species of sea snail a marine gastropod mollusk in the family fissurellidae the keyhole limpets and slit limpets
# /item description high spined commensal hydroids grow as a fuzzy looking orange coat usually on the shell of a marine snail the scaly dogwhelk nucella squamosa
# /item euthria philpoppei is a species of sea snail a marine gastropod mollusk in the family buccinidae the true whelks
# /item mangelia fieldeni is a species of sea snail a marine gastropod mollusk in the family mangeliidae
# /item justin and sarah jane wear themselves out babysitting snail race justin and sarah jane set off for a snail race and picnic
# /item justin and sarah jane wear themselves out babysitting snail race justin and sarah jane set off for a snail race and picnic
# /item babylonia ambulacrum is a species of sea snail a marine gastropod mollusk in the family babyloniidae
# /item group are linear in shape and flood prone at the base of a gorge references sources adclarkia dawsonensis boggomoss snail dawson valley snail category patterned grounds category soil category australian slang
# /item group are linear in shape and flood prone at the base of a gorge references sources adclarkia dawsonensis boggomoss snail dawson valley snail category patterned grounds category soil category australian slang
# /item echinolittorina natalensis is a species of sea snail a marine gastropod mollusk in the family littorinidae the winkles or periwinkles
# /item maculotriton digitalis is a species of sea snail a marine gastropod mollusk in the family muricidae the murex snails or rock snails
# /item habitat this snail has been found in two caves in very close proximity within a km² area in pohara takaka
# /item canarium scalariforme is a species of sea snail a marine gastropod mollusk in the family strombidae the true conchs
# /item there have been hybridizations of snail species although these do not occur commonly in the wild in captivity they can be coaxed into doing so
# /item this snail was long thought to be endemic to one cove on the edge of the cumberland plateau near the town of sherwood tennessee
# /item volutoconus hargreavesi is a species of sea snail a marine gastropod mollusk in the family volutidae the volutes
# /item oliva sargenti is a species of sea snail a marine gastropod mollusk in the family olividae the olives
# /item vexillum costellaria poppei is a species of small sea snail marine gastropod mollusk in the family costellariidae the ribbed miters
# /item the courtship rituals for the snail begin with one following the trail of another snail
# /item the courtship rituals for the snail begin with one following the trail of another snail
# /item prior to copulation each of the two snails or slugs attempts to shoot one or more darts into the other snail or slug
# /item caseolus sphaerulus is a species of small land snail a terrestrial pulmonate gastropod mollusk
# /item mitrella bruggeni is a species of sea snail a marine gastropod mollusk in the family columbellidae the dove snails
# /item conus felix is a species of sea snail a marine gastropod mollusc in the family conidae the cone snails cone shells or cones
# /item the servings include a handful of cooked millet and rice two pieces of pork two pieces of snail and two thin strips of banana leaves spread over the food
# /item sowerby iii a sea snail found f
# /item this pelagic snail is not at all closely related to the pelagic opistobranchs such as the sea angels and sea butterflies
# /item snail suppers were a feature of local pubs and southwick working men were collecting and eating snails as late as the though the tradition may now have died out
# /item this snail farming method was described by fulvius lippinus bc and mentioned by marcus terentius varro in de re rustica iii
# /item human activities such as logging housing developments and forest fires can all alter the environmental conditions that the flat spired three toothed snail needs to survive
# /item the golden apple snail a
# /item the maiden rocksnail scientific name †leptoxis formosa was a species of freshwater snail with a gill and an operculum an aquatic gastropod mollusk in the family pleuroceridae
# /item a typical example is the decollate snail rumina decollata
# /item the snail is also found in the middle e
# /item cerithium balletoni is a species of sea snail a marine gastropod mollusc in the family cerithiidae
# /item afropomus balanoidea is a species of freshwater snail an aquatic gastropod mollusk in the family ampullariidae the apple snails and their allies
# /item the endemic freshwater snail elimia cahawbensis is named after the river
# /item tylomelania insulaesacrae is a species of freshwater snail with an operculum an aquatic gastropod mollusk in the family pachychilidae
# /item population density in a mark recapture study was initiated where newcomb s tree snail occurred
# /item nassarina thetys is a species of sea snail a marine gastropod mollusk in the family columbellidae the dove snails
# /item species species within the genus austrocochlea include austrocochlea brevis parsons ward austrocochlea constellata souverbie austrocochlea constricta lamarck the southern ribbed top snail austrocochlea diminuta hedley austrocochlea piperina philippi austrocochlea porcata a
# /item turcica admirabilis is a species of sea snail a marine gastropod mollusc in the family eucyclidae
# /item this snail prefers an aquarium temperature of to °c
# /item the us fish and wildlife service recently proposed to list this snail as an endangered species
# /item the rare snail abide secale is recorded
# /item the common name worm snail or worm snai
# /item crossea biconica is a species of small sea snail or micromollusc a marine gastropod mollusc in the family conradiidae
# /item clea bangueyensis is a species of freshwater snail with an operculum an aquatic gastropod mollusk in the family buccinidae the true whelks most of which are marine
# /item lyncina vitellus common name the calf cowry or the pacific deer cowry is a species of sea snail a cowry a marine gastropod mollusk in the family cypraeidae the cowries
# /item the new zealand mud snail has infested watersheds in the santa monica mountains posing serious threats to native species and complicating efforts to improve stream water quality for the endangered steelhead
# /item the cercariae eventually leave the snail and infect the second intermediate host crustaceans
# /item the authors group of all known cone snail species under conus they recognize subgenera within conus and subgenera within the genus conasprella
# /item triloba may refer to triloba genus a land snail genus in the family clausiliidae
# /item one of its predators is ocenebra lurida middendorff a murex snail
# /item it has uncommon liverworts mosses and lichens together with rare and scarce invertebrates such as rolph s door snail and the crane fly lipsothrix nervosa
# /item many mystery snail owners make food called snail jello for their pets to eat
# /item many mystery snail owners make food called snail jello for their pets to eat
# /item enigmaticolus monnieri is a species of sea snail a marine gastropod mollusc in the family buccinidae the true whelks
# /item fulgida may refer to acyphoderes fulgida a longhorn beetle aeschynomene fulgida a legume with an aeschynomenoid root nodule anachis fulgida a dove snail andrena fulgida a mining bee argia fulgida a new world damselfly arhopala fulgida a blue butterfly
# /item daphnella itonis is a species of sea snail a marine gastropod mollusc in the family raphitomidae
# /item tugali stewartiana is a species of medium sized sea snail or limpet a marine gastropod mollusc in the family fissurellidae the keyhole limpets and slit limpets
# /item comitas eurina is a species of sea snail a marine gastropod mollusc in the family pseudomelatomidae
# /item cochlostoma pageti is a species of small land snail with an operculum a terrestrial gastropod mollusc in the family cochlostomatidae
# /item phalium glaucum common name the grey bonnet or glaucus bonnet is a species of large sea snail a marine gastropod mollusk in the family cassidae the helmet snails and bonnet snails
# /item smaller wildlife such as snowshoe hare lepus americanus and american pygmy shrew sorex hoyi can be found here as well and the banff springs snail physella johnsoni which is endemic to banff national park
# /item eulithidium rubrilineatum common name the red line pheasant is an extremely small species of sea snail with a calcareous opercula a marine gastropod mollusk in the family phasianellidae the pheasant snails
# /item some other endemics are cooper s rocky mountain snail black hills subspecies of red bellied snake and a black hills subspecies of southern red backed vole
# /item cittarium pica common name the west indian top shell or magpie shell is a species of large edible sea snail a marine gastropod mollusk in the family tegulidae
# /item tricolia gabiniana is a species of small sea snail with calcareous opercula a marine gastropod mollusk in the family phasianellidae the pheasant snails
# /item it contains various silly short stories about things such as snail shell repairing baby pram riding and nonsense dreams

# %% [markdown]
# # end of section

# %%
import pickle5 as pickle



with open(f'../data_shared/sat28jan/df_curated10_diag_Falsenum1.pickle', 'rb') as f:
    df1test = pickle.load(f)




# CALCULATE KL and COS


print("----------BERT RESULTS-----------")
print("COS AP               : ", average_precision_score(df1test["True label"], df1test["bert COS score"]))
print("KL AP                : ", average_precision_score(df1test["True label"], -df1test["bert KL score"]))

# result_df1= df1test.loc[df1test['True label']==1]
# result_df1.nlargest(5, 'bert KL score')
# Out:
# ----------BERT RESULTS-----------
# COS AP               :  0.7075361224001171
# KL AP                :  0.756379509554135
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2765    False
# 2766    False
# 2767    False
# 2768    False
# 2769    False
# Name: Wordpair, Length: 2770, dtype: bool

# %%
result_df2= df1test.loc[df1test['True label']==0]
result_df2.nsmallest(5, 'bert KL score')
# Out:
#                      Wordpair  True label  bert KL score  bert COS score  \
# 2283   [passageway, corridor]           0   16585.785156  tensor(0.8397)
# 2627      [treatment, people]           0   17270.125000  tensor(0.5925)
# 2161           [meal, dinner]           0   17319.978516  tensor(0.8668)
# 2716       [waiter, waitress]           0   17585.244141  tensor(0.8533)
# 2072  [journalist, columnist]           0   17700.158203  tensor(0.8731)
#
#       empirical KL score  empirical COS score
# 2283           46.429169             0.640688
# 2627           41.497139             0.164805
# 2161          164.677582             0.820719
# 2716           78.471375             0.852165
# 2072           37.774750             0.803825

# %%
import pickle5 as pickle
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt

# Initialize an empty dataframe to store the merged data
df = pd.DataFrame()

# Loop through the pickled files and merge them
for j in tqdm(range(1,6)):
    for i in range(5,26,5):
        with open(f'../data_shared/fixed/df_AP{i}_Truenum{j}.pickle', 'rb') as f:
            df1 = pickle.load(f)
        df = pd.concat([df, df1])

# Split the dataframe into separate dataframes for BERT and EMP scores
df_bert = df[df['Max Context'].str.contains("BERT")]
df_emp = df[df['Max Context'].str.contains("EMP")]

# Create a boxplot for the BERT scores
plt.figure(figsize=(10,5))
df_bert.boxplot(column=['KL Score AP', 'COS Score AP'])
plt.title("BERT Scores")
plt.xlabel("Scores")
plt.ylabel("Value")
plt.show()

# Create a boxplot for the EMP scores
plt.figure(figsize=(10,5))
df_emp.boxplot(column=['KL Score AP', 'COS Score AP'])
plt.title("EMP Scores")
plt.xlabel("Scores")
plt.ylabel("Value")
plt.show()
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:00<00:00,  5.68it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.71it/s]

# %%
import pickle5 as pickle 
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt

# Initialize an empty dataframe to store the merged data
df = pd.DataFrame()

# Loop through the pickled files and merge them
for j in tqdm(range(1,6)):
    for i in range(5,51,5):
        with open(f'../data_shared/ma31jan/df_AP{i}_Falsenum{j}.pickle', 'rb') as f:
            df1 = pickle.load(f)
        df = pd.concat([df, df1])

print(df)
# Split the dataframe into separate dataframes for BERT and EMP scores
df_bert = df[df['Max Context'].str.contains("BERT")]
df_emp = df[df['Max Context'].str.contains("EMP")]

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 10))

# KL Score AP BERT
df_kl_bert = df_bert.melt(id_vars='Max Context', value_vars=['KL Score AP'], value_name='Score')
df_kl_bert['Model'] = df_kl_bert['variable'].apply(lambda x: x.split()[0])
df_kl_bert['Max Context'] = df_kl_bert['Max Context'].apply(lambda x: int(x.split("BERT")[1]))

df_kl_bert.boxplot(by=['Max Context', 'Model'], ax=axes[0, 0]) #,color='orange')
axes[0, 0].set_title('KL Score AP BERT')
axes[0, 0].set_xlabel('Max Context')
axes[0, 0].set_ylabel('Score')

# KL Score AP EMP
df_kl_emp = df_emp.melt(id_vars='Max Context', value_vars=['KL Score AP'], value_name='Score')
df_kl_emp['Model'] = df_kl_emp['variable'].apply(lambda x: x.split()[0])
df_kl_emp['Max Context'] = df_kl_emp['Max Context'].apply(lambda x: int(x.split("EMP")[1]))

df_kl_emp.boxplot(by=['Max Context', 'Model'], ax=axes[0, 1])
axes[0, 1].set_title('KL Score AP EMP')
axes[0, 1].set_xlabel('Max Context')
axes[0, 1].set_ylabel('Score')

# COS Score AP BERT
df_cos_bert = df_bert.melt(id_vars='Max Context', value_vars=['COS Score AP'], value_name='Score')
df_cos_bert['Model'] = df_cos_bert['variable'].apply(lambda x: x.split()[0])
df_cos_bert['Max Context'] = df_cos_bert['Max Context'].apply(lambda x: int(x.split("BERT")[1]))

df_cos_bert.boxplot(by=['Max Context', 'Model'], ax=axes[1, 0])
axes[1, 0].set_title('COS Score AP BERT')
axes[1, 0].set_xlabel('Max Context')
axes[1, 0].set_ylabel('Score')

# COS Score AP EMP
df_cos_emp = df_emp.melt(id_vars='Max Context', value_vars=['COS Score AP'], value_name='Score')
df_cos_emp['Model'] = df_cos_emp['variable'].apply(lambda x: x.split()[0])
df_cos_emp['Max Context'] = df_cos_emp['Max Context'].apply(lambda x: int(x.split("EMP")[1]))


df_cos_emp.boxplot(by=['Max Context', 'Model'], ax=axes[1, 1])
axes[1, 1].set_title('COS Score AP EMP')
axes[1, 1].set_xlabel('Max Context')
axes[1, 1].set_ylabel('Score')

axes[0, 0].set_xticklabels([5, 10, 15, 20, 25, 30, 35, 40, 45, 50])
axes[0, 1].set_xticklabels([5, 10, 15, 20, 25, 30, 35, 40, 45, 50])
axes[1, 0].set_xticklabels([5, 10, 15, 20, 25, 30, 35, 40, 45, 50])
axes[1, 1].set_xticklabels([5, 10, 15, 20, 25, 30, 35, 40, 45, 50])
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
#  40%|████      | 2/5 [00:00<00:00, 13.71it/s]
# 100%|██████████| 5/5 [00:00<00:00, 16.12it/s]
#    Max Context  KL Score AP  COS Score AP
# 0        BERT5     0.745565      0.711886
# 1         EMP5     0.557188      0.727667
# 0       BERT10     0.752972      0.708317
# 1        EMP10     0.543200      0.727667
# 0       BERT15     0.751078      0.708620
# ..         ...          ...           ...
# 1        EMP40     0.531662      0.727667
# 0       BERT45     0.745307      0.708453
# 1        EMP45     0.529628      0.727667
# 0       BERT50     0.746207      0.708028
# 1        EMP50     0.529020      0.727667
#
# [100 rows x 3 columns]
# [Text(1, 0, '5'),
#  Text(2, 0, '10'),
#  Text(3, 0, '15'),
#  Text(4, 0, '20'),
#  Text(5, 0, '25'),
#  Text(6, 0, '30'),
#  Text(7, 0, '35'),
#  Text(8, 0, '40'),
#  Text(9, 0, '45'),
#  Text(10, 0, '50')]

# %%
import pickle5 as pickle 
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt

# Initialize an empty dataframe to store the merged data
df = pd.DataFrame()

# Loop through the pickled files and merge them
for j in tqdm(range(1,6)):
    for i in range(5,26,5):
        with open(f'../data_shared/ma31jan/df_AP{i}_Falsenum{j}.pickle', 'rb') as f:
            df1 = pickle.load(f)
        df = pd.concat([df, df1])

        
# Split the dataframe into separate dataframes for BERT and EMP scores
df_bert = df[df['Max Context'].str.contains("BERT")]
df_emp = df[df['Max Context'].str.contains("EMP")]

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 10))

# KL Score AP BERT
df_kl_bert = df_bert.melt(id_vars='Max Context', value_vars=['KL Score AP'], value_name='Score')
df_kl_bert['Model'] = df_kl_bert['variable'].apply(lambda x: x.split()[0])
df_kl_bert['Max Context'] = df_kl_bert['Max Context'].apply(lambda x: int(x.split("BERT")[1]))

df_kl_bert.boxplot(by=['Max Context', 'Model'], ax=axes[0, 0]) #,color='orange')
axes[0, 0].set_title('KL Score AP BERT')
axes[0, 0].set_xlabel('Max Context')
axes[0, 0].set_ylabel('Score')

# KL Score AP EMP
df_kl_emp = df_emp.melt(id_vars='Max Context', value_vars=['KL Score AP'], value_name='Score')
df_kl_emp['Model'] = df_kl_emp['variable'].apply(lambda x: x.split()[0])
df_kl_emp['Max Context'] = df_kl_emp['Max Context'].apply(lambda x: int(x.split("EMP")[1]))

df_kl_emp.boxplot(by=['Max Context', 'Model'], ax=axes[0, 1])
axes[0, 1].set_title('KL Score AP EMP')
axes[0, 1].set_xlabel('Max Context')
axes[0, 1].set_ylabel('Score')

# COS Score AP BERT
df_cos_bert = df_bert.melt(id_vars='Max Context', value_vars=['COS Score AP'], value_name='Score')
df_cos_bert['Model'] = df_cos_bert['variable'].apply(lambda x: x.split()[0])
df_cos_bert['Max Context'] = df_cos_bert['Max Context'].apply(lambda x: int(x.split("BERT")[1]))

df_cos_bert.boxplot(by=['Max Context', 'Model'], ax=axes[1, 0])
axes[1, 0].set_title('COS Score AP BERT')
axes[1, 0].set_xlabel('Max Context')
axes[1, 0].set_ylabel('Score')

# COS Score AP EMP
df_cos_emp = df_emp.melt(id_vars='Max Context', value_vars=['COS Score AP'], value_name='Score')
df_cos_emp['Model'] = df_cos_emp['variable'].apply(lambda x: x.split()[0])
df_cos_emp['Max Context'] = df_cos_emp['Max Context'].apply(lambda x: int(x.split("EMP")[1]))


df_cos_emp.boxplot(by=['Max Context', 'Model'], ax=axes[1, 1])
axes[1, 1].set_title('COS Score AP EMP')
axes[1, 1].set_xlabel('Max Context')
axes[1, 1].set_ylabel('Score')

axes[0, 0].set_xticklabels([5, 10, 15, 20, 25])
axes[0, 1].set_xticklabels([5, 10, 15, 20, 25])
axes[1, 0].set_xticklabels([5, 10, 15, 20, 25])
axes[1, 1].set_xticklabels([5, 10, 15, 20, 25])
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-387-72ccc0bd9f75> in <module>
#      10 for j in tqdm(range(1,6)):
#      11     for i in range(5,26,5):
# ---> 12         with open(f'../data_shared/ma31jan/df_AP{i}_Falsenum{j}.pickle', 'rb') as f:
#      13             df1 = pickle.load(f)
#      14         df = pd.concat([df, df1])
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data_shared/ma31jan/df_AP5_Falsenum1.pickle'

# %%
import pickle5 as pickle 
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt

# Initialize an empty dataframe to store the merged data
df = pd.DataFrame()

# Loop through the pickled files and merge them
for j in tqdm(range(1,6)):
    i = 100

    with open(f'../data_shared/fixed/df_AP{i}_Falsenum{j}.pickle', 'rb') as f:
        df1 = pickle.load(f)
    df = pd.concat([df, df1])

# Split the dataframe into separate dataframes for BERT and EMP scores
df_bert = df[df['Max Context'].str.contains("BERT")]
df_emp = df[df['Max Context'].str.contains("EMP")]

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 10))

# KL Score AP BERT
df_kl_bert = df_bert.melt(id_vars='Max Context', value_vars=['KL Score AP'], value_name='Score')
df_kl_bert['Model'] = df_kl_bert['variable'].apply(lambda x: x.split()[0])
df_kl_bert['Max Context'] = df_kl_bert['Max Context'].apply(lambda x: int(x.split("BERT")[1]))

df_kl_bert.boxplot(by=['Max Context', 'Model'], ax=axes[0, 0], color='orange')
axes[0, 0].set_title('KL Score AP BERT')
axes[0, 0].set_xlabel('Max Context')
axes[0, 0].set_ylabel('Score')

# KL Score AP EMP
df_kl_emp = df_emp.melt(id_vars='Max Context', value_vars=['KL Score AP'], value_name='Score')
df_kl_emp['Model'] = df_kl_emp['variable'].apply(lambda x: x.split()[0])
df_kl_emp['Max Context'] = df_kl_emp['Max Context'].apply(lambda x: int(x.split("EMP")[1]))

df_kl_emp.boxplot(by=['Max Context', 'Model'], ax=axes[0, 1], color='orange')
axes[0, 1].set_title('KL Score AP EMP')
axes[0, 1].set_xlabel('Max Context')
axes[0, 1].set_ylabel('Score')

# COS Score AP BERT
df_cos_bert = df_bert.melt(id_vars='Max Context', value_vars=['COS Score AP'], value_name='Score')
df_cos_bert['Model'] = df_cos_bert['variable'].apply(lambda x: x.split()[0])
df_cos_bert['Max Context'] = df_cos_bert['Max Context'].apply(lambda x: int(x.split("BERT")[1]))

df_cos_bert.boxplot(by=['Max Context', 'Model'], ax=axes[1, 0], color='orange')
axes[1, 0].set_title('COS Score AP BERT')
axes[1, 0].set_xlabel('Max Context')
axes[1, 0].set_ylabel('Score')

# COS Score AP EMP
df_cos_emp = df_emp.melt(id_vars='Max Context', value_vars=['COS Score AP'], value_name='Score')
df_cos_emp['Model'] = df_cos_emp['variable'].apply(lambda x: x.split()[0])
df_cos_emp['Max Context'] = df_cos_emp['Max Context'].apply(lambda x: int(x.split("EMP")[1]))


df_cos_emp.boxplot(by=['Max Context', 'Model'], ax=axes[1, 1], color='orange')
axes[1, 1].set_title('COS Score AP EMP')
axes[1, 1].set_xlabel('Max Context')
axes[1, 1].set_ylabel('Score')
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:00<00:00,  5.94it/s]
# 100%|██████████| 5/5 [00:00<00:00, 17.19it/s]
# Text(0, 0.5, 'Score')

# %%
with open(f'../data_shared/fixed/df_AP5_Falsenum1.pickle', 'rb') as f:
    df1 = pickle.load(f)

df1
# Out:
#   Max Context  KL Score AP  COS Score AP
# 0       BERT5     0.704724      0.734969
# 1        EMP5     0.472953      0.780603

# %%
for i in range(0,26,5):
    print(i)
# Out:
# 0
# 5
# 10
# 15
# 20
# 25

# %%
with open('../data_shared/fixed/ramdom_curated0-25/curated5num1.pickle', 'rb') as f:
    df_AP1_True = pickle.load(f)
    
df_AP1_True
# Out:
# ['world war ii although many squadrons were raised at raaf station laverton during world war ii the base s prime focus continued to be its aircraft depot',
#  'minidoux and hard tits from the album smash were used in the adult swim super violence disclaimer and actn water tanks bumpers respectively',
#  'in the name of the locality was officially gazetted as hūkerenui',
#  'throughout the frets magazine readers chose phillips in five readers poll awards for best jazz and best bluegrass bassist',
#  'his show ruuddewild',
#  'it landed three times in deloitte’s technology fast central europe ranking and twice on the ft ” the financial times’ list of fastest growing companies in europe',
#  'this building burned to the ground in the and was replaced with a stone courthouse',
#  'the work of sociologist erving goffman laid the theoretical foundation for ways to study the construction of everyday social meanings and behavioral norms especially by breaking unstated but universally accepted rules',
#  'it is still mild comparatively speaking temperatures on a clear night will likely be colder than the land at the top of valley floor or roughly speaking along reddish road gorton road',
#  'becky would visit ian to inform him of tank being taken in for questioning and discover the bite marks zoe left on ian s arm while attempting to change his dressing on his wound',
#  'at this stage only two of the four accused – james king and steve – will be tried since the other two accused – richard bobo evans and osvaldo cruz – have entered into a plea bargain',
#  'the effective length is the actual length plus an end correction',
#  'a compass is one such device one that measures the direction of an ambient magnetic field in this case the earth s magnetic field',
#  'tutush s son duqaq and the latter s deputy tughtakin besieged the town but failed to capture it',
#  'this technique has been so successful that commercial microbial cellulose products such as biofill ® have been developed',
#  'this device would allow for a patient to be treated twenty four hours a day',
#  'los angeles dodgers on august padilla signed a minor league contract with the los angeles dodgers',
#  'history plans to build the arts center in burnsville originated with partners for tomorrow a citizen based community forum convened in and',
#  'homosexuality klyuev was homosexual and had love affairs in vytegra in the immediate post revolutionary years and before settling in st petersburg in the',
#  'in a bridge across the clarence river a unique design of two storeys with the railway running underneath the road was opened',
#  'iq et ox opera for three adult singers six child singers and children s choir',
#  'stunned the fans stopped fighting picked up their hats and coats and exited the building',
#  'pacific media expo did not occur in due to schedule conflicts with ncaa football and the convention s traditional november date',
#  'after gathering information indy and sophia eventually find it in a collection of barnett college',
#  'both him and his wife were known for being wealthy educated kenyans and turned their back on their ethnic community while his brother stayed loyal to clan',
#  'history the locality s name orallo comes from a railway station name assigned by the queensland railways department from november reportedly an aboriginal word meaning shade',
#  'the guild published a list of lecturers willing to speak on subjects',
#  'the term is now considered to be a derogatory slur for vietnamese people',
#  'smith also found holes in the rules system and thought the chracter creation system was fairly cumbersome',
#  'he played for auckland and made the new zealand national rugby league team for three tests against the touring great britain lions side that year',
#  'furthermore it is stated that the awakening of consciousness is the only way to acquiring gnosis and achieve a true and radical change by removing the spurious psychological aggregates that cause unnecessary suffering',
#  'club career real sociedad born in olaberria gipuzkoa basque country begiristain began his professional career with real sociedad in at the age of being immediately cast into the first team s setup',
#  'of the rest of the population there were members of an orthodox church or about',
#  'the top floor is the vvip floor with master bedroom and suite the second floor has four executive suites and the ground floor has a reception hall two bedrooms and a large waiting lounge',
#  'it is one of the most prominent army schools ranking among the top three army public schools and top ten in india',
#  'some team games with imperfect information on a finite board but with unlimited time are undecidable',
#  'he was the scion of an amsterdam patrician family that counted many burgemeesters like cornelis hooft and the poet and statesman pieter corneliszoon hooft',
#  'fitzball finding that his text had been presented in german without his consent the playbill naming herr fixball as the english author was obliged to accept the situation but it seems to have ended his association with hatton',
#  'external links profile yahoo sports category births category living people category sportspeople from luanda category angolan men s basketball players category basketball players at the summer olympics category point guards category olympic basketball players of angola category atlético sport aviação basketball players category c',
#  'today the line is generally quiet except for the school train on a morning and early evening',
#  'li was quoted in a taiwanese newspaper interview i m a musician',
#  'the name apparently played on the fate that frequently befell the authors and readers of forbidden and heretical works i',
#  'new this season is a spa room complete with a massage table two person sauna and lounge',
#  'following the trail they found geneva s body behind a fodder stock which had been partly covered',
#  'see also list of army barracks in hong kong references references the country boy who died for hong kong category kowloon tsai category military of hong kong under british rule category barracks in hong kong',
#  'furthermore the social structure of one s community is often reflected through speech and language behavior',
#  'onemount onemount is a complex cultural facility that has nine floors above ground and two underground',
#  'the alleged assailant began fighting with the officer and wrested the officers service pistol away from him',
#  'full text from google books an history of early opinions concerning jesus christ vol',
#  'in he founded in werther german company werther’sche zuckerwarenfabrik',
#  'details of and episodes at the private home the living room is dominated by a grand piano which aino aalto is known to have enjoyed playing',
#  'plastic extrusion machine to plastic extrusion machine plastic extruder is usually called the host and its follow up equipments are called the plastic auxiliary equipments',
#  'farms cocoa crop outputs struggle to match the increasing demand for chocolate',
#  'she was the first and only woman to rule over delhi',
#  'races were run to a maximum four hour time limit to prevent the indefinite suspension of a race',
#  'phoenicia university pu is a private institution of higher education with its main campus located in daoudiye the district of zahrani south governorate of lebanon a minute drive from beirut international airport',
#  'during the choir s performance at the ceremony tess notices that her beautiful divorcée mother louise rayton morgan isn t there',
#  'terns are a group of generally medium to large seabirds typically with grey or white plumage often with black markings on the head',
#  'rb is mono phosphorylated during early to mid cyclin d opposing the idea that its activity gradually increases',
#  'september – at least nine people are killed as a roof collapses in a mosque in the low income neighbourhood of daroghawala in lahore',
#  'it is unclear whether he did so on his own initiative or at the request of another crime family',
#  'gunter was also best man for ramsey at his wedding',
#  'the nrcse refers to its members as nebraskans of various religious faiths who respect both science and theology',
#  'goodstein – american publisher and lgbt activist eban goodstein born american economist judith r',
#  'binhai park binhai park is named after binhai road a main road which is its southern border',
#  'david watts was a british teacher and amateur sound recordist',
#  'the method of entry moe facility is a suite of facilities to allow the tactical training of method of entry techniques',
#  'another player going nowhere is qpr striker les ferdinand who has been subject to transfer speculation for months',
#  'with his victory at the london marathon in april of romanchuk also won the world para athletics marathon championships title',
#  'at least catholic bishops operate independently of official sanction and some are under surveillance house arrest detention or have disappeared',
#  'the green tree facility provides and stores digitally and in microfilm aperture cards over maps of abandoned mines',
#  'after deeming the session a failure due to naoko s skepticism a meteor shower descends on japan with the largest crashing in mount kurodake',
#  'singh joined the indian foreign service in after completing his master s degree in economics from delhi university and teaching at the university for two years',
#  'first it may not have sufficient capital to prudently retain all of the business that it can sell',
#  'while exploring the royal palace blair and her roommates happen upon a portrait of a young queen isabella and note her striking resemblance to blair',
#  'approximately came from the top ten countries and an overlapping came from the fourteen current opec members in the table below',
#  'in japan today the system of counting years from the reign of emperor jimmu has been officially abandoned',
#  'in the medal games canada defeated sweden – to claim its second consecutive gold medal while the americans beat finland – to win the bronze',
#  'kyriacos kerry tsolakis born january in agros is a cypriot architect and politician',
#  'the review noted on the other hand some on screen elements that make it tough to play on inch iphones',
#  'the ship had a cruising range of at a speed of',
#  'these conditions required him to carry an oxygen tank wherever he went',
#  'on september the band backed danny saucedo at the aftonbladet music gala rockbjörnen',
#  'after college king began working for harper’s weekly as an associate editor',
#  'recent history regeneration there have been several regeneration projects in the area starting in the after the opening of the thames barrier',
#  'following the exposition he became president of the newly formed chicago civic federation which sought to reform city governance',
#  'references category digital signal processing',
#  'the music during the commercial featuring the oboe of bach s brandenburg concerto no',
#  'carolina panthers on december williams was signed to the carolina panthers practice squad',
#  'the song went onto become an underground hit following its signing to ultra records and a high profile remix from agoria',
#  'by time and many fires had left the crumbling building useless and the state sold the property to a private owner',
#  'all seats in the assembly were up for election',
#  'people migrated from tamil nadu to this area when the madurai king thirumalainaicker was defeated by tippu sultan in the eighteenth century ce',
#  'the black death world war ii which may cause great distress but also eustress in the form of hardiness coping and fostering a sense of community',
#  'gameplay nba jam is a on basketball game with a unique art style',
#  'david dato magradze born june is a georgian poet and politician',
#  'it is located on a private area of land on the tennessee river',
#  'there is a landing fee for non based aircraft and non based flight school aircraft must obtain written prior permission',
#  'owing to more than dozen grade separators flyovers the road is almost signal free',
#  'the louisiana–monroe warhawks football team represented the university of louisiana at monroe in the ncaa division i fbs football season',
#  'database servers have to be accessible to user on the same or any other computer',
#  'hairs match and as a result super crazy the last man left in the cage was forced to have his head shaved bald',
#  'the team is composed mainly of players who are in their first year of professional baseball either as draftees or non drafted free agents from the united states canada dominican republic venezuela and other countries',
#  'cm the left hand edge is very dark brown and can be read with the assistance of infrared photography',
#  'ptt culture ptt culture and lingo fifth floor — the fifth comment of a post which is often regarded as words of wisdom also fifth floor please rate this post villager — refers to ptt users',
#  'in the early days this endeavor involved dispute and original research as the tools to precisely map every square inch of the country were just beginning to find widespread use and this was part of the charm',
#  'the same panel also passed a set of gui',
#  'the saff u championship is the edition of the saff u championship hosted by nepal from to july at dasarath stadium and army ground',
#  'the second french military mission also helped reorganize the imperial japanese army and establish the first draft law january',
#  'geography according to the united states census bureau madison township covers an area of of this',
#  'schramm says that the names of at least eight towns in the same region likewise suggest the one time presence of a romance speaking population in their vicinity',
#  'they have had their portrait painted by renowned fine artist kehinde wiley',
#  '… it is believed to be the nation s largest child molestation prosecution ever directed at a single person in terms of number of victims and number of alleged criminal acts',
#  'second round the top league team ranked played off against the winner of the teams ranked and and the top league team ranked played off against the winner of the teams ranked and',
#  'luis segura is an argentinian football administrator and a member of the fifa council the main decision making body of fifa the governing body of association football',
#  'in november charmaine dragun a year old newsreader who worked for news first jumped from the gap after battling depression and anorexia',
#  'it is the mosque built by the government within the city limits',
#  'no reason was given him for the arrest though a commander a captain yihye said she had flouted an earlier army order to leave her home',
#  'the introduction of jade hedy lucy gape was revealed to leave these characters in danger with two of the characters involved set to die during the series',
#  'due to the heavy airplay that it received blige s version peaked at number thirteen on the hot r b songs chart and number twenty two on the us billboard hot',
#  'music bell s song one stringed harp includes the lyric like wile e',
#  'it explores philosophical thoughts about the mind the human existence and god in connection with natural theology',
#  'in the mekong delta reliable information indicated that at least ethnic khmer monks were derobed and subjected to disciplinary action including detention and pagoda arrest for participation in a protest or protests against the authorities in early',
#  'in the band released their first studio album frizzle fry and released singles for john the fisherman and too many puppies',
#  'in january her seventh single kimi iro signal was used as opening theme to saekano how to raise a boring girlfriend',
#  'on march of that year the new york daily news disclosed that in he and national league umpire frank pulli had associated with florida based bookmakers who were known drug dealers',
#  'ibn zuhr performed the first experimental tracheotomy on a goat',
#  'non league football adarabioyo made his first appearance in senior football for macclesfield town coming off the bench against aldershot town having signed for them on september',
#  'ben dunkelman says that the brigade had a mainly diversionary role in operation hiram',
#  'professional boxing record see also list of current nabf champions references external links category boxers from quintana roo category people from cozumel category super bantamweight boxers category births category living people category mexican male boxers',
#  'this causes several problems including compatibility when multi booting with operating systems that set the clock to utc and double adjusting the clock when multi booting different windows versions such as with a rescue boot disk',
#  'she was the first vietnamese women footballer playing abroad',
#  'willard buddy willard s father and mrs',
#  'further evidence has demonstrated a significant reduction in levels of insomnia',
#  'philosophical consequences the discovery of hyperbolic geometry had important philosophical consequences',
#  'the luxembourg national rugby union team is a minor team and is ranked as a third tier nation',
#  'however the cryptokitty art is not on the blockchain and is instead owned by axiom zen',
#  'he would be diagnosed with cancer in january which would kill him by december',
#  'it used the bombing s devastation and massacre of civilians as recruitment propaganda and as an excuse for its brutal radical policies and its purge of moderate communists and sihanoukists',
#  'the game ended in april',
#  'in he collaborated with chochoco has no horse to set the snake people of weahwewa wolf dog s band free from the klamath reservation where they were starving under the mismanagement of indian agent william v',
#  'the parish of st augustine s was formed from that of st john s padiham in october with fr notterdam as the first parish priest',
#  'as the gustatory system senses both harmful and beneficial things all basic taste modalities are classified as either aversive or appetitive depending upon the effect the things they sense have on our bodies',
#  'for example if a married woman committed adultery her father had the legal right to kill her whereas her husband was required to divorce her',
#  'reception billboard wrote the arrangements by glenn osser are lush and warm and mathis has never been in better voice',
#  'it will not need huge quantities of rocket fuel it will be bred and programmed to eat ice and hydrocarbons found in the rings surrounding the outer planets',
#  'he also netted the third and final goal',
#  'it is set in the arrowverse sharing continuity with the other television series of the universe and is a spin off of arrow',
#  'by this phase in his career aderca was establishing his reputation as a magazine columnist and theater chronicler one particularly interested in the development of modernism in weimar germany and in italy',
#  'the team s representative is often determined by a challenge match in which the top two wrestlers at that weight compete for the right to participate in the varsity match',
#  'interactions have been observed in eurasia between wolves and golden jackals the latter s numbers being comparatively small in areas with high wolf densities',
#  'life he studied medicine in prague and vienna and from until was a professor of anatomy physiology and ophthalmology at the university of prague',
#  'the country s great economic polarization has stimulated criminal activity in the lower socioeconomic strata which include the majority of the country s population',
#  'the heart of the town contains a central office staffed only part time a single restaurant l escargot and one hotel',
#  'in there oswald and his girlfriend kitty are playing a piano together',
#  'after a rapid low level descent the intruder was seen to pull up and likely stalled resulting in a crash on a hill at ft msl near a village surrounded by syrian anti aircraft artillery positions',
#  'in house television program production was limited to local news and community interest programs this programming ceased with the closing of the local newsroom',
#  'also catering to the tourists are a burgeoning number of restaurants and shops spread around the coastal area',
#  'it is located in northeast corner of island near the garbage collecting area close to beach',
#  '| see also list of onroerend erfgoed in limburg belgium hamont achel references flemish organization for immovable heritage de inventaris van het bouwkundig erfgoed hamont achel',
#  'also mir is downregulated in myocardial infarcted tissue compared to healthy heart tissue',
#  'prior to his execution for murdering prince rwagasore jean kageorgis explicitly accused harroy and régnier of responsibility in the murder stating ce crime fut perpétré par la tutelle m',
#  'kymulga mill continues to operate to this day though under electricity still making corn meal with its huge millstones',
#  'it is an important nesting site for migratory birds and the endangered loggerhead and green sea turtle and the shelter of the arabian spiny mouse and many other important creatures including wall lizards common pipistrelle and european badger',
#  'a historical essay wydawnictwo ars print production warszawa external links polska podziemna akcja n category armia krajowa category psychological warfare category black propaganda category polish underground press in world war ii category secret printing',
#  'henry george keller april – august was an american artist who led a generation of ohio watercolor painters of the cleveland school',
#  'ellis language acquisition just zipf’s right along paper given at the université du québec à montréal january',
#  'although many studies and one meta analysis have shown that fertility moderated shifts in attraction to facial and bodily symmetry occur robustly other reviews have concluded that the effect is small or non existent',
#  'the game today is played on a field roughly about one hundred yards with a tall cylindrical pole or set of poles at each end of the field for goals',
#  'some members have also chosen to post their entries entirely with pictures and photos',
#  'one of the dining rooms is located in the western wing off of the hallway and was used primarily used by the family for smaller meals like breakfast or tea',
#  'at the commonwealth games she won silver in the metre freestyle and bronze in the × m freestyle relay events',
#  'it is a grade ii listed building',
#  'a mother goddess is a goddess who represents or is a personification of motherhood',
#  'coat of arms shield gules on a bend between in dexter chief a sea lion holding in dexter paw a sword and in sinister base a bar dancette couped or five fleurs de lis paleways azure',
#  'one of julia s students edison bryce robinson orders flowers from reed to be sent to his teacher',
#  'he is the winningest boys basketball coach in the history of the school with more than wins since he took the reins in',
#  'the bungalows in rogers park manor were built by several different developers and architects which led to variation in the size and shape of the homes despite their similar designs',
#  'in hay moved to london with partner andrew fagan ex lead singer of rock band the mockers',
#  'authorship claim chicago area musician james pobiega who goes by the stage name little howlin wolf has claimed that he wrote bad to the bone and that thorogood stole it from him',
#  'for the european market where it was marketed as nissan terrano ii and also supplied under an oem agreement to ford europe for sale as the ford maverick on the continent and in the united kingdom',
#  'members gaius lentidius augustalis found on a sepulchral tablet in a house at pisaurum',
#  'the phrase also serves as the motto of',
#  'players category english football league players category north american soccer league – players category english expatriate sportspeople in the united states category expatriate soccer players in the united states category english expatriate footballers',
#  'it was a small group of jesuits led by matteo ricci who being able both to travel throughout china and to read learned about the country from chinese books and from conversation with people of all walks of life',
#  'notable people miroslav benka screenwriter director designer and university pedagogue mira brtka academic paintar sculptor theatre and film director ján čajak jan čajak writer ján čajak ml',
#  'in october it published a provisory list of songs shortlisted to compete in the two semi finals of the contest',
#  'com tsn biography category births category living people category canadian television sportscasters category people from athabasca alberta category ryerson university alumni category fox sports people',
#  'atr has an obligate checkpoint partner atr interacting protein atrip and together these two proteins are responsive to stretches of single stranded dna that are coated by replication protein a rpa',
#  'godot in house open source mit licensed game development software',
#  'the lower floor comprised a vaulted entrance tunnel running into the older castle courtyard',
#  'it was realized that the excellent long term accuracy of nonrelativistic boris algorithm is due to the fact it conserves phase space volume even though it is not symplectic',
#  'they were arrested by the hong kong independent commission against corruption cautioned against conspiracy to commit theft and sentenced to hours of community service',
#  'notable alumni below is a list of not',
#  'political action standing in opposition to zionist groups and jewish organizations such as the centralverein deutscher staatsbürger jüdischen glaubens central association of german citizens of jewish faith naumann advocated total assimilation as an answer to antisemitism',
#  'during construction the new york central railroad moved bridge l from the rondout creek near kingston to carry its mahopac branch across a section of the reservoir near goldens bridge',
#  'cal crutchlow completed the podium on his return after missing the final two races of due to injury',
#  'neugebauer austrian born american mathematician and historian of science b',
#  'villanova entered the game having lost three in a row while the hawks had won nine straight',
#  'her mother s faith her women s meetings and her brother s infant death may have all inspired sumner decades later to begin the mothers union',
#  'hessler and sanders were able to document the large diversity of the macrofauna over a broad area with their device',
#  'he was a friend of cremona and ranzoni and with them assumed a renewed anti academist position and shared their common luministic research',
#  'in club swimming in australasia the short course season lasts from april to september and the long course season from october to march with open water in the summer months',
#  'the midnight express would lose the awa southern tag team title to bobby eaton and sweet brown sugar before returning to secw in the spring of',
#  'we wrote this song as a thank you to those who have supported us over the past years',
#  'rowling has stated that hermione resembles herself as a young girl with her insecurity and fear of failure',
#  'lakoff and harry seidman of overbrook hills pennsylvania who registered their business in philadelphia as spatini co',
#  'he played the title role in the trouble with harry an episode of the television series twice in a lifetime directed by david winning',
#  'thießen is a village and a former municipality in the district of wittenberg saxony anhalt germany',
#  'additionally it is used as the location throughout the year for spectator events featuring monster trucks motorcycle acrobatics and other shows',
#  'there is little other documentation on the use of the island during the dutch colonial period other than the fact that it has remained in public ownership since van twiller left new netherland',
#  'downstream is a british crime film directed by giuseppe guarino and starring chili bouchier harold huth and marie ault',
#  'theo spielberg of spinner described the song as razor sharp and electro roughed',
#  'shortly after günterstal the small team at the huntsman s well were met with superior government forces',
#  'godfinger maze finger rolando a game similar to loco roco for the psp which involves using the iphone s accelerometer to move your rolandos around to beat missions',
#  'the knockout experiments done in chicken models suggest radical fringe plays an integral role in wing development',
#  'frame up dinozzo is a flirt and has a fondness for playing pranks on his co workers sometimes with little respect for their boundaries',
#  'he made his debut in the serie a on october playing a little less than seven minutes per game over the rest of the season',
#  'he also had an uncredited role in the film scary movie before playing papa jenkins in the comedy film welcome home roscoe jenkins',
#  'in the case of rule each cell s new value is the exclusive or of the two neighboring values',
#  'because of this electro is confronted by wolverine in an alley where after a battle he leaves dillon beaten and unconscious',
#  'mike is then transformed back into his year old self and happily reunites with scarlet saying that she was the best decision he ever made',
#  'ultrasound is effective at detecting joint effusions',
#  'sanjay alung chhattisgarh ki janjaatiyaa tribes aur jatiyaa castes mansi publication external links category districts of chhattisgarh category bastar district category establishments in india category districts of india',
#  'she challenged the right of the father to have sole control over his children and pointed out the injustice of the law as regards the property rights of married women',
#  'they also charge the warp drive and engage the ship into warp speed',
#  'after retiring from football he was convicted of various criminal offences including keeping a brothel and was jailed for three years for financing a plot to counterfeit gold coins',
#  'administration the student government is administered by five full time undergraduate executives along with several full and part time staff members',
#  'draper james has been featured in people vanity fair oprah magazine and coveteur among others and the signature totes y all bag was seen in the gilmore girls revival',
#  'he was promoted as an associate professor in and as a professor in and in he became the head of the department of electrical engineering a post he held till',
#  'the quarterstaff match with little john being decided with rock paper scissors with the band s lead singer tobias sammet taking the role of robin hood and the other band members as unnamed merry men',
#  'by that point many of the early turnpikes were going broke and reverting to public ownership and maintenance',
#  'also in of gravel road was constructed from the nanjemoy end',
#  'in the miocene pliocene a major lava plateau was formed on the eastern end of the taryat depression with a surface area of',
#  'at king of the ring on june they successfully defended the title against yokozuna and crush',
#  'both were carried by the current clear of the raft which by a great error of judgment as it now appeared on the part of the builders had only been made to protect the floating portion of the bridge',
#  'candidates one candidate was removed from the ballot due to insufficient nominating petition signatures yessenia carreón community activist endorsements results ward second term incumbent matthew o shea won reelection defeating david dewar his sole challenger on the ballot',
#  'honours olympiacos greek super league – – – greek football cup – references external links official website category births category living people category brazilian footballers category greek people of brazilian descent category brazilian expatriate footballers category santos fc players category ael limassol players category olympiacos f',
#  'the student union at teesside university cancelled a screening of it in',
#  'in the book rose offers a postmodernist feminist interpretation of plath s work and criticises plath s husband ted hughes and other editors of plath s writing',
#  'terminology the term content control is used on occasion by cnn playboy magazine the san francisco chronicle and the new york times',
#  'haiku is a japanese poem of seventeen syllables in three lines of five seven and five traditionally evoking images of the natural world',
#  'he and tobie leave the house as his voice on the radio show leads into the song misty',
#  'jerome in and enlarged with the addition of a second building moved onto the property and set at a degree angle to the original building',
#  'in he was elected judge of the circuit court for the ninth judicial district of indiana where he remained for thirteen years',
#  'its name refers to the silva major the great forest that then occupied the whole region known as the vignoble de l entre deux mers vineyard between two seas which was a gift to gerald from duke william viii of aquitaine',
#  'one remarkable example is that of a lex regia that forbids the inhumation of a pregnant woman before delivery since it is believed that so doing would mean killing a life',
#  'place was a tie between byanca y malessa and katy',
#  'criticized the review as inaccurate and misleading',
#  'her involvement in railways extended beyond parliamentary responsibilities and in december she presented the coveted national railway heritage award plaque to a swanage railway team of volunteers for the installation of a historic footbridge at corfe castle railway station',
#  'at the first hoosier salon merit prizes were awarded to steele for winter morning first snow judged best picture and painted by a man more than sixty years of age',
#  'on april barely a week before the election pellegrini declared a state of siege and arrested alem and other opposition leaders resulting in the overwhelming election of pan candidate luis sáenz peña',
#  'complicating matters was the desire by the cw s parent companies cbs and warner bros',
#  'course cowhouse beck and bonfield gill meet at the end of lund ridge at coning s birks in hag wood to form the riccal',
#  'the village website gives several theories for the origins of the name',
#  'judaism in some synagogues the president and honorary officers may wear a top hat on shabbat or the great festivals',
#  'category french navy ship names',
#  'the longest race ever run at the kentish circuit took place on may this being the guards consisting of two mile races for production saloon cars',
#  'the story still takes place in kraków during the reign of king krakus the city s legendary founder and a calf s skin filled with sulfur was used as bait to the dragon',
#  'accounting for inflation changes in personal wealth and population changes it is estimated diane would have caused billion in damage in or the highest for a united states hurricane',
#  'it was caused by the death of the constituency s sitting conservative member of parliament frederick alers hankey who had held the seat since the general election',
#  'today only the monastery church survives from what was a significantly more extensive complex of buildings in the century',
#  'the choral department was developed under ann s',
#  'classical vocal music that belongs to the traditional arab music of al andalus muslim spain ad',
#  'the lotteries act except section was repealed by section of and the schedule to the statute law revision act',
#  'members of the organization and its publication systematic biology formally known as systematic zoology work on the theory principles methodology and practice of systematics involving living and fossil organisms',
#  'the old railway from kilmarnock to irvine branching off at busbie junction crosshouse station has become a tarmaced cyclepath maintained by sustrans',
#  'williams late singer the plasmatics communities and locations in the town of webster avalon estates – a neighborhood development located off phillips rd',
#  'the site was probably an open camp and flint working site',
#  'also see list for the previous and next year',
#  'to see more light contains eleven tracks with a total running time of fifty two minutes',
#  'their stay in the top flight only lasted a single season however as the club finished bottom in – and dropped back down to the first division',
#  'in the – season nicholls was voted player of the year by luton supporters as the club won the league one championship',
#  'åkerman was then head of the air defense detail of the general staff from to and artillery battery commander of svea artillery regiment from to',
#  'along with multi purpose buildings that were mostly used for housing',
#  'bus the interchange has a large bus station with routes covering most of south yorkshire but especially the local sheffield and rotherham area',
#  'for example many women are found to be more critical in addressing conflict',
#  'armstrong argues that slash s personal growth can be perceived through his relationships with his family and community lutz',
#  'located on historic whiskey row in prescott the saloon was opened in and rebuilt in after a disastrous fire swept the district in',
#  'there are often memorial wreaths on the platform at the head of the eastbound tracks of the station on the anniversaries of the incident',
#  'he then required that money collected be place in the box on a daily basis together will all associated receipts and accounting logs',
#  'references category births category living people category athletes track and field at the summer olympics category sierra leonean male sprinters category olympic athletes of sierra leone category place of birth missing living people',
#  'premier ernest manning called a snap election in to gain a new mandate',
#  'mar elias university was established in claiming to be the first arab university in israel though it is not officially holding a university status',
#  'this performance of homeward bound was later included on the charity album nobody s child romanian angel appeal and it is also found on the bonus dvd accompanying simon s compilation the essential paul simon',
#  'hansen attended the founding convention for the ccf in and later served on its provincial council',
#  'he was ordained a priest by cardinal latino malabranca orsini on may and was consecrated a bishop and crowned pope on trinity sunday may in st',
#  'education and early career educated at the independent day schools rokeby school and king s college school in wimbledon south london urban continued his education at the london school of economics',
#  'cronenberg while amused by the idea rejects it for being too self referential he cites a sequence in his film videodrome in which a character pulls a handgun from a slit in his stomach',
#  'nail railovich yakupov born october is a russian professional ice hockey forward who is currently playing with ska saint petersburg in the kontinental hockey league khl',
#  '” this show also included the work of gary baseman and joe coleman',
#  'he later signed a recording contract with arista records but was dropped when president and chief executive officer ceo l',
#  'potamomya is an extinct genus of bivalve mollusc from the late eocene of europe',
#  'chithra have recorded the song',
#  'in new zealand the film earned on its opening weekend',
#  'the volkswagen group c platform is a series of extended midsize automobile platforms from the german automotive concern volkswagen group',
#  'footage is shown from the in car cameras fixed cameras on police cars and film crews with the police officers',
#  'on april she participated in a charity single for the people of mexico titled resistiré méxico',
#  'he was born in columbia south carolina grew up in mount willing the family cotton plantation in edgefield county now saluda county and went to work in the family s columbia based insurance business e',
#  'he continued that day and stated can',
#  'in some locations particularly the united states the word connotes a rental unit owned by the building owner and is not typically used for a condominium',
#  'the uprising led to damage to the officer s property including his garage door and truck',
#  'this obviously would entail the making and promulgation of such regulation by following the procedure as provided for in section of the promotion of administrative justice act',
#  'bedrock in geology is the lithified rock that lies under loose softer material called regolith within the surface of the earth s crust or other terrestrial planets',
#  'the most voted housemates entered the house on day while fede was the housemate with fewest votes on day and sofía was the most voted and became an official housemate on day therefore candela was re evicted',
#  'his seasonal performance named him a usl rookie of the year finalist',
#  'such information and knowledge in promotion of the public interest',
#  'because of the quality of their craftsmanship original shaker furniture is costly',
#  'the baseline sum ld will be used as reference by which to characterize the objective tumor response',
#  'zbigniew unable to sleep joins him and the brothers admit to each other that they have fallen in love with hanna and jadwiga despite their vows',
#  'the cycle nearby dnieper which is not a landscape in the traditional sense but a symphony of expression and color',
#  'son of former nepalese prime minister b p koirala and father of actress manisha koirala salman khurshid ex minister of external affairs government of india new delhi abhayanand d',
#  'it was promoted to branch status and moved into a large new building at union avenue in',
#  'on october the board of directors of the baptist general convention of oklahoma voted to ban srs at baptist medical center',
#  'through her relationship with antheil she met the american artist man ray who photographed her several times the first being in',
#  'the indoor athletic court commonly known as the tin can or the indoor athletic center was the home of north carolina tar heels men s basketball team from january through february across fifteen seasons',
#  'but despite this growth in the endowment was still only half the size it needed to be',
#  'this especially showed during the sylvania at loudon when dale jarrett had stopped in the middle of the track at the start finish line while the drivers were racing back to the flag',
#  'sexual rights is not the same as civil rights and human rights',
#  'the required beliefs include belief in a supreme being and belief in a future state of rewards and punishments',
#  'after an hour of intense fighting by the main attack began to falter and the north vietnamese subsequently withdrew into a rubber plantation to the north east carrying many of their dead and wounded',
#  'transfer given the trifocal tensor of three views and a pair of matched points in two views it is possible to determine the location of the point in the third view without any further information',
#  'during this period he was briefly a villain paying off gambling debts to a criminal named mad hat harry',
#  'ely bernays son of berman bernays edward bernays – the father of public relations son of ely bernays and anna freud nephew of sigmund freud husband of doris fleischman father of anne bernays',
#  'their work changed the entire policy of transplantation in china',
#  'phylogeny fernando novas defined herrerasauridae as herrerasaurus staurikosaurus and their most recent common ancestor',
#  'this leads to him meeting natalie price lucy speed who runs romantic relations',
#  'in the next stretch the columbia slough flows by portland meadows horse racing track on the right and crosses under interstate at about rm rk',
#  'oliver bond circa – was an irish merchant and revolutionary one of the leaders of the society of united irishmen',
#  'the group also corresponded with the iron and metal founders and their labourers of lower austria a swiss union and three other australian unions but by the end of it had ceased to operate',
#  'the quadroon balls were social events designed to encourage mixed race women to form liaisons with wealthy white men through a system of concubinage known as plaçage',
#  'after falling ill in late september fanta s father traveled to his native village of sokodougou kilometres away where he died on october',
#  'it is used as a starter and also has medicinal uses for cough and throat ailments also tambadaa rassa which is red soup have same benefits as pandhra rassa but instead of coconut milk is made up of red chilli',
#  'crassisubiculata is in the form of a small thin crust up to μm thick with a creamy yellow colour on the surface of the woody substrate',
#  'he has an enormous collection of swords many of which are crafted by himself',
#  'an inscription already illegible by the late century recorded that the church was founded by james in marking the christian jubilee year',
#  'career club career jones was born in trefonen shropshire to lot jones a coal miner and labourer',
#  'solid polymer type bearings are limited by the injection molding process',
#  'the investigation gradually reveals details of the murder that had not been discovered at that time using more advanced scientific techniques',
#  '°e are compatible with the satcr system',
#  'this meant that when the divisions went into the front line they could only cover a brigade area',
#  'at the crew of ross revenge made contact with the ramsgate lifeboat which had also been sent by the dover coast guard',
#  'with jools holland and a few performances of stone by stone as cerys matthews was being treated for alcohol addiction and nervous exhaustion',
#  'native americans used the seeds for food grinding them into a flour',
#  'interpretation the term scheibe disk stands for the sun and the term hut hat for protection thereby protection by the sun',
#  'once she arrived at the capital she made an appeal on behalf of her father to emperor wen himself instead of going to any of the officials',
#  'however some in the netherlands particularly those from regions outside holland may find it undesirable or misrepresentative to use the term for the whole country',
#  'the election was the second of two held in texas during the american civil war',
#  'each missile was housed in an underground silo and was driven into the air before launch by a gas powered piston',
#  'july july – the opening of neihu line of taipei metro',
#  'the tornado caused extensive damage to springfield s connecticut river walk park deforesting much of the park s formerly lush tree canopy and removing large sections of its wrought iron fences',
#  'robert bagg born new jersey is an american poet and translator',
#  'some people said that the port was constructed to the beach due to some conservative people think swimming and walking with swimsuit and shorts is disturbing for local peoples',
#  'the presence of the cross caused this mineral be used as a gem',
#  'it is also suggested that males have super black feathers which help to create an optical illusion during courtship that emphasizes the iridescent patches they are adjacent to',
#  'foudroyant was scuttled again by the germans as a blockship in toulon in august while bison sank after a collision with a submarine in june',
#  'some light rail systems were updated from streetcar use and thus feature a combination of high platform stops and curbside tram stops',
#  'the baron’s young son sigi goes missing on the day of the harvest festival and is found the following morning in the sawmill bound and badly caned',
#  'like all gray horses they have black skin dark eyes and as adult horses a white hair coat',
#  'the church has had discussions with various other churches particularly with the protestant church methodists seventh day adventist church anglican church and the roman catholic church',
#  '– dominick dunne american journalist and author d',
#  'asme v v provides a detailed methodology for validating computational simulations as applied to fluid dynamics and heat transfer',
#  'recordings like this one disheartened the jazz world but made him a household name and a staple on am radio',
#  'constructed between and it was the largest mosque in the world upon construction',
# ...
#  'a third nurse was temporarly employed for the same reason',
#  'hawkins rushes to his side where oleg says a final few words about the movie that is still being taped just before he dies',
#  'prior to september the chiefs always wore white pants with their red jerseys',
#  'the collection includes bloch s hugo award winning story that hell bound train',
#  'while coaching at cnec he led the broncos to a – record a cif central valley championship in both division i and division ii football and secured second place in the central section in',
#  'when the radarman rating was split up into os electronics technician et and electronic warfare technician ew ratings the original rd rating badge continued to be used by the operations specialist',
#  'in april he was named the nba defensive player of the year becoming the first player in grizzlies history to earn the honor',
#  'but no commodity will bear three pence or will bear a penny when the general feelings of men are irritated and two millions of people are resolved not to pay',
#  'a correspondent from yank the army weekly described the scene four of the twelve lcprs had been damaged',
#  'the state highway along somerset avenue was widened from main street to md around',
#  'he would go on to perform at the palace of versailles in front of royalty',
#  'democrat pete aguilar who has represented the district since won reelection',
#  'liberal party leader lars sponheim said during a televised debate in early that the ruling red green coalition government would face the same problems as kjell magne bondevik s second coalition government',
#  'among some of his many voice over credits are the animated features spider man into the spider verse bilal a new breed of hero penguins of madagascar mr',
#  'in she was part of the north korean team which won the bronze medal in the olympic tournament',
#  'cooling and dehumidifying the high outdoor air quantities in the summer and humidifying and heating the air in the winter is an energy intensive proposition',
#  'on december a granite pedestal was constructed with an epitaph written by the editor of venezia tridentina magazine',
#  'personal health could be self defined with the recognition of their own symptoms and determining if they need to seek treatment of medical professionals',
#  'the homeowner vacancy rate was',
#  'falciparum exports a membrane network into the red blood cell cytoplasm and also inserts several of its own proteins into the host membrane including its own v atpase',
#  'in the spring needle shaped ascospores are released from overwintering apothecia in fallen leaf debris',
#  'they had to appoint a district liaison who was paid by pde to serve as the conduit of all information between the district and the department and its agents along with submitting orders and distributing supplies to implementing teachers',
#  'or = olympic record tr = track record references category women s speed skating at the winter olympics',
#  'dyma r dystiolaeth is the debut album by the welsh band tystion released on fit cassette',
#  'during the ensuing fight aykroyd plants a homing beacon on mayor west s leg',
#  'pacific northwest arose over the spread of a relatively new fungal disease called annosus root rot heterobasidion annosum or fomes annosus',
#  'on the boundary with barry county at avenue brouard post office opened on march',
#  'depth = depth transpositiontables',
#  'hardtop coupes featured a semi fastback flowing roofline with a long hood and short deck mimicking the camaro which itself was an answer to the ford mustang',
#  'lekoloane joined athlete ally a sports focused lgbtq advocacy organization',
#  'among the companies targeted by sherborne have been electra private equity and investment company foreign colonial investment trust',
#  'there is no formal landscaping within the cemetery proper and the graves are laid out in an irregular fashion',
#  'it also peaked at on the billboard hot making it a minor crossover hit and is vassar s highest peaking song on the chart',
#  'however he remained such a dominant defensive player that opposing coaches regularly assigned two players to block him',
#  'the consolidation initially cut the combined rental car bus fleet in half from buses to',
#  'meanwhile terentius restored sauromaces to the throne of iberia but the king appointed by the persians aspacures retained control of the eastern part of that kingdom',
#  'her grandfather george murnaghan was a well known nationalist politician in northern ireland',
#  'the fans response refined the contest down to three finalists—reno fc reno united and reno —with the winner being reno a nod to the founding year of the city of reno',
#  'the unusual and distinctive organ part was played by petty on a hammond solovox model j',
#  'students take general curriculum courses along with specialized courses relevant to the department',
#  'the plot angle and height of the view are continuously transformed the spatial height is changed and the introverted and open spaces are being mutually altered by the walking direction as well',
#  'the largest colonies of cliff breeding seabirds are mainly located on the bird cliffs of the biggest island storstappen and between june and august visitors are not allowed to set foot on this island',
#  'yontz seka dated comedian sam kinison in the mid',
#  'these songs were performed to calypso rhythms and later the new reggae beat coming out of jamaica',
#  'sheila awarded the dickin medal for conspicuous gallantry or devotion to duty while serving in military conflict',
#  'following a game in seattle in early gill suffered a heart attack in his hotel room while with his wife',
#  'he founded a seminary and an orphan asylum as well each with ample buildings and endowments',
#  'the airplane was lightly damaged but all ten occupants the pilot and nine passengers escaped unhurt',
#  '– eric returns to salem in november as a priest at st',
#  'inch android based tablet computer produced and marketed by samsung electronics',
#  'different amounts of these male or fema',
#  'in richard adams s book watership down the chapter entitled the raid begins with this epigraph quoted from renault s book he went consenting or else he was no king',
#  'references works cited krak category conflicts in category century in the mamluk sultanate cairo krak krak category period post ninth crusade',
#  'in addition to transfer programs the college offers a broad range of degrees and certificates in allied health high tech business and career tech areas',
#  'however the basic concept is that the burnishing rod is held against the edge of the scraper at a slight angle and drawn along the edge a number of times until the burr is created',
#  'he is a member of the ascap performing rights organization as both a writer and publisher',
#  'likewise the first season of the show featured a recurring more dramatic storyline in which the formans were in danger of losing their home due to red s hours being cut back at the auto parts plant where he worked',
#  'tom brislin born keyboardist vocalist songwriter and producer he was inducted in the school s hall of fame in',
#  'janet henry born in february in bristol is a british economist who has served as the global chief economist at hsbc since',
#  'the drawback of laser roughening is the cost of the equipment and tooling',
#  'players category english football league players category deaths from cancer in england category deaths from pancreatic cancer',
#  'a study on the molecular age of the earliest flowering plant lineages is published by salomo et al',
#  'gameplay concept the objective in the game is to lead the character ivy a newly born bird to her lost mother',
#  'carson township is one of twenty townships in fayette county illinois usa',
#  'in she was named the gilbert and ruth whitaker professor of business administration and was presented with the researcher of the year award from the university of michigan’s ross school of business for research excellence',
#  'l sohc engine with four valves per cylinder',
#  'in the late marx began to produce metal lithographed dollhouses with plastic furniture at the same time it began producing service stations',
#  'okada made his first title defense on march defeating tetsuya naito in the main event of njpw s anniversary event',
#  'in a move against ireland the act additionally repealed the ability of ireland in the act to obtain the necessary bond for products shipped to overseas colonies',
#  'the player can open a map screen at any time which tracks the player s current position and also displays the layouts of all rooms visited to that point',
#  'blossius aemilius dracontius of carthage was a christian poet who flourished in the latter part of the century',
#  'the fourth spacewalk was added to allow the crew to coax and retract a stubborn solar panel to fold up accordion style into its box',
#  'design by contract has its roots in work on formal verification formal specification and hoare logic',
#  'there are two main differences in the first line between the greek text given above and the slavonic text given here',
#  'usually eaten when the main meal of the day is taken at lunchtime or high tea',
#  'first wave the first wave of crossgen',
#  'kidd bogart category songs written by redone category billboard dance club songs number one singles category universal republic records singles category usher musician songs category songs written by erika nuri category songs written by david quinones category songs about dancing',
#  'in the classical and light classical fields edition international who s who in music',
#  'while the singer starts reading the book that he had opened earlier the women start to get strange behaviors',
#  'she is hired by bojack s publisher to ghostwrite his memoir having written a biography of bojack s childhood hero secretariat',
#  'shields and rangarajan argue that it is this tie to purpose that make american football plays such a good metaphor',
#  'the first medium to be tested was george valiantine who claimed that in his presence spirits would speak through a trumpet that floated around a darkened room',
#  'the second new statistical account of scotland begins publication under the auspices of the general assembly of the church of scotland',
#  'the slaves were stamped with a hot iron on the forehead a branding which meant that they were brought to the country legally and prevented their kidnapping',
#  'category serbian rebels category serbian folklore category characters in serbian epic poetry category serbian military personnel category serbian soldiers category serbian guerrillas category ottoman serbia category serbia under habsburg rule category serbian culture',
#  'larrea was appointed bishop of the diocese of valladolid in',
#  'career edwards majored in psychology at knoxville college in tennessee and continued his education at northwestern university where he received a master s degree in drama',
#  'she is best known as the author of humayun nama the account of the life of her half brother emperor humayun which she wrote on the request of her nephew emperor akbar',
#  'culture near the edge of kilkenny on kilkenny road is the spanish club of sa catering to the spanish of south australia',
#  '– sergejs žoltoks latvian ice hockey player b',
#  'i spouting and down pipe',
#  'he owned a cinema hall named bharat talkies at itarsi which he built in year',
#  'historian richard white describes cleveland as the andrew johnson of the in that cleveland s temperament and conservative policies were unsuited to the crisis confronting the nation',
#  'coming online in a second water residue treatment plant will treat s',
#  'phase out regulations effectively ban the manufacture importation or sale of incandescent light bulbs for general lighting',
#  'prior to the first world war a golf course operated between the railway line and churchdown hill with a club house adjacent on pirton lane',
#  'big brother gave her a secret mission to make strange comments to the other housemates otherwise they would not be given their suitcases',
#  'the second battle of passchendaele cost the canadian corps casualties with over dead in days of fighting',
#  'it aims to produce students that are w',
#  'he drew many portraits of his friends including trelawny and the journalist john scott and in made a self portrait',
#  'janet pease emery s book states hagaman left life passively causing not a ripple in the pond where for so many years he was the big fish',
#  'however considerable variation exists in the relative risk of death following different aids defining clinical conditions',
#  'campbell died of stomach cancer in elsternwick victoria and was buried in brighton cemetery',
#  'tradition holds that the dish was served to the qianlong emperor of the qing dynasty during the emperor s tour of pingqiao',
#  'in it was revealed that brown s lawyer had applied for a section verdict unfit to be tried from the jury',
#  'it is known the height of everest may be changing due to its position on tectonic plates which can alternately raise or lower it depending on the type of tectonic event',
#  'warner was reported by blazer to valcke for these activities on may as they violate the terms of his suspension by the ethics committee',
#  'gender studies scholar aine mcglynn described how many licks as one of the most sexually explicit songs to receive airplay',
#  'in she started a publishing house and founded the swedish golf magazine for women red tee the first niched sports magazine for women',
#  'in san diego he attended city college and received an associate degree in technical illustration',
#  'a year later in strumlauf along with partners michael krohngold marc cooperman dee grimes and consulting chef guenter seeger opened mumbo jumbo a seat modern american restaurant located in downtown atlanta',
#  'however development of the first avenue extension to the east and scott avenue to the north enclosed the park and new housing and commercial developments within this area greatly reduced the potential expansion area for hickory hill',
#  'in toei asked fans if they would like to see all figure types included in the kinnikuman complete box set',
#  'they should also be provided with an extra large cloak or hooded mantle of felt with broad sleeves to wear large enough to wear over their armament including the coat of mail and the bow',
#  'his criminal activities started with petty crime robbery and drug dealing',
#  'on an inspection of the whole record we are of opinion that the title of the petitioner to the land surveyed is valid and therefore affirm the decree of the court below',
#  'kanai headed the tokyo based arm of mutual trading an importer of japanese food ingredients that served kawafuku and other restaurants',
#  'in the united states house of representatives carmel highlands is in notable people john denver american singer songwriter and resident from – died in a plane crash in monterey bay near pacific grove on october',
#  'jim perry had entered to pitch in relief for the al and gave up a single to bud harrelson to start the inning',
#  'moreau was presented with the yellow jersey by two podium girls',
#  'nmfs manages recovery for endangered and threatened marine species including foreign species',
#  'the site is listed as a folly in the sites and monuments record smr prn',
#  'ouyang ziyuan a geologist and chemical cosmologist was among the first to advocate the exploitation not only of known lunar reserves of metals such as titanium but also of helium an ideal fuel for future nuclear fusion power plants',
#  'as long as the labor power is sold temporarily then the worker is not considered a slave',
#  'krishna das is a bharatiya janata party politician from assam',
#  'in he became both the assistant coach with the los angeles salsa of the apsl and head coach of the east los angeles cobras of usisl',
#  'medicinal usage the plant has a long history of medicinal usage dating back to ancient greece',
#  'rather like the owl and the pussycat setting sail in a pea green boat',
#  ...]

# %%
tok = Tokenizer()
tok.words(df_AP1_True)
# Out:
# [['References',
#   'External',
#   'links',
#   'Category:1994',
#   'births',
#   'Category:Living',
#   'people',
#   'Category:Sri',
#   'Lankan',
#   'cricketers',
#   'Category:Kurunegala',
#   'Youth',
#   'Cricket',
#   'Club',
#   'cricketers',
#   'Category:Sri',
#   'Lanka',
#   'Army',
#   'Sports',
#   'Club',
#   'cricketers',
#   'Category:Sportspeople',
#   'from',
#   'Kurunegala'],
#  ['Members',
#   'of',
#   'the',
#   'commission',
#   'and',
#   'the',
#   'county',
#   'mayor',
#   'are',
#   'elected',
#   'to',
#   'four',
#   'year',
#   'terms'],
#  ['In',
#   'fact,',
#   'after',
#   'Return',
#   'of',
#   'the',
#   'Jedi,',
#   'I',
#   "didn't",
#   'have',
#   'a',
#   'burning',
#   'desire',
#   'to',
#   'return',
#   'to',
#   'this',
#   'galaxy',
#   "'far,",
#   'far',
#   "away',",
#   'but,',
#   'with',
#   'The',
#   'Phantom',
#   'Menace,',
#   'Lucas',
#   'has',
#   'revived',
#   'my',
#   'interest'],
#  ['He',
#   'ends',
#   'up',
#   'confronting',
#   'his',
#   'Shadow',
#   'who',
#   'represents',
#   'his',
#   'resentment',
#   'of',
#   'living',
#   'in',
#   'a',
#   'small',
#   'country',
#   'town',
#   'with',
#   'little',
#   'to',
#   'do,',
#   'as',
#   'well',
#   'as',
#   'his',
#   'inner',
#   'wish',
#   'for',
#   'something',
#   'exciting',
#   'to',
#   'happen'],
#  ['He',
#   'ends',
#   'up',
#   'confronting',
#   'his',
#   'Shadow',
#   'who',
#   'represents',
#   'his',
#   'resentment',
#   'of',
#   'living',
#   'in',
#   'a',
#   'small',
#   'country',
#   'town',
#   'with',
#   'little',
#   'to',
#   'do,',
#   'as',
#   'well',
#   'as',
#   'his',
#   'inner',
#   'wish',
#   'for',
#   'something',
#   'exciting',
#   'to',
#   'happen'],
#  ['Personal',
#   'life',
#   'His',
#   'younger',
#   'brother',
#   'Artur',
#   'Sadirov',
#   'was',
#   'also',
#   'a',
#   'professional',
#   'footballer'],
#  ['Personal',
#   'life',
#   'His',
#   'younger',
#   'brother',
#   'Artur',
#   'Sadirov',
#   'was',
#   'also',
#   'a',
#   'professional',
#   'footballer'],
#  ['"',
#   'Benjamin',
#   'Lumley',
#   'was',
#   'determained',
#   'to',
#   'procure',
#   'the',
#   'best',
#   'artists',
#   'for',
#   'his',
#   'theatre'],
#  ['Adrien',
#   'Niyonshuti',
#   'has',
#   'earned',
#   'a',
#   'spot',
#   'in',
#   'the',
#   '2012',
#   'London',
#   'Summer',
#   'Olympics',
#   'cross-country',
#   'mountain',
#   'bike',
#   'race',
#   'for',
#   'Rwanda'],
#  ['Adrien',
#   'Niyonshuti',
#   'has',
#   'earned',
#   'a',
#   'spot',
#   'in',
#   'the',
#   '2012',
#   'London',
#   'Summer',
#   'Olympics',
#   'cross-country',
#   'mountain',
#   'bike',
#   'race',
#   'for',
#   'Rwanda'],
#  ['In',
#   'the',
#   'south,',
#   'the',
#   'border',
#   'to',
#   'Östergötland',
#   'is',
#   'comprised',
#   'by',
#   'the',
#   'Kolmården',
#   'forest'],
#  ['Apogee',
#   'is',
#   'the',
#   'farthest',
#   'point',
#   'that',
#   'a',
#   'satellite',
#   'or',
#   'celestial',
#   'body',
#   'can',
#   'go',
#   'from',
#   'Earth,',
#   'at',
#   'which',
#   'the',
#   'orbital',
#   'velocity',
#   'will',
#   'be',
#   'at',
#   'its',
#   'minimum'],
#  ['Apogee',
#   'is',
#   'the',
#   'farthest',
#   'point',
#   'that',
#   'a',
#   'satellite',
#   'or',
#   'celestial',
#   'body',
#   'can',
#   'go',
#   'from',
#   'Earth,',
#   'at',
#   'which',
#   'the',
#   'orbital',
#   'velocity',
#   'will',
#   'be',
#   'at',
#   'its',
#   'minimum'],
#  ['Like',
#   'Ash',
#   'Tree,',
#   'Escobar',
#   'claims',
#   'she',
#   'was',
#   'inspired',
#   'to',
#   'write',
#   'the',
#   'story',
#   'after',
#   'the',
#   'idea',
#   'came',
#   'to',
#   'her',
#   'in',
#   'a',
#   'dream'],
#  ['Roma',
#   'servizi',
#   'per',
#   'la',
#   'Mobilità',
#   'is',
#   'the',
#   'municipally-owned',
#   'public',
#   'transport',
#   'agency',
#   'which',
#   'is',
#   'in',
#   'charge',
#   'of',
#   'programming',
#   'bus',
#   'routes',
#   'and',
#   'providing',
#   'real-time',
#   'information',
#   'and',
#   'services',
#   'to',
#   'the',
#   'user'],
#  ['"', 'In', 'his', 'book', 'titled', 'Towards', 'Understand'],
#  ['Three',
#   'community',
#   'colleges',
#   'were',
#   'granted',
#   'authority',
#   'to',
#   'offer',
#   'baccalaureate',
#   'degrees',
#   'following',
#   'a',
#   '1988',
#   'government',
#   'initiative',
#   'designed',
#   'to',
#   'increase',
#   'access',
#   'to',
#   'degree',
#   'programs',
#   'in',
#   'British',
#   'Columbia'],
#  ['The',
#   'Muslim',
#   'League',
#   'government',
#   'of',
#   'Bengal',
#   'declared',
#   'a',
#   'public',
#   'holiday',
#   'on',
#   'that',
#   'day'],
#  ['It',
#   'is',
#   'the',
#   'first',
#   'and',
#   'only',
#   'authentic',
#   'international',
#   'school',
#   'in',
#   'the',
#   'Kingdom,',
#   'where',
#   'wholesome',
#   'education',
#   'is',
#   'offered'],
#  ['The',
#   'engine',
#   'used',
#   'a',
#   'single',
#   'crankshaft',
#   'at',
#   'one',
#   'end',
#   'of',
#   'the',
#   'cylinders',
#   'and',
#   'a',
#   'crosshead',
#   'for',
#   'the',
#   'opposing',
#   'piston'],
#  ['The',
#   'engine',
#   'used',
#   'a',
#   'single',
#   'crankshaft',
#   'at',
#   'one',
#   'end',
#   'of',
#   'the',
#   'cylinders',
#   'and',
#   'a',
#   'crosshead',
#   'for',
#   'the',
#   'opposing',
#   'piston'],
#  ['References',
#   'External',
#   'links',
#   'Category:1958',
#   'births',
#   'Category:Living',
#   'people',
#   'Category:People',
#   'from',
#   'Thurcroft',
#   'Category:English',
#   'footballers',
#   'Category:Association',
#   'football',
#   'defenders',
#   'Category:Sheffield',
#   'Wednesday',
#   'F'],
#  ['References',
#   'External',
#   'links',
#   'National',
#   'Gallery',
#   'of',
#   'Art',
#   'See',
#   'also',
#   'Orsanmichele',
#   'Santa',
#   'maria',
#   'del',
#   'fiore',
#   'Category:1384',
#   'births',
#   'Category:1421',
#   'deaths',
#   'Category:People',
#   'from',
#   'Florence',
#   'Category:15th-century',
#   'Italian',
#   'sculptors',
#   'Category:Italian',
#   'male',
#   'sculptors'],
#  ['She',
#   'recovered',
#   'torpedoes',
#   'for',
#   'the',
#   'fleet',
#   'ballistic',
#   'missile',
#   'submarines',
#   'and',
#   ',',
#   'provided',
#   'underway',
#   'training',
#   'for',
#   'men',
#   'of',
#   'the',
#   'submarine',
#   'tender',
#   ',',
#   'then',
#   'sailed',
#   '20',
#   'July',
#   'for',
#   'Norfolk,',
#   'arriving',
#   '30',
#   'July',
#   '1965'],
#  ['She',
#   'recovered',
#   'torpedoes',
#   'for',
#   'the',
#   'fleet',
#   'ballistic',
#   'missile',
#   'submarines',
#   'and',
#   ',',
#   'provided',
#   'underway',
#   'training',
#   'for',
#   'men',
#   'of',
#   'the',
#   'submarine',
#   'tender',
#   ',',
#   'then',
#   'sailed',
#   '20',
#   'July',
#   'for',
#   'Norfolk,',
#   'arriving',
#   '30',
#   'July',
#   '1965'],
#  ['The',
#   'second',
#   'solution',
#   'requires',
#   'us',
#   'to',
#   'take',
#   'the',
#   'partial',
#   'derivative',
#   'w'],
#  ['Trains',
#   'travelling',
#   'to',
#   'or',
#   'from',
#   'the',
#   'south',
#   'of',
#   'the',
#   'station',
#   'pass',
#   'through',
#   'the',
#   'short',
#   'Ludlow',
#   'Tunnel',
#   '(',
#   'long),',
#   'which',
#   'passes',
#   'under',
#   'Gravel',
#   'Hill',
#   'and',
#   'has',
#   'its',
#   'tunnel',
#   'entrance',
#   'immediately',
#   'south',
#   'of',
#   'the',
#   'platforms'],
#  ['When',
#   'Barbara',
#   'starts',
#   'to',
#   'fight',
#   'back,',
#   'Violet',
#   'tauntingly',
#   'reveals',
#   'the',
#   'full',
#   'extent',
#   'of',
#   'her',
#   'addiction,',
#   'and',
#   'the',
#   'tensions',
#   'develop',
#   'into',
#   'a',
#   'violent',
#   'confrontation,',
#   'culminating',
#   'in',
#   'Barbara',
#   'physically',
#   'attacking',
#   'her',
#   'mother'],
#  ['In',
#   'the',
#   'semifinals,',
#   'it',
#   'defeated',
#   'Mega',
#   'Leks',
#   '2–0,',
#   'and',
#   'in',
#   'the',
#   'final',
#   'triumphed',
#   'over',
#   'great',
#   'rival',
#   'Partizan,',
#   '3–0'],
#  ['The',
#   'Dornier',
#   'Do',
#   '217-equipped',
#   'bomber',
#   'units',
#   'spent',
#   'most',
#   'of',
#   'the',
#   'rest',
#   'of',
#   '1942',
#   'recovering',
#   'from',
#   'these',
#   'losses',
#   'and',
#   're-equipping',
#   'with',
#   'the',
#   'more',
#   'capable',
#   'Do',
#   '217K',
#   'and',
#   'M'],
#  ['Vastra',
#   'tells',
#   'Clara',
#   'she',
#   'gets',
#   'only',
#   'one',
#   'word',
#   'to',
#   'impress',
#   'the',
#   'Doctor',
#   'with',
#   'if',
#   'she',
#   'wants',
#   'his',
#   'help'],
#  ['Distribution',
#   'The',
#   'brewery',
#   'owns',
#   '93',
#   'pubs',
#   'in',
#   'the',
#   'Swindon',
#   'area',
#   'and',
#   'surrounds,',
#   'including',
#   'locations',
#   'in',
#   'Oxford,',
#   'Newbury,',
#   'Reading,',
#   'Cheltenham,',
#   'Gloucester',
#   'and',
#   'Ascot;',
#   'and',
#   'sells',
#   'its',
#   'products',
#   'to',
#   'free',
#   'houses',
#   'in',
#   'the',
#   'Thames',
#   'Valley',
#   'and',
#   'London'],
#  ['Other',
#   'The',
#   'neutral',
#   'mutation',
#   'hypothesis—firms',
#   'fall',
#   'into',
#   'various',
#   'habits',
#   'of',
#   'financing,',
#   'which',
#   'do',
#   'not',
#   'impact',
#   'on',
#   'value'],
#  ['"',
#   'Using',
#   'software',
#   'to',
#   'check',
#   'on',
#   'what',
#   'his',
#   'client',
#   'was',
#   'doing,',
#   'Abu',
#   'Asab',
#   'discovered',
#   "Husayin's",
#   'sacrilegious',
#   'Facebook',
#   'writings'],
#  ['Negro',
#   'Hollow',
#   'was',
#   'used',
#   'as',
#   'a',
#   'water',
#   'supply',
#   'for',
#   'Mahanoy',
#   'City',
#   'in',
#   'the',
#   'early',
#   '1900s'],
#  ['"',
#   'The',
#   'obituary',
#   'in',
#   'The',
#   'Times',
#   'described',
#   'him',
#   'as',
#   '"the',
#   'most',
#   'polite',
#   'and',
#   'unsplenetic',
#   'of',
#   'cartoonists,',
#   'he',
#   'was',
#   'never',
#   'a',
#   'crusader,',
#   'remaining',
#   'always',
#   'a',
#   'witty,',
#   'civilized',
#   'critic',
#   'with',
#   'a',
#   'profound',
#   'understanding',
#   'of',
#   'the',
#   'vagaries',
#   'of',
#   'human',
#   'nature'],
#  ['As', 'the', 'building', 'was', 'built', 'in', 'the', 'very', 'e'],
#  ['White',
#   'scroll',
#   'with',
#   'black',
#   'lettering,',
#   'in',
#   'capitals,',
#   'reading',
#   'SANTO',
#   'ANDRÉ',
#   '-',
#   'SANTIAGO',
#   'DO',
#   'CACÉM'],
#  ['Cases',
#   'have',
#   'been',
#   'reported',
#   'when',
#   'tribals',
#   '(Mishing',
#   'people)',
#   'were',
#   'instigated',
#   'to',
#   'attack',
#   'government',
#   'sanctioned',
#   'Bengali',
#   'Hindu',
#   'refugee',
#   'settlements',
#   'in',
#   'the',
#   'Lakhimpur',
#   'district,',
#   'resulting',
#   'in',
#   'horrendous',
#   'massacres',
#   'where',
#   'Bengali',
#   'babies',
#   'were',
#   'snatched',
#   'from',
#   'their',
#   'mothers',
#   'and',
#   'thrown',
#   'to',
#   'fire,',
#   'alive'],
#  ['In',
#   '1997',
#   'Restless',
#   'was',
#   'acquired',
#   'by',
#   'Arnon',
#   "Milchan's",
#   'New',
#   'Regency',
#   'Productions,',
#   'one',
#   'of',
#   'the',
#   'entertainment',
#   "industry's",
#   'largest',
#   'independent',
#   'film',
#   'production',
#   'companies'],
#  ['Some',
#   'say',
#   'that',
#   "it's",
#   'a',
#   'corrupted',
#   'version',
#   'of',
#   'Bu',
#   'ring,',
#   'a',
#   'Bhutia',
#   'word',
#   'where',
#   'bu',
#   'stands',
#   'for',
#   'snake',
#   'and',
#   'ring',
#   'stands',
#   'for',
#   'long'],
#  ['NJPW',
#   'president',
#   'Naoki',
#   'Sugabayashi',
#   'predicted',
#   'the',
#   'tour',
#   'could',
#   'take',
#   'up',
#   'to',
#   'two',
#   'or',
#   'three',
#   'years'],
#  ['NJPW',
#   'president',
#   'Naoki',
#   'Sugabayashi',
#   'predicted',
#   'the',
#   'tour',
#   'could',
#   'take',
#   'up',
#   'to',
#   'two',
#   'or',
#   'three',
#   'years'],
#  ['He',
#   'was',
#   'arrested',
#   'on',
#   'suspicion',
#   'of',
#   'making',
#   'criminal',
#   'threats'],
#  ['He',
#   'spent',
#   'most',
#   'of',
#   'his',
#   'life',
#   'devoted',
#   'to',
#   'military',
#   'affairs,',
#   'being',
#   'involved',
#   'in',
#   'the',
#   'siege',
#   'of',
#   'Rouen',
#   'in',
#   '1204,',
#   'and',
#   'the',
#   'sieges',
#   'of',
#   'Béziers',
#   'and',
#   'Carcasonne',
#   'during',
#   'the',
#   'Albigensian',
#   'crusade'],
#  ['He',
#   'spent',
#   'most',
#   'of',
#   'his',
#   'life',
#   'devoted',
#   'to',
#   'military',
#   'affairs,',
#   'being',
#   'involved',
#   'in',
#   'the',
#   'siege',
#   'of',
#   'Rouen',
#   'in',
#   '1204,',
#   'and',
#   'the',
#   'sieges',
#   'of',
#   'Béziers',
#   'and',
#   'Carcasonne',
#   'during',
#   'the',
#   'Albigensian',
#   'crusade'],
#  ['The',
#   'film',
#   'is',
#   'narrated',
#   'by',
#   'Pirkko',
#   'Saisio',
#   'but',
#   'narration',
#   'and',
#   'dialogue',
#   'are',
#   'sparse',
#   'and',
#   'the',
#   'imagery',
#   'is',
#   'left',
#   'to',
#   'convey',
#   'the',
#   'largest',
#   'part',
#   'of',
#   'the',
#   "film's",
#   'message'],
#  ['Brown',
#   'published',
#   'a',
#   'further',
#   'eleven',
#   'species',
#   'in',
#   '1830,',
#   'placing',
#   'all',
#   'of',
#   'them',
#   'in',
#   'Banksia',
#   'verae'],
#  ['&/',
#   'find',
#   'the',
#   'minimum',
#   'value',
#   'of',
#   'the',
#   'list',
#   'of',
#   'modulo',
#   'result'],
#  ['north',
#   'of',
#   'Nowy',
#   'Sącz',
#   'is',
#   'Lake',
#   'Rożnów',
#   '(Jezioro',
#   'Rożnowskie),',
#   'a',
#   'reservoir',
#   '(',
#   'long,',
#   'covering',
#   'an',
#   'area',
#   'of',
#   ',',
#   'and',
#   'having',
#   'a',
#   'capacity',
#   'of',
#   '193,000,000',
#   'm³),',
#   'with',
#   'many',
#   'dachas',
#   'and',
#   'camping',
#   'sites'],
#  ['In',
#   'July',
#   '2011,',
#   'López',
#   'moved',
#   'to',
#   'the',
#   'newly',
#   'promoted',
#   'Costa',
#   'Rican',
#   'Primera',
#   'División',
#   'club',
#   'Belén',
#   'Siglo',
#   'XXI',
#   'on',
#   'a',
#   'free',
#   'transfer',
#   'and',
#   'in',
#   'August',
#   '2013',
#   'he',
#   'signed',
#   'for',
#   'Uruguay',
#   'de',
#   'Coronado'],
#  ['The',
#   'G&GR',
#   'opened',
#   'in',
#   '1831,',
#   'and',
#   'at',
#   'first',
#   'relations',
#   'with',
#   'the',
#   'M&KR',
#   'were',
#   'friendly;',
#   'the',
#   'G&GR',
#   'was',
#   'dependent',
#   'on',
#   'its',
#   'mineral',
#   'traffic',
#   'originating',
#   'on',
#   'the',
#   'M&KR'],
#  ['Sir',
#   'Richard',
#   'Mason',
#   'died',
#   '8',
#   'March',
#   '1685',
#   'and',
#   'is',
#   'buried',
#   'at',
#   'the',
#   'parish',
#   'church',
#   'at',
#   'Sutton'],
#  ['Healthcare',
#   'In',
#   '2014,',
#   'the',
#   'Neturia',
#   'CD',
#   'block',
#   'had',
#   '1',
#   'rural',
#   'hospital',
#   'and',
#   '3',
#   'primary',
#   'health',
#   'centres,',
#   'with',
#   'total',
#   '48',
#   'beds',
#   'and',
#   '6',
#   'doctors'],
#  ['8',
#   'out',
#   'of',
#   '10,',
#   'saying',
#   'the',
#   'season',
#   'is',
#   '"bigger,',
#   'more',
#   'ambitious',
#   'and',
#   'much',
#   'weirder',
#   'than',
#   'its',
#   'predecessor"'],
#  ['The',
#   'Evans',
#   'County',
#   'School',
#   'District',
#   'is',
#   'a',
#   'school',
#   'district',
#   'based',
#   'in',
#   'Evans',
#   'County,',
#   'Georgia,',
#   'United',
#   'States'],
#  ['It',
#   'is',
#   'located',
#   'in',
#   'the',
#   'province',
#   'of',
#   'Lapland',
#   'along',
#   'the',
#   'Tornio',
#   'River,',
#   'opposite',
#   'the',
#   'Swedish',
#   'town',
#   'of',
#   'Övertorneå',
#   'about',
#   'by',
#   'road',
#   'to',
#   'its',
#   'northwest'],
#  ['Its',
#   'rapid',
#   'growth',
#   'crowds',
#   'out',
#   'native',
#   'vegetation',
#   'and',
#   'it',
#   'is',
#   'very',
#   'difficult',
#   'to',
#   'remove',
#   'since',
#   'it',
#   'can',
#   'grow',
#   'back',
#   'from',
#   'the',
#   'tubers,',
#   'and',
#   'new',
#   'vines',
#   'can',
#   'grow',
#   'from',
#   'the',
#   'bulbils',
#   'even',
#   'after',
#   'being',
#   'cut',
#   'down',
#   'or',
#   'burned'],
#  ['It',
#   'had',
#   'licensed',
#   'the',
#   '"Willy',
#   'Wonka"',
#   'name',
#   'in',
#   '1971',
#   'so',
#   'that',
#   'their',
#   'candy',
#   'could',
#   'be',
#   'used',
#   'as',
#   'merchandising',
#   'tie-ins',
#   'for',
#   'Willy',
#   'Wonka',
#   '&',
#   'the',
#   'Chocolate',
#   'Factory',
#   'film,',
#   'which',
#   'was',
#   'released',
#   'the',
#   'same',
#   'year'],
#  ['It',
#   'had',
#   'licensed',
#   'the',
#   '"Willy',
#   'Wonka"',
#   'name',
#   'in',
#   '1971',
#   'so',
#   'that',
#   'their',
#   'candy',
#   'could',
#   'be',
#   'used',
#   'as',
#   'merchandising',
#   'tie-ins',
#   'for',
#   'Willy',
#   'Wonka',
#   '&',
#   'the',
#   'Chocolate',
#   'Factory',
#   'film,',
#   'which',
#   'was',
#   'released',
#   'the',
#   'same',
#   'year'],
#  ['Phule',
#   'is',
#   'a',
#   'strong-willed',
#   'individual,',
#   'with',
#   'a',
#   'strong',
#   'dislike',
#   'for',
#   'stereotyping,',
#   'and',
#   'not',
#   'infrequently',
#   'finds',
#   'himself',
#   'in',
#   'conflict',
#   'with',
#   'other',
#   'authority',
#   'figures',
#   'such',
#   'as',
#   'his',
#   'father'],
#  ['Phule',
#   'is',
#   'a',
#   'strong-willed',
#   'individual,',
#   'with',
#   'a',
#   'strong',
#   'dislike',
#   'for',
#   'stereotyping,',
#   'and',
#   'not',
#   'infrequently',
#   'finds',
#   'himself',
#   'in',
#   'conflict',
#   'with',
#   'other',
#   'authority',
#   'figures',
#   'such',
#   'as',
#   'his',
#   'father'],
#  ['Style',
#   'The',
#   'title',
#   'shares',
#   'its',
#   'name',
#   'with',
#   'the',
#   'Robert',
#   'Frost',
#   'poem',
#   'Acquainted',
#   'with',
#   'the',
#   'Night,',
#   'which',
#   'is',
#   'quoted',
#   'on',
#   'the',
#   'first',
#   'page'],
#  ['Style',
#   'The',
#   'title',
#   'shares',
#   'its',
#   'name',
#   'with',
#   'the',
#   'Robert',
#   'Frost',
#   'poem',
#   'Acquainted',
#   'with',
#   'the',
#   'Night,',
#   'which',
#   'is',
#   'quoted',
#   'on',
#   'the',
#   'first',
#   'page'],
#  ['"',
#   'Simplified',
#   'explanation',
#   'The',
#   'basic',
#   'idea',
#   'of',
#   'loop',
#   'unrolling',
#   'is',
#   'that',
#   'the',
#   'number',
#   'of',
#   'instructions',
#   'executed',
#   'in',
#   'a',
#   'loop',
#   'can',
#   'be',
#   'reduced',
#   'by',
#   'reducing',
#   'the',
#   'number',
#   'of',
#   'loop',
#   'tests,',
#   'sometimes',
#   'reducing',
#   'the',
#   'amount',
#   'of',
#   'time',
#   'spent',
#   'in',
#   'the',
#   'loop'],
#  ['However,',
#   'having',
#   'proved',
#   'her',
#   'point,',
#   'Mrs',
#   'Weldon',
#   'publicised',
#   'her',
#   'story',
#   'by',
#   'giving',
#   'interviews',
#   'to',
#   'the',
#   'daily',
#   'newspapers',
#   'and',
#   'the',
#   'spiritualist',
#   'press,',
#   'in',
#   'an',
#   'attempt',
#   'to',
#   'provoke',
#   'her',
#   'husband',
#   'and',
#   'the',
#   'two',
#   'doctors',
#   'into',
#   'suing',
#   'her',
#   'for',
#   'libel'],
#  ['When',
#   'the',
#   'machine',
#   'is',
#   'running,',
#   'half',
#   'the',
#   'power',
#   'is',
#   'transmitted',
#   'mechanically',
#   'through',
#   'the',
#   'shaft',
#   'while',
#   'the',
#   'other',
#   'half',
#   'is',
#   'transmitted',
#   'electrically'],
#  ['These',
#   'were',
#   'the',
#   'only',
#   'ODI',
#   'matches',
#   'played',
#   'by',
#   'Namibia',
#   'until',
#   'they',
#   'gained',
#   'ODI',
#   'status',
#   'after',
#   'reaching',
#   'the',
#   'final',
#   'of',
#   'the',
#   '2019',
#   'ICC',
#   'World',
#   'Cricket',
#   'League',
#   'Division',
#   'Two'],
#  ['Whether',
#   "you're",
#   'celebrating',
#   'the',
#   'cowboy',
#   'spirit',
#   'of',
#   'old',
#   'or',
#   'the',
#   'maverick',
#   'in',
#   'all',
#   'of',
#   'us,',
#   'there',
#   'is',
#   'something',
#   'for',
#   'everyone'],
#  ['In',
#   'addition',
#   'to',
#   'his',
#   'efforts',
#   'in',
#   'that',
#   'field,',
#   'he',
#   'owns',
#   'and',
#   'runs',
#   'a',
#   '"small',
#   'business',
#   'centre,',
#   'which',
#   'deals',
#   'with',
#   'computer',
#   'repairs,',
#   'software,',
#   'and',
#   'office',
#   'supplies"'],
#  ['In',
#   'addition',
#   'to',
#   'his',
#   'efforts',
#   'in',
#   'that',
#   'field,',
#   'he',
#   'owns',
#   'and',
#   'runs',
#   'a',
#   '"small',
#   'business',
#   'centre,',
#   'which',
#   'deals',
#   'with',
#   'computer',
#   'repairs,',
#   'software,',
#   'and',
#   'office',
#   'supplies"'],
#  ['Another',
#   'fruitful',
#   'point',
#   'of',
#   'view',
#   'is',
#   'to',
#   'define',
#   'the',
#   'differential',
#   'directly',
#   'as',
#   'a',
#   'kind',
#   'of',
#   'directional',
#   'derivative:',
#   'which',
#   'is',
#   'the',
#   'approach',
#   'already',
#   'taken',
#   'for',
#   'defining',
#   'higher',
#   'order',
#   'differentials',
#   '(and',
#   'is',
#   'most',
#   'nearly',
#   'the',
#   'definition',
#   'set',
#   'forth',
#   'by',
#   'Cauchy)'],
#  ['Airtasker',
#   'is',
#   'a',
#   'Sydney-based',
#   'Australian',
#   'company',
#   'which',
#   'provides',
#   'an',
#   'online',
#   'and',
#   'mobile',
#   'marketplace',
#   'enabling',
#   'users',
#   'to',
#   'outsource',
#   'everyday',
#   'tasks'],
#  ['He',
#   'held',
#   'a',
#   'regent',
#   'position',
#   'kampaku',
#   'from',
#   '1703',
#   'to',
#   '1707'],
#  ['Weaknesses',
#   'When',
#   'not',
#   'used',
#   'in',
#   'a',
#   'private',
#   'setting,',
#   'graphical',
#   'passwords',
#   'are',
#   'typically',
#   'more',
#   'susceptible',
#   'than',
#   'text-based',
#   'passwords',
#   'to',
#   '"shoulder-surfing',
#   'attacks",',
#   'in',
#   'which',
#   'an',
#   'attacker',
#   'learns',
#   'the',
#   'password',
#   'by',
#   'watching',
#   'the',
#   'screen',
#   'as',
#   'a',
#   'user',
#   'gains',
#   'access'],
#  ['is',
#   'a',
#   'Japanese',
#   'media',
#   'franchise',
#   'created',
#   'by',
#   'Marvelous,',
#   'which',
#   'was',
#   'announced',
#   'at',
#   'the',
#   'AnimeJapan',
#   'convention',
#   'in',
#   'March',
#   '2015'],
#  ['Although',
#   'misunderstood',
#   'by',
#   'some',
#   'critics',
#   'as',
#   '"essentializing"',
#   '(this',
#   'was',
#   'a',
#   'nasty',
#   'charge',
#   'in',
#   'the',
#   '1990s)',
#   'or',
#   'as',
#   'a',
#   'glorification',
#   'of',
#   'female',
#   'masochism,',
#   'it',
#   'was',
#   'in',
#   'fact',
#   'neither'],
#  ['In',
#   'an',
#   'interview',
#   'in',
#   '1996',
#   'with',
#   'The',
#   'Common',
#   'Sense,',
#   'a',
#   'documentary',
#   'produced',
#   'by',
#   'the',
#   'Radio',
#   'Television',
#   'Hong',
#   'Kong,',
#   'Cradock',
#   'claimed',
#   'that',
#   'the',
#   'United',
#   'Kingdom',
#   'nearly',
#   'lost',
#   'all',
#   'her',
#   'influence',
#   'over',
#   'China',
#   'because',
#   'the',
#   'two',
#   'countries',
#   'had',
#   'been',
#   'in',
#   'political',
#   'dispute'],
#  ['In',
#   'the',
#   'movie,',
#   'the',
#   'song',
#   'is',
#   'performed',
#   'in',
#   'a',
#   'night',
#   'club',
#   'scene',
#   'by',
#   'Mangano,',
#   'though',
#   'she',
#   'is',
#   'lip-syncing;',
#   'the',
#   'lyrics',
#   'are',
#   'actually',
#   'sung',
#   'by',
#   'Flo',
#   "Sandon's"],
#  ['Dennis',
#   'Harvey',
#   'wrote',
#   'in',
#   'Variety,',
#   '"Lane',
#   'and',
#   'company',
#   'created',
#   'a',
#   'sort',
#   'of',
#   'prankish',
#   'ode',
#   'to',
#   'the',
#   'classic',
#   'American',
#   'Dream',
#   'of',
#   'hard',
#   'work',
#   'and',
#   'high',
#   'ideals',
#   'leading',
#   'inevitably',
#   'to',
#   'fame,',
#   'fortune',
#   'and',
#   'happiness'],
#  ['Etymology',
#   'and',
#   'regional',
#   'variants',
#   'In',
#   'Ancient',
#   'Rome,',
#   'panis',
#   'focacius',
#   'was',
#   'a',
#   'flat',
#   'bread',
#   'baked',
#   'on',
#   'the',
#   'hearth'],
#  ['”',
#   'As',
#   'the',
#   'film',
#   'reports,',
#   'the',
#   'Polisario',
#   'Liberation',
#   'Front,',
#   'a',
#   'nationalist',
#   'organization',
#   'backed',
#   'by',
#   'Algeria,',
#   'has',
#   'been',
#   'fighting',
#   'with',
#   'Morocco',
#   'over',
#   'Western',
#   'Sahara',
#   'for',
#   'the',
#   'last',
#   '34',
#   'years'],
#  ['They',
#   'then',
#   'moved',
#   'into',
#   'pre-production',
#   'work',
#   'which',
#   'included',
#   'an',
#   'eight-month',
#   'long',
#   'casting',
#   'process',
#   'to',
#   'find',
#   'actors',
#   'to',
#   'fill',
#   'out',
#   'smaller',
#   'roles',
#   'and',
#   'putting',
#   'together',
#   'a',
#   'crew',
#   'for',
#   'the',
#   'film'],
#  ['It',
#   'was',
#   'screened',
#   'in',
#   'the',
#   'main',
#   'competition',
#   'section',
#   'of',
#   'the',
#   '65th',
#   'Berlin',
#   'International',
#   'Film',
#   'Festival'],
#  ['56', 'and', 'the', 'average', 'family', 'size', 'was', '2'],
#  ['The',
#   'systematic',
#   'name',
#   'of',
#   'this',
#   'enzyme',
#   'class',
#   'is',
#   '(+)-bornyl-diphosphate',
#   'lyase',
#   '(decyclizing)'],
#  ['During',
#   'the',
#   'Taiping',
#   'Rebellion',
#   'Shaoxing',
#   'was',
#   'home',
#   'to',
#   'a',
#   'local',
#   'militia',
#   'leader',
#   'named',
#   'Bao',
#   'Lisheng',
#   'who',
#   'organized',
#   'an',
#   'armed',
#   'resistance',
#   'to',
#   'the',
#   'Taiping',
#   'army',
#   'in',
#   'his',
#   'home',
#   'village',
#   'of',
#   'Baochun'],
#  ['During',
#   'the',
#   'Taiping',
#   'Rebellion',
#   'Shaoxing',
#   'was',
#   'home',
#   'to',
#   'a',
#   'local',
#   'militia',
#   'leader',
#   'named',
#   'Bao',
#   'Lisheng',
#   'who',
#   'organized',
#   'an',
#   'armed',
#   'resistance',
#   'to',
#   'the',
#   'Taiping',
#   'army',
#   'in',
#   'his',
#   'home',
#   'village',
#   'of',
#   'Baochun'],
#  ['During',
#   'the',
#   'Taiping',
#   'Rebellion',
#   'Shaoxing',
#   'was',
#   'home',
#   'to',
#   'a',
#   'local',
#   'militia',
#   'leader',
#   'named',
#   'Bao',
#   'Lisheng',
#   'who',
#   'organized',
#   'an',
#   'armed',
#   'resistance',
#   'to',
#   'the',
#   'Taiping',
#   'army',
#   'in',
#   'his',
#   'home',
#   'village',
#   'of',
#   'Baochun'],
#  ['However,',
#   'even',
#   'fine',
#   'art',
#   'often',
#   'has',
#   'goals',
#   'beyond',
#   'pure',
#   'creativity',
#   'and',
#   'self-expression'],
#  ['The',
#   'single',
#   'received',
#   'a',
#   'mixed',
#   'critical',
#   'reception,',
#   'but',
#   'had',
#   'moderate',
#   'commercial',
#   'performance'],
#  ['He',
#   'was',
#   'elected',
#   'at',
#   'the',
#   '1951',
#   'general',
#   'election',
#   'as',
#   'Member',
#   'of',
#   'Parliament',
#   '(MP)',
#   'for',
#   'Great',
#   'Yarmouth,',
#   'a',
#   'seat',
#   'which',
#   'had',
#   'been',
#   'held',
#   'at',
#   'the',
#   'start',
#   'of',
#   'the',
#   '20th',
#   'century',
#   'by',
#   'his',
#   'grandfather',
#   'Sir',
#   'Arthur',
#   'Fell'],
#  ['He',
#   'was',
#   'elected',
#   'at',
#   'the',
#   '1951',
#   'general',
#   'election',
#   'as',
#   'Member',
#   'of',
#   'Parliament',
#   '(MP)',
#   'for',
#   'Great',
#   'Yarmouth,',
#   'a',
#   'seat',
#   'which',
#   'had',
#   'been',
#   'held',
#   'at',
#   'the',
#   'start',
#   'of',
#   'the',
#   '20th',
#   'century',
#   'by',
#   'his',
#   'grandfather',
#   'Sir',
#   'Arthur',
#   'Fell'],
#  ['Its',
#   'official',
#   'audio',
#   'on',
#   'YouTube',
#   'has',
#   '334,546,280',
#   'views',
#   '(as',
#   'of',
#   'February',
#   '14th',
#   '2020)'],
#  ['On',
#   'January',
#   '7,',
#   '1961,',
#   'at',
#   'a',
#   'contentious',
#   'meeting',
#   'of',
#   'the',
#   'Group,',
#   'Amos',
#   'Vogel',
#   'attempted',
#   'to',
#   'stonewall',
#   'the',
#   'formation',
#   'of',
#   'the',
#   'distribution',
#   'center',
#   'claiming',
#   'that',
#   'his',
#   'own',
#   'Cinema',
#   '16',
#   'organization',
#   'should',
#   'be',
#   'the',
#   'only',
#   'distributor',
#   'of',
#   'experimental',
#   'films'],
#  ['Foreign',
#   'policy',
#   'The',
#   'Lemass',
#   'era',
#   'saw',
#   'some',
#   'significant',
#   'developments',
#   'in',
#   'Irish',
#   'foreign',
#   'policy'],
#  ['She',
#   'became',
#   'enraged',
#   'when',
#   'GOP',
#   'party',
#   'leaders',
#   'endorsed',
#   'fellow',
#   'assemblyman',
#   '(Ross',
#   'Johnson)',
#   'with',
#   'a',
#   'more',
#   'conservative',
#   'voting',
#   'record',
#   'than',
#   'hers,',
#   'who',
#   'had',
#   'moved',
#   'into',
#   'the',
#   'district',
#   'to',
#   'run'],
#  ['Major',
#   'Pryor',
#   'was',
#   'a',
#   'member',
#   'of',
#   'the',
#   'Society',
#   'of',
#   'the',
#   'Cincinnati'],
#  ['The', 'farmhouse', 'was', 'built', 'in', 'about', '1817'],
#  ['"',
#   'The',
#   'point',
#   'of',
#   'this',
#   'exercise',
#   'was',
#   'to',
#   'separate',
#   'function',
#   'from',
#   'design;',
#   'a',
#   'surface',
#   'or',
#   'a',
#   'defining',
#   'of',
#   'space',
#   'was',
#   'not',
#   'necessarily',
#   'a',
#   'floor',
#   'or',
#   'a',
#   'ceiling',
#   'or',
#   'a',
#   'wall-',
#   'those',
#   'titles',
#   'are',
#   'added',
#   'by',
#   'people'],
#  ['"',
#   'The',
#   'point',
#   'of',
#   'this',
#   'exercise',
#   'was',
#   'to',
#   'separate',
#   'function',
#   'from',
#   'design;',
#   'a',
#   'surface',
#   'or',
#   'a',
#   'defining',
#   'of',
#   'space',
#   'was',
#   'not',
#   'necessarily',
#   'a',
#   'floor',
#   'or',
#   'a',
#   'ceiling',
#   'or',
#   'a',
#   'wall-',
#   'those',
#   'titles',
#   'are',
#   'added',
#   'by',
#   'people'],
#  ['Department',
#   'of',
#   'Education,',
#   'was',
#   'founded',
#   'in',
#   '1990',
#   'as',
#   'a',
#   'joint',
#   'venture',
#   'of',
#   'Katz',
#   'and',
#   "Pitt's",
#   'University',
#   'Center',
#   'for',
#   'International',
#   'Studies'],
#  ['”',
#   'Remembering',
#   'Akaky',
#   'he',
#   '“shuddered',
#   'at',
#   'how',
#   'much',
#   'inhumanity',
#   'there',
#   'is',
#   'in',
#   'man'],
#  ['Still,',
#   'the',
#   'prolonged',
#   'talk,',
#   'combined',
#   'with',
#   'some',
#   'medicine',
#   'he',
#   'takes,',
#   'make',
#   'him',
#   'feel',
#   'better'],
#  ['He',
#   'made',
#   'his',
#   'first-class',
#   'debut',
#   'for',
#   'Punjab',
#   'against',
#   'Bengal',
#   'in',
#   'the',
#   '2017–18',
#   'Ranji',
#   'Trophy,',
#   'in',
#   'late',
#   '2017,',
#   'with',
#   'a',
#   'half-century',
#   'in',
#   'the',
#   'game',
#   'and',
#   '129',
#   'runs',
#   'in',
#   'the',
#   'next',
#   'match',
#   'against',
#   'Services'],
#  ['Hitler',
#   'made',
#   'peace',
#   'overtures',
#   'to',
#   'the',
#   'new',
#   'British',
#   'leader,',
#   'Winston',
#   'Churchill,',
#   'and',
#   'upon',
#   'their',
#   'rejection',
#   'he',
#   'ordered',
#   'a',
#   'series',
#   'of',
#   'aerial',
#   'attacks',
#   'on',
#   'Royal',
#   'Air',
#   'Force',
#   'airbases',
#   'and',
#   'radar',
#   'stations',
#   'in',
#   'south-east',
#   'England'],
#  ['0',
#   'board:',
#   'Xilinx',
#   'Spartan-3',
#   '400k',
#   'gate',
#   '(XC3S400-4PQ208C)',
#   'FPGA',
#   'using',
#   '82%',
#   'capacity'],
#  ['Her',
#   'name',
#   'and',
#   'titles',
#   'survived',
#   'on',
#   'her',
#   'canopic',
#   'jars',
#   'and',
#   'on',
#   'an',
#   'alabaster',
#   'vessel',
#   'found',
#   'in',
#   'her',
#   'tomb'],
#  ['Professional',
#   'career',
#   'On',
#   'November',
#   '28,',
#   '2014,',
#   'it',
#   'was',
#   'announced',
#   'that',
#   'Emanuel',
#   'had',
#   'accepted',
#   'his',
#   'invitation',
#   'to',
#   'play',
#   'in',
#   'the',
#   '2015',
#   'East-West',
#   'Shrine',
#   'Game'],
#  ['Methane',
#   'could',
#   'be',
#   'produced',
#   'by',
#   'non-biological',
#   'process',
#   'such',
#   'as',
#   'serpentinization',
#   'involving',
#   'water,',
#   'carbon',
#   'dioxide,',
#   'and',
#   'the',
#   'mineral',
#   'olivine,',
#   'which',
#   'is',
#   'known',
#   'to',
#   'be',
#   'common',
#   'on',
#   'Mars'],
#  ['During',
#   'the',
#   'struggle',
#   'of',
#   '1857',
#   'the',
#   'Raikawars,',
#   'independence',
#   'fighters',
#   'from',
#   'nearby',
#   'village',
#   'Rudamau,',
#   'burned',
#   "Mallawan's",
#   'court',
#   'house'],
#  ['Apostasy',
#   'and',
#   'Blasphemy',
#   'Rafiq',
#   'Taqi,',
#   'a',
#   'journalist',
#   'residing',
#   'in',
#   'Baku,',
#   'Azerbaijan',
#   'was',
#   'fatally',
#   'stabbed',
#   'based',
#   'on',
#   'fatwa',
#   'of',
#   'an',
#   'Ayatollah',
#   'the',
#   'student',
#   'of',
#   'Ayatollah',
#   'Khomeini',
#   'in',
#   '2011,',
#   'accused',
#   'to',
#   'apostasy',
#   'and',
#   'blasphemy',
#   'because',
#   'of',
#   'his',
#   'articles'],
#  ['Apostasy',
#   'and',
#   'Blasphemy',
#   'Rafiq',
#   'Taqi,',
#   'a',
#   'journalist',
#   'residing',
#   'in',
#   'Baku,',
#   'Azerbaijan',
#   'was',
#   'fatally',
#   'stabbed',
#   'based',
#   'on',
#   'fatwa',
#   'of',
#   'an',
#   'Ayatollah',
#   'the',
#   'student',
#   'of',
#   'Ayatollah',
#   'Khomeini',
#   'in',
#   '2011,',
#   'accused',
#   'to',
#   'apostasy',
#   'and',
#   'blasphemy',
#   'because',
#   'of',
#   'his',
#   'articles'],
#  ['The',
#   'declaration',
#   'authorized',
#   'Federal',
#   'Emergency',
#   'Management',
#   'Agency',
#   '(FEMA)',
#   'to',
#   'provide',
#   'resources',
#   'and',
#   'personnel,',
#   'funding',
#   'for',
#   '75%',
#   'of',
#   'the',
#   'cost',
#   'of',
#   'debris',
#   'removal,',
#   'and',
#   'loans',
#   'from',
#   'the',
#   'Small',
#   'Business',
#   'Administration'],
#  ['The',
#   'declaration',
#   'authorized',
#   'Federal',
#   'Emergency',
#   'Management',
#   'Agency',
#   '(FEMA)',
#   'to',
#   'provide',
#   'resources',
#   'and',
#   'personnel,',
#   'funding',
#   'for',
#   '75%',
#   'of',
#   'the',
#   'cost',
#   'of',
#   'debris',
#   'removal,',
#   'and',
#   'loans',
#   'from',
#   'the',
#   'Small',
#   'Business',
#   'Administration'],
#  ['1837)',
#   'February',
#   '16',
#   '–',
#   'Stephen',
#   'Cassin,',
#   'United',
#   'States',
#   'Navy',
#   'officer',
#   '(d'],
#  ['His',
#   'initial',
#   'intentions',
#   'were',
#   'to',
#   'fly',
#   'crew',
#   'and',
#   'supplies',
#   'to',
#   'his',
#   'and',
#   'others',
#   'ships',
#   'throughout',
#   'the',
#   'world—primarily',
#   'in',
#   'the',
#   'Far',
#   'East'],
#  ['When',
#   'Devon',
#   'finally',
#   'arrived,',
#   'he',
#   'was',
#   'either',
#   'unable',
#   'to',
#   'engage',
#   'his',
#   'troops,',
#   'or',
#   'too',
#   'late',
#   'to',
#   'make',
#   'a',
#   'difference'],
#  ['Augmentation',
#   'of',
#   'a',
#   'global',
#   'navigation',
#   'satellite',
#   'system',
#   '(GNSS)',
#   'is',
#   'a',
#   'method',
#   'of',
#   'improving',
#   'the',
#   'navigation',
#   "system's",
#   'attributes,',
#   'such',
#   'as',
#   'accuracy,',
#   'reliability,',
#   'and',
#   'availability,',
#   'through',
#   'the',
#   'integration',
#   'of',
#   'external',
#   'information',
#   'into',
#   'the',
#   'calculation',
#   'process'],
#  ['Augmentation',
#   'of',
#   'a',
#   'global',
#   'navigation',
#   'satellite',
#   'system',
#   '(GNSS)',
#   'is',
#   'a',
#   'method',
#   'of',
#   'improving',
#   'the',
#   'navigation',
#   "system's",
#   'attributes,',
#   'such',
#   'as',
#   'accuracy,',
#   'reliability,',
#   'and',
#   'availability,',
#   'through',
#   'the',
#   'integration',
#   'of',
#   'external',
#   'information',
#   'into',
#   'the',
#   'calculation',
#   'process'],
#  ['The',
#   'locomotive',
#   'was',
#   'not',
#   'successful',
#   'and',
#   'was',
#   'scrapped',
#   'soon',
#   'afterwards'],
#  ['Collections',
#   'The',
#   'museum',
#   'has',
#   'a',
#   'collection',
#   'of',
#   '19,162',
#   'objects'],
#  ['In',
#   'August',
#   '2011,',
#   'he',
#   'suffered',
#   'knee',
#   'ligament',
#   'damage',
#   'that',
#   'put',
#   'him',
#   'out',
#   'of',
#   'action',
#   'for',
#   'six',
#   'weeks,',
#   'but',
#   'when',
#   'he',
#   'returned,',
#   'he',
#   'was',
#   'unable',
#   'to',
#   'match',
#   'his',
#   'goalscoring',
#   'tally',
#   'of',
#   'the',
#   'previous',
#   'season',
#   'as',
#   'the',
#   'team',
#   'struggled',
#   'against',
#   'relegation'],
#  ['A',
#   'Black',
#   'Nail',
#   'served',
#   'without',
#   'ice',
#   'is',
#   'sometimes',
#   'called',
#   'a',
#   'Straight',
#   'Black',
#   'Nail'],
#  ['The',
#   'city',
#   'lost',
#   'population',
#   'from',
#   'the',
#   '1960s',
#   'through',
#   'the',
#   '1980s,',
#   'but',
#   'experienced',
#   'some',
#   'recovery',
#   'in',
#   'the',
#   '1990s'],
#  ['Between',
#   '2001',
#   'and',
#   '2006,',
#   'some',
#   'of',
#   'the',
#   'council',
#   'housing',
#   'around',
#   'Blakenall',
#   'Heath',
#   'were',
#   'demolished,',
#   'including',
#   'the',
#   'whole',
#   'of',
#   'Taylor',
#   'Avenue,',
#   'the',
#   'three',
#   'late',
#   '1950s',
#   'tower',
#   'blocks,',
#   'and',
#   'large',
#   'sections',
#   'of',
#   'Walker',
#   'Road',
#   'and',
#   'Barracks',
#   'Lane'],
#  ['Between',
#   '2001',
#   'and',
#   '2006,',
#   'some',
#   'of',
#   'the',
#   'council',
#   'housing',
#   'around',
#   'Blakenall',
#   'Heath',
#   'were',
#   'demolished,',
#   'including',
#   'the',
#   'whole',
#   'of',
#   'Taylor',
#   'Avenue,',
#   'the',
#   'three',
#   'late',
#   '1950s',
#   'tower',
#   'blocks,',
#   'and',
#   'large',
#   'sections',
#   'of',
#   'Walker',
#   'Road',
#   'and',
#   'Barracks',
#   'Lane'],
#  ['Between',
#   '2001',
#   'and',
#   '2006,',
#   'some',
#   'of',
#   'the',
#   'council',
#   'housing',
#   'around',
#   'Blakenall',
#   'Heath',
#   'were',
#   'demolished,',
#   'including',
#   'the',
#   'whole',
#   'of',
#   'Taylor',
#   'Avenue,',
#   'the',
#   'three',
#   'late',
#   '1950s',
#   'tower',
#   'blocks,',
#   'and',
#   'large',
#   'sections',
#   'of',
#   'Walker',
#   'Road',
#   'and',
#   'Barracks',
#   'Lane'],
#  ['Clark',
#   'Elementary,',
#   'built',
#   'in',
#   '1977',
#   'and',
#   'named',
#   'for',
#   'musician',
#   'and',
#   'entertainer',
#   'Roy',
#   'Clark'],
#  ['Clark',
#   'Elementary,',
#   'built',
#   'in',
#   '1977',
#   'and',
#   'named',
#   'for',
#   'musician',
#   'and',
#   'entertainer',
#   'Roy',
#   'Clark'],
#  ['In',
#   'the',
#   'summer',
#   'of',
#   '1968,',
#   'Tate',
#   'began',
#   'The',
#   'Wrecking',
#   'Crew',
#   '(1969),',
#   'a',
#   'comedy',
#   'in',
#   'which',
#   'she',
#   'played',
#   'Freya',
#   'Carlson,',
#   'an',
#   'accident-prone',
#   'spy',
#   'who',
#   'was',
#   'also',
#   'a',
#   'romantic',
#   'interest',
#   'for',
#   'star',
#   'Dean',
#   'Martin,',
#   'playing',
#   'Matt',
#   'Helm'],
#  ['City',
#   'Council',
#   'hearing',
#   'that',
#   'his',
#   'department',
#   'was',
#   'solving',
#   '72'],
#  ['Personal',
#   'He',
#   'is',
#   'the',
#   'son',
#   'of',
#   'Buddy',
#   'Crotta',
#   'and',
#   'Tammy',
#   'Crotta'],
#  ['The',
#   'Mishnah',
#   'taught',
#   'that',
#   'where',
#   'inhabitants',
#   'customarily',
#   'ate',
#   'roasted',
#   'meat',
#   'on',
#   'Passover',
#   'night,',
#   'one',
#   'could',
#   'eat',
#   'it,',
#   'while',
#   'where',
#   'inhabitants',
#   'customarily',
#   'did',
#   'not',
#   'to',
#   'eat',
#   'it,',
#   'one',
#   'could',
#   'not',
#   'eat',
#   'it'],
#  ['Rotten',
#   'Tomatoes',
#   'gave',
#   'the',
#   'show',
#   'a',
#   '25%',
#   '"rotten"',
#   'rating',
#   'with',
#   'the',
#   "site's",
#   'critical',
#   'consensus',
#   'read,',
#   '"Implausible',
#   'and',
#   'populated',
#   'with',
#   'unlikeable',
#   'characters,',
#   'Notorious',
#   'forsakes',
#   'dramatic',
#   'credibility',
#   'in',
#   'favor',
#   'of',
#   'flash',
#   'and',
#   'fluff'],
#  ['Death',
#   'and',
#   'legacy',
#   'On',
#   '20',
#   'May',
#   '2019,',
#   'Lauda',
#   'died',
#   'in',
#   'his',
#   'sleep,',
#   'aged',
#   '70,',
#   'at',
#   'the',
#   'University',
#   'Hospital',
#   'of',
#   'Zürich,',
#   'where',
#   'he',
#   'had',
#   'been',
#   'undergoing',
#   'dialysis',
#   'treatment',
#   'for',
#   'kidney',
#   'problems,',
#   'following',
#   'a',
#   'period',
#   'of',
#   'ill',
#   'health'],
#  ['Plot',
#   'Jack',
#   '(George',
#   'Eads)',
#   'is',
#   'a',
#   'professional',
#   'poker',
#   'player',
#   'who',
#   'gets',
#   'involved',
#   'with',
#   'the',
#   'underworld',
#   '-',
#   'after',
#   'taking',
#   'a',
#   'wager',
#   'proposed',
#   'by',
#   'gambler',
#   'Duffy',
#   '(Stephen',
#   'Lang)'],
#  ['In',
#   'response',
#   'to',
#   'media',
#   'coverage,',
#   'the',
#   'ISAF',
#   'Joint',
#   'command',
#   'and',
#   'Afghan',
#   'authorities',
#   'conducted',
#   'an',
#   'investigation',
#   'into',
#   'the',
#   'events',
#   'in',
#   'Tirgiran',
#   'valley'],
#  ['The',
#   'plant',
#   'contains',
#   'vitamins,',
#   'minerals,',
#   'and',
#   'antioxidants,',
#   'as',
#   'well',
#   'as',
#   'being',
#   'useful',
#   'for',
#   'fighting',
#   'indigestion'],
#  ['Patients',
#   'cured',
#   'of',
#   'Hodgkin',
#   'lymphoma',
#   'remain',
#   'at',
#   'increased',
#   'risk',
#   'of',
#   'developing',
#   'other',
#   '(secondary)',
#   'cancers'],
#  ['Wild', 'boar', 'abounds', 'and', 'its', 'population', 'is', 'growing'],
#  ['Of',
#   'particular',
#   'note',
#   'was',
#   'that',
#   'this',
#   'was',
#   'the',
#   'second',
#   'occasion',
#   'Taylor',
#   'had',
#   'committed',
#   'such',
#   'offences,',
#   'having',
#   'already',
#   'been',
#   'forced',
#   'to',
#   'repay',
#   'for',
#   'misused',
#   'stationery',
#   'and',
#   'postage',
#   'in',
#   'April',
#   '2007'],
#  ['5)',
#   'He',
#   'did',
#   'not',
#   'receive',
#   'a',
#   'place',
#   'in',
#   'the',
#   'untouchable',
#   'chair',
#   'and',
#   'was',
#   'up',
#   'for',
#   'elimination'],
#  ['How',
#   'they',
#   'work',
#   'Although',
#   'most',
#   'commercial',
#   'powerheads',
#   'use',
#   'standard',
#   'handgun',
#   'ammunition,',
#   'such',
#   'as'],
#  ['VIDA',
#   'Review',
#   'is',
#   'edited',
#   'by',
#   'Amy',
#   'King',
#   'and',
#   'the',
#   'managing',
#   'editor',
#   'is',
#   'Marcelle',
#   'Heath'],
#  ['The',
#   "ridge's",
#   'very',
#   'far',
#   'eastern',
#   'end',
#   'forms',
#   'the',
#   'north',
#   'wall',
#   'of',
#   'the',
#   'short',
#   'canyon',
#   'connecting',
#   'the',
#   'foot',
#   'of',
#   'Seton',
#   'Lake',
#   'and',
#   'merging',
#   'with',
#   'the',
#   'canyon',
#   'of',
#   'Cayoosh',
#   'Creek',
#   'known',
#   'historically',
#   'as',
#   'Nkoomptch,',
#   'or',
#   'the',
#   'Nkoomptch',
#   '("water',
#   'crossing',
#   'over")'],
#  ['After',
#   'World',
#   'War',
#   'II,',
#   'he',
#   'taught',
#   'art',
#   'at',
#   'the',
#   'West',
#   'of',
#   'England',
#   'College',
#   'of',
#   'Art',
#   'in',
#   'Bristol:',
#   'he',
#   'became',
#   'the',
#   'head',
#   'of',
#   'painting',
#   'there',
#   'in',
#   '1960'],
#  ['After',
#   'the',
#   'WJTO',
#   'site',
#   'was',
#   'deemed',
#   'to',
#   'not',
#   'be',
#   'optimal',
#   'for',
#   'regular',
#   'operation,',
#   'WCME',
#   'signed',
#   'off',
#   'once',
#   'again',
#   'on',
#   'May',
#   '25'],
#  ['His',
#   'research',
#   'focuses',
#   'on',
#   'the',
#   'history',
#   'of',
#   'social',
#   'and',
#   'economic',
#   'development,',
#   'above',
#   'all',
#   'in',
#   '20th-century',
#   'Brazil'],
#  ['After',
#   'a',
#   'change',
#   'in',
#   'ward',
#   'boundaries',
#   'from',
#   'Parkinson',
#   'Ward',
#   'to',
#   'Calamvale',
#   'Ward',
#   'in',
#   '2016,',
#   'Owen',
#   'was',
#   'elected',
#   'as',
#   'the',
#   'inaugural',
#   'Councillor',
#   'for',
#   'Calamvale',
#   'Ward,',
#   'then',
#   're-elected',
#   'in',
#   '2020'],
#  ['On',
#   'April',
#   '28,',
#   '2009,',
#   'the',
#   'group',
#   'reunited',
#   'for',
#   'the',
#   'fifth',
#   'annual',
#   'Threadhead',
#   'Patry',
#   'in',
#   'New',
#   'Orleans,',
#   'LA',
#   'during',
#   'Jazz',
#   'Fest',
#   'daze',
#   'between,',
#   'followed',
#   'by',
#   'a',
#   'show',
#   'on',
#   'May',
#   '1',
#   'at',
#   'Carrollton',
#   'Station,',
#   'playing',
#   'to',
#   'a',
#   'sold-out',
#   'crowd'],
#  ['April',
#   '15',
#   '–',
#   'President',
#   'Nixon',
#   'requests',
#   'Congress',
#   'authorize',
#   'a',
#   'ban',
#   'of',
#   'dumping',
#   'polluted',
#   'materials',
#   'in',
#   'the',
#   'Great',
#   'Lakes'],
#  ['Ecology',
#   'Exastilithoxus',
#   'species',
#   'are',
#   'unique',
#   'among',
#   'loricariids',
#   'in',
#   'that',
#   'they',
#   'subsist',
#   'entirely',
#   'on',
#   'insect',
#   'larvae'],
#  ['During',
#   'the',
#   'war,',
#   'venereal',
#   'diseases',
#   'such',
#   'as',
#   'syphilis',
#   'and',
#   'gonorrhea',
#   'spread',
#   'at',
#   'a',
#   'rate',
#   'that',
#   'warranted',
#   'government',
#   'attention'],
#  ['In',
#   'November',
#   '2017,',
#   'Fox',
#   'News',
#   'host',
#   'Shepard',
#   'Smith',
#   'concisely',
#   'debunked',
#   'the',
#   'alleged',
#   'scandal,',
#   'infuriating',
#   'viewers',
#   'who',
#   'suggested',
#   'he',
#   'should',
#   'work',
#   'for',
#   'CNN',
#   'or',
#   'MSNBC'],
#  ['com',
#   'Category:Railway',
#   'stations',
#   'in',
#   'Uttara',
#   'Kannada',
#   'district',
#   'Category:Railway',
#   'stations',
#   'along',
#   'Konkan',
#   'Railway',
#   'line',
#   'Category:Railway',
#   'stations',
#   'opened',
#   'in',
#   '1997',
#   'Category:Karwar',
#   'railway',
#   'division'],
#  ['Srikkanth',
#   'too',
#   'scored',
#   'three',
#   'fifties',
#   'and',
#   'India',
#   'posted',
#   'century',
#   'opening',
#   'stands',
#   'against',
#   'Australia',
#   'and',
#   'in',
#   'the',
#   'final'],
#  ['Overview',
#   'Seattle',
#   'Youth',
#   'Symphony',
#   'Orchestras',
#   '(SYSO)',
#   'is',
#   'the',
#   'largest',
#   'youth',
#   'symphony',
#   'organization',
#   'and',
#   'youth',
#   'orchestra',
#   'training',
#   'program',
#   'in',
#   'the',
#   'United',
#   'States,',
#   'as',
#   'well',
#   'as',
#   'the',
#   'eighth',
#   'oldest'],
#  ['The',
#   '4th',
#   'Division',
#   'was',
#   'placed',
#   'on',
#   'the',
#   'right',
#   'wing',
#   'of',
#   'Polish',
#   'line',
#   'of',
#   'defence,',
#   'with',
#   'Nowogródzka',
#   'Cavalry',
#   'Brigade',
#   'located',
#   'to',
#   'its',
#   'right'],
#  ['Under',
#   'the',
#   'code',
#   'name',
#   'Operation',
#   'Willi,',
#   'Nazi',
#   'agents,',
#   'principally',
#   'Walter',
#   'Schellenberg,',
#   'plotted',
#   'unsuccessfully',
#   'to',
#   'persuade',
#   'the',
#   'Duke',
#   'to',
#   'leave',
#   'Portugal',
#   'and',
#   'return',
#   'to',
#   'Spain,',
#   'kidnapping',
#   'him',
#   'if',
#   'necessary'],
#  ['Despite',
#   'his',
#   'own',
#   'condition,',
#   'he',
#   'directed',
#   'abandon',
#   'ship',
#   'operations,',
#   'remaining',
#   'at',
#   'his',
#   'post',
#   'until',
#   'the',
#   'ship',
#   'went',
#   'down'],
#  ['Despite',
#   'his',
#   'own',
#   'condition,',
#   'he',
#   'directed',
#   'abandon',
#   'ship',
#   'operations,',
#   'remaining',
#   'at',
#   'his',
#   'post',
#   'until',
#   'the',
#   'ship',
#   'went',
#   'down'],
#  ['Due',
#   'to',
#   'its',
#   'large',
#   'size',
#   'and',
#   'relative',
#   'completeness,',
#   'the',
#   'species,',
#   'nicknamed',
#   '"Predator',
#   'X"',
#   'before',
#   'its',
#   'formal',
#   'description,',
#   'gained',
#   'extensive',
#   'media',
#   'coverage,',
#   'which',
#   'claimed',
#   'that',
#   'it',
#   'was',
#   '"most',
#   'fearsome',
#   'animal',
#   'ever',
#   'to',
#   'swim',
#   'in',
#   'the',
#   'oceans"'],
#  ['Due',
#   'to',
#   'its',
#   'large',
#   'size',
#   'and',
#   'relative',
#   'completeness,',
#   'the',
#   'species,',
#   'nicknamed',
#   '"Predator',
#   'X"',
#   'before',
#   'its',
#   'formal',
#   'description,',
#   'gained',
#   'extensive',
#   'media',
#   'coverage,',
#   'which',
#   'claimed',
#   'that',
#   'it',
#   'was',
#   '"most',
#   'fearsome',
#   'animal',
#   'ever',
#   'to',
#   'swim',
#   'in',
#   'the',
#   'oceans"'],
#  ['An', 'alternate', 'name', 'for', 'this', 'castle', 'is', 'Tsurushima-jō'],
#  ['Tomasi',
#   'presents',
#   'the',
#   'concept',
#   'of',
#   '"free',
#   'market',
#   'fairness"',
#   'or',
#   '"market',
#   'democracy,"',
#   'a',
#   'middle',
#   'ground',
#   'between',
#   'Friedrich',
#   'Hayek',
#   'and',
#   'John',
#   "Rawls's",
#   'ideas'],
#  ['After',
#   'the',
#   'release',
#   'of',
#   'their',
#   'second',
#   'EP,',
#   'Annihilation,',
#   'in',
#   '1999',
#   'singer',
#   'Stephanie',
#   'left',
#   'the',
#   'band',
#   'to',
#   'be',
#   'replaced',
#   'by',
#   'JJ'],
#  ['Frieder',
#   'intended',
#   'to',
#   'coach',
#   'Michigan',
#   'through',
#   'the',
#   'end',
#   'of',
#   'the',
#   '1989',
#   'NCAA',
#   'tournament'],
#  ['King',
#   'Star',
#   'King',
#   'is',
#   'an',
#   'American',
#   'adult',
#   'animated',
#   'web',
#   'series',
#   'created',
#   'by',
#   'J'],
#  ['He',
#   'much',
#   'prefers',
#   'hunting,',
#   'fishing,',
#   'and',
#   'dancing',
#   '-',
#   'a',
#   'lifestyle',
#   'that',
#   'has',
#   'put',
#   'a',
#   'considerable',
#   'financial',
#   'strain',
#   'on',
#   'the',
#   'kingdom'],
#  ['Movie',
#   'starts',
#   'at',
#   'a',
#   'concert',
#   'location',
#   'for',
#   'Los',
#   'Chicos',
#   'where',
#   'Migue,',
#   'the',
#   'oldest',
#   'member',
#   'of',
#   'the',
#   'band,',
#   'was',
#   'kidnapped',
#   'prior',
#   'to',
#   'the',
#   'show'],
#  ['In',
#   '1924,',
#   'he',
#   'was',
#   'hired',
#   'by',
#   'the',
#   'University',
#   'of',
#   'Michigan',
#   'as',
#   'an',
#   'assistant',
#   'basketball',
#   'and',
#   'football',
#   'coach'],
#  ['Born',
#   'in',
#   'Kathmandu,',
#   'Nepal,',
#   'Sharma',
#   'was',
#   'ordained',
#   'a',
#   'Roman',
#   'Catholic',
#   'priest',
#   'for',
#   'the',
#   'Society',
#   'of',
#   'Jesus',
#   'in',
#   '1968'],
#  ['Lemieux',
#   'is',
#   'also',
#   'a',
#   'Senior',
#   'Affiliated',
#   'Scholar',
#   'at',
#   'the',
#   'Mercatus',
#   'Center,',
#   'a',
#   'non-profit',
#   'think',
#   'tank',
#   'associated',
#   'with',
#   'George',
#   'Mason',
#   'University'],
#  ['Origin',
#   'of',
#   'the',
#   'name',
#   "Křesomysl's",
#   'name',
#   'is',
#   'thought',
#   'to',
#   'be',
#   'derived',
#   'from',
#   'the',
#   'old',
#   'Slavonic',
#   'words',
#   '"křesat"',
#   'meaning',
#   'to',
#   'strike',
#   'a',
#   'light',
#   'and',
#   '"mysl"',
#   'meaning',
#   'mind',
#   'or',
#   'spirit',
#   'thus',
#   'literally',
#   'the',
#   'name',
#   'should',
#   'have',
#   'meant',
#   '"lighting',
#   'the',
#   'mind"'],
#  ['After',
#   'Shankar,',
#   'Harrison',
#   'and',
#   'their',
#   'families',
#   'holidayed',
#   'together',
#   'over',
#   'Christmas',
#   '1994,',
#   'Harrison',
#   'began',
#   'compiling',
#   'a',
#   'career',
#   'retrospective,',
#   'Ravi',
#   'Shankar:',
#   'In',
#   'Celebration,',
#   'as',
#   'part',
#   'of',
#   'Angel',
#   "Records'",
#   'celebrations',
#   'for',
#   "Shankar's",
#   '75th',
#   'birthday',
#   'year'],
#  ['7', 'cm', 'bone', 'from', 'a', 'bear', 'or', 'large', 'herbivore'],
#  ['His', 'second', 'wife', 'was', 'Sadhbh', 'Ní', 'Fhaolain'],
#  ['Électricité',
#   'du',
#   'Laos',
#   '(EDL)',
#   'is',
#   'the',
#   'state',
#   'corporation',
#   'of',
#   'Laos',
#   'that',
#   'owns',
#   'and',
#   'operates',
#   'the',
#   "country's",
#   'electricity',
#   'generation,',
#   'electricity',
#   'transmission',
#   'and',
#   'electricity',
#   'distribution',
#   'assets'],
#  ['Excessively',
#   'stringent',
#   'criteria',
#   'can',
#   'prevent',
#   'rapid',
#   'care',
#   'and',
#   'transport',
#   'of',
#   'trauma',
#   'victims;',
#   'relaxed',
#   'criteria',
#   'can',
#   'result',
#   'in',
#   'the',
#   'patient',
#   'being',
#   'unnecessarily',
#   'exposed',
#   'to',
#   'the',
#   'potential',
#   'dangers',
#   'of',
#   'dangerous',
#   'weather',
#   'conditions',
#   'or',
#   'other',
#   'aviation-related',
#   'risks'],
#  ['Its',
#   'purpose',
#   'was',
#   'to',
#   'support',
#   'the',
#   'growth',
#   'of',
#   'sport',
#   'to',
#   'detract',
#   'the',
#   'youth',
#   'from',
#   'vices',
#   'and',
#   'to',
#   'promote',
#   'national',
#   'tourism',
#   'for',
#   'rural',
#   'towns'],
#  ['Plant',
#   'oils,',
#   'particularly',
#   'seed',
#   'and',
#   'nut',
#   'oils,',
#   'contain',
#   'ALA'],
#  ['Plant',
#   'oils,',
#   'particularly',
#   'seed',
#   'and',
#   'nut',
#   'oils,',
#   'contain',
#   'ALA'],
#  ['Four',
#   'days',
#   'following',
#   'the',
#   'win,',
#   'Wenger',
#   'signed',
#   'a',
#   'contract',
#   'extension',
#   'until',
#   '2019'],
#  ['Shipps',
#   'served',
#   'as',
#   'diocesan',
#   'bishop',
#   'from',
#   '1985',
#   'through',
#   '1995'],
#  ['Steinsaltz',
#   'and',
#   'his',
#   'wife',
#   'live',
#   'in',
#   'Jerusalem,',
#   'and',
#   'have',
#   'three',
#   'children',
#   'and',
#   'more',
#   'than',
#   'ten',
#   'grandchildren'],
#  ['The',
#   'man',
#   'assumes',
#   'no',
#   'position',
#   'in',
#   'favor',
#   'of',
#   'either',
#   'woman',
#   'and',
#   'instead',
#   'chooses',
#   'to',
#   'flee',
#   'from',
#   'the',
#   'conflict'],
#  ['The',
#   'Bridge',
#   'of',
#   'Remembrance',
#   'was',
#   'adopted,',
#   'while',
#   'the',
#   'hall',
#   'of',
#   'memories',
#   'idea',
#   'disappeared',
#   'due',
#   'to',
#   'lack',
#   'of',
#   'support'],
#  ['MBM',
#   'Motorsports',
#   'eventually',
#   'invested',
#   'into',
#   'TRT,',
#   'acquiring',
#   'the',
#   "company's",
#   'equipment',
#   'for',
#   'use',
#   'in',
#   'the',
#   "team's",
#   'Cup',
#   'and',
#   'NASCAR',
#   'Xfinity',
#   'Series',
#   'programs'],
#  ['While',
#   'Chandler',
#   'Harper',
#   'was',
#   'being',
#   'declared',
#   'the',
#   'winner',
#   'for',
#   'the',
#   'television',
#   'audience,',
#   'they',
#   'saw',
#   'Lew',
#   'Worsham',
#   'use',
#   'a',
#   'wedge',
#   'to',
#   'hit',
#   'an',
#   'eagle',
#   'from',
#   '104',
#   'yards',
#   'for',
#   'an',
#   'unexpected',
#   'win'],
#  ['While',
#   'Chandler',
#   'Harper',
#   'was',
#   'being',
#   'declared',
#   'the',
#   'winner',
#   'for',
#   'the',
#   'television',
#   'audience,',
#   'they',
#   'saw',
#   'Lew',
#   'Worsham',
#   'use',
#   'a',
#   'wedge',
#   'to',
#   'hit',
#   'an',
#   'eagle',
#   'from',
#   '104',
#   'yards',
#   'for',
#   'an',
#   'unexpected',
#   'win'],
#  ['It',
#   'is',
#   'red',
#   'to',
#   'brown',
#   'in',
#   'colour',
#   'with',
#   'a',
#   'darker',
#   'brown',
#   'line',
# ...
#   'John',
#   'Elmherst'],
#  ['Polio',
#   '"withered',
#   'the',
#   'body"',
#   'but',
#   'did',
#   'not',
#   'touch',
#   'the',
#   'face,',
#   'placing',
#   'it',
#   'above',
#   'afflictions',
#   'like',
#   'leprosy'],
#  ['A',
#   'brown',
#   'seaweed',
#   'named',
#   'Sargassum',
#   'muticum,',
#   'originally',
#   'from',
#   'the',
#   'Pacific',
#   '(Japan)',
#   'was',
#   'discovered',
#   'on',
#   '15',
#   'March',
#   '1995',
#   'in',
#   'Strangford',
#   'Lough',
#   'at',
#   "Paddy's",
#   'Point'],
#  ['Claudia',
#   'Koonz,',
#   'Professor',
#   'of',
#   'History,',
#   'Duke',
#   'University:',
#   'Ethnic',
#   'panic',
#   'and',
#   'the',
#   'headscarf',
#   'controversies',
#   'in',
#   'Europe,',
#   '1945-2004'],
#  ['Back',
#   'at',
#   'the',
#   'jewelry',
#   'store,',
#   'Bill',
#   'shows',
#   'the',
#   'police',
#   'detectives',
#   'that',
#   'Mr'],
#  ['The',
#   'volume',
#   'in',
#   'the',
#   'vicinity',
#   'of',
#   'the',
#   'central',
#   'star',
#   'is',
#   'often',
#   'filled',
#   'with',
#   'a',
#   'very',
#   'hot',
#   '(coronal)',
#   'gas',
#   'having',
#   'the',
#   'temperature',
#   'of',
#   'about',
#   '1,000,000',
#   'K'],
#  ['Faehlmann',
#   'brought',
#   'attention',
#   'to',
#   'the',
#   'Estonian',
#   'folklore',
#   'of',
#   'Kalevipoeg,',
#   'which',
#   'after',
#   'his',
#   'death',
#   'has',
#   'become',
#   'the',
#   'Estonian',
#   'national',
#   'epic',
#   'by',
#   'the',
#   'efforts',
#   'of',
#   'another',
#   'Estophile,',
#   'Friedrich',
#   'Reinhold',
#   'Kreutzwald'],
#  ['Subsequently,',
#   'an',
#   'Internet',
#   'troll',
#   'on',
#   '4chan',
#   'posted',
#   'an',
#   'edited',
#   'version',
#   'of',
#   'the',
#   'cartoon',
#   'in',
#   'which',
#   'the',
#   'Eye',
#   'of',
#   'Providence',
#   'has',
#   'been',
#   'replaced',
#   'by',
#   'an',
#   'anti-Semitic',
#   'caricature',
#   'of',
#   'a',
#   'Jewish',
#   'man',
#   '("Happy',
#   'Merchant"',
#   'by',
#   'A'],
#  ['This',
#   'included',
#   'a',
#   'contribution',
#   'of',
#   'wheat',
#   'flour',
#   'valued',
#   'at',
#   'US$55,000'],
#  ['The',
#   'sample',
#   'is',
#   'however',
#   'confirmed',
#   'to',
#   'belong',
#   'to',
#   'haplogroup',
#   'R:',
#   '16263',
#   'is',
#   'a',
#   'critical',
#   'marker',
#   'for',
#   'haplogroup',
#   'R'],
#  ['1586)',
#   'Lope',
#   'de',
#   'Rueda,',
#   'Spanish',
#   'dramatist',
#   'and',
#   'author',
#   '(d'],
#  ['It',
#   'is',
#   'noted',
#   'for',
#   'being',
#   'one',
#   'of',
#   'the',
#   'last',
#   'locations',
#   'in',
#   'the',
#   'Rio',
#   'Grande',
#   'Valley',
#   'with',
#   'a',
#   'profuse',
#   'grove',
#   'of',
#   'sabal',
#   'palms,',
#   'an',
#   'edible-heart-bearing',
#   'palm',
#   'much',
#   'prized',
#   'by',
#   'pre-Hispanic',
#   'inhabitants',
#   'and',
#   'noted',
#   'by',
#   'early',
#   'explorers'],
#  ['Career',
#   'Leaving',
#   'Collurian',
#   'he',
#   'worked',
#   'as',
#   'a',
#   'porter',
#   'at',
#   'Penzance',
#   'railway',
#   'station',
#   'for',
#   'the',
#   'Great',
#   'Western',
#   'Railway',
#   'and',
#   'with',
#   'the',
#   'free',
#   'pass,',
#   'that',
#   'was',
#   'part',
#   'of',
#   'his',
#   'entitlement,',
#   'he',
#   'travelled',
#   'to',
#   'London',
#   'to',
#   'search',
#   'for',
#   'a',
#   'post',
#   'as',
#   'a',
#   'journalist'],
#  ['Endemic',
#   'to',
#   'China,',
#   'the',
#   'Yarkand',
#   'hare',
#   'is',
#   'restricted',
#   'to',
#   'the',
#   'Tarim',
#   'Basin',
#   'in',
#   'Southern',
#   'Xinjiang,',
#   'China'],
#  ['Despite',
#   'his',
#   'competitiveness',
#   'and',
#   'fiery',
#   'temper,',
#   'he',
#   'showed',
#   'far',
#   'more',
#   'understanding',
#   'and',
#   'empathy',
#   'towards',
#   'children,',
#   'amateur',
#   'and',
#   'special',
#   'needs',
#   'chefs',
#   '(notably',
#   'Christine',
#   'Hà',
#   'on',
#   'MasterChef),',
#   'although',
#   'he',
#   'continued',
#   'to',
#   'offer',
#   'constructive',
#   'criticism'],
#  ['fr/ark:/12148/bpt6k6538682n',
#   'Les',
#   'Modes,',
#   'revue',
#   'mensuelle',
#   'illustrée',
#   'des',
#   'Arts',
#   'décoratifs',
#   'appliqués',
#   'à',
#   'la',
#   'femme],',
#   'February',
#   '1906</ref>',
#   'First',
#   'World',
#   'War',
#   'When',
#   'war',
#   'broke',
#   'out',
#   'in',
#   '1914,',
#   'Boutet',
#   'de',
#   'Monvel',
#   'was',
#   'called',
#   'up',
#   'as',
#   'a',
#   'reservist'],
#  ['Mobile',
#   'disco',
#   'and',
#   'lights',
#   'with',
#   'their',
#   'contemporary',
#   'dance',
#   'tunes',
#   'dominates',
#   'the',
#   'landscape'],
#  ['On',
#   'April',
#   '17,',
#   '1963,',
#   'President',
#   'Kennedy',
#   'signed',
#   'National',
#   'Security',
#   'Action',
#   'Memorandum',
#   '235',
#   '(NSAM',
#   '235)',
#   'authorizing:',
#   'The',
#   'deployments',
#   'of',
#   'Project',
#   '112',
#   'agents',
#   'and',
#   'field',
#   'testing',
#   'commenced',
#   'immediately',
#   'after',
#   'the',
#   'memorandum',
#   'was',
#   'signed'],
#  ['It',
#   'was',
#   'discovered',
#   'that',
#   'the',
#   'sloping',
#   'earthen',
#   'rampart',
#   'could',
#   'be',
#   'defended',
#   'against',
#   'escalade',
#   'and',
#   'was',
#   'also',
#   'much',
#   'more',
#   'resistant',
#   'to',
#   'cannon',
#   'fire',
#   'than',
#   'the',
#   'curtain',
#   'wall',
#   'it',
#   'had',
#   'replaced'],
#  ['Local',
#   'newscasts,',
#   'which',
#   'air',
#   'during',
#   'the',
#   'lunch',
#   'and',
#   'supper',
#   'hours,',
#   'now',
#   'also',
#   'carry',
#   'the',
#   'Téléjournal',
#   'name,',
#   'i'],
#  ['Simmons',
#   'led',
#   'the',
#   "A's",
#   'to',
#   'the',
#   'AL',
#   'pennant',
#   'in',
#   '1929',
#   'as',
#   'Philadelphia',
#   'went',
#   '104–46,',
#   'finishing',
#   '18',
#   'games',
#   'ahead',
#   'of',
#   'the',
#   'New',
#   'York',
#   'Yankees'],
#  ['"',
#   ':',
#   'Spanish',
#   'Prime',
#   'Minister',
#   'Mariano',
#   'Rajoy',
#   'Brey',
#   'expressed',
#   'the',
#   'sadness',
#   'of',
#   'the',
#   'Government',
#   'of',
#   'Spain',
#   'upon',
#   'learning',
#   'of',
#   'the',
#   'demise',
#   'of',
#   'Lee',
#   'Kuan',
#   'Yew'],
#  ['With',
#   'regular',
#   'left',
#   'back',
#   'Charlie',
#   'Taylor',
#   'pushed',
#   'forward',
#   'into',
#   'an',
#   'attacking',
#   'left',
#   'wing',
#   'position,',
#   'during',
#   '2015',
#   'Berardi',
#   'became',
#   'a',
#   'regular',
#   'fixture',
#   'in',
#   'the',
#   'left-back',
#   'position',
#   'for',
#   'Leeds'],
#  ['Eulalia',
#   'Szwajkowska',
#   '(born',
#   '12',
#   'February',
#   '1932)',
#   'is',
#   'a',
#   'Polish',
#   'sprinter'],
#  ['He',
#   'fell',
#   'into',
#   'alcoholism',
#   'and',
#   'was',
#   'unable',
#   'to',
#   're-establish',
#   'fiscal',
#   'solvency',
#   'despite',
#   'winning',
#   'partial',
#   'reimbursement',
#   'from',
#   'the',
#   'federal',
#   'government',
#   'in',
#   '1823'],
#  ['From',
#   '1986',
#   'to',
#   '1989,',
#   'he',
#   'attended',
#   'Harvard',
#   'University',
#   'as',
#   'an',
#   'exchange',
#   'scholar',
#   'in',
#   'linguistics'],
#  ['Costigan',
#   'introduced',
#   'the',
#   'use',
#   'of',
#   'massage',
#   'machines',
#   'to',
#   'Henlow',
#   'Grange',
#   'in',
#   '1960'],
#  ['While',
#   'she',
#   'and',
#   'her',
#   'son',
#   'were',
#   'working',
#   'in',
#   'her',
#   'vegetable',
#   'garden,',
#   'Irvin',
#   'approached',
#   'them,',
#   'and',
#   'demanded',
#   'the',
#   'return',
#   'of',
#   'a',
#   'pair',
#   'of',
#   'pliers'],
#  ['Here',
#   'the',
#   'weft',
#   'was',
#   'held',
#   'in',
#   'the',
#   'beard',
#   'and',
#   'carried',
#   'up',
#   'to',
#   'the',
#   'next',
#   'course',
#   'where',
#   'two',
#   'threads',
#   'were',
#   'passed',
#   'together'],
#  ['consumers’',
#   'lack',
#   'of',
#   'financial',
#   'education,',
#   'Dvorkin',
#   'announced',
#   'in',
#   '2013',
#   'that',
#   'he',
#   'was',
#   'stepping',
#   'down',
#   'as',
#   'Consolidated',
#   'Credit’s',
#   'spokesperson',
#   'to',
#   'launch',
#   'Debt'],
#  ['They',
#   'present',
#   'evidence',
#   'for',
#   'the',
#   'primacy',
#   'of',
#   'natural',
#   'and',
#   'sexual',
#   'selection',
#   'over',
#   'genetic',
#   'drift',
#   'in',
#   'driving',
#   'speciation'],
#  ['The',
#   'surcharge',
#   'has',
#   'been',
#   'reduced',
#   'by',
#   'law',
#   'to',
#   '5%',
#   'in',
#   'Victoria',
#   'following',
#   'recommendations',
#   'made',
#   'by',
#   'the',
#   'Taxi',
#   'Industry',
#   'Inquiry',
#   'and',
#   'a',
#   'further',
#   'review',
#   'of',
#   'the',
#   'surcharge',
#   'in',
#   'that',
#   'State',
#   'may',
#   'lead',
#   'to',
#   'the',
#   'figure',
#   'being',
#   'set',
#   'at',
#   'well',
#   'below',
#   '5%'],
#  ['National',
#   'Historic',
#   'Site',
#   'The',
#   'internment',
#   'camp',
#   'site',
#   'was',
#   'listed',
#   'on',
#   'the',
#   'National',
#   'Register',
#   'of',
#   'Historic',
#   'Places',
#   'on',
#   'July',
#   '10,',
#   '1979'],
#  ['PFOS',
#   'is',
#   'a',
#   'fluorosurfactant',
#   'that',
#   'lowers',
#   'the',
#   'surface',
#   'tension',
#   'of',
#   'water',
#   'more',
#   'than',
#   'that',
#   'of',
#   'hydrocarbon',
#   'surfactants'],
#  ['The',
#   'treasure',
#   'consists',
#   'of',
#   'six',
#   'silver',
#   'openwork',
#   'disc',
#   'brooches,',
#   'five',
#   'made',
#   'entirely',
#   'of',
#   'silver',
#   'and',
#   'one',
#   'composed',
#   'of',
#   'silver',
#   'and',
#   'copper',
#   'alloy'],
#  ['While',
#   'this',
#   'was',
#   'formally',
#   '"advice"',
#   'from',
#   'the',
#   'Senate',
#   'to',
#   'a',
#   'magistrate',
#   'stating',
#   'the',
#   "Senate's",
#   'position',
#   'on',
#   'some',
#   'topic,',
#   'the',
#   'senatus',
#   'consulta',
#   'were',
#   'usually',
#   'obeyed',
#   'by',
#   'the',
#   'magistrates'],
#  ['multiculturalism',
#   'and',
#   'immigration',
#   'led',
#   'to',
#   'adaptation',
#   'problems',
#   'such',
#   'as',
#   'school',
#   'drop-out,',
#   'unemployment,',
#   'and',
#   'high',
#   'crime',
#   'rates'],
#  ['Wade',
#   'left',
#   'the',
#   'buffalo',
#   'soldiers',
#   'with',
#   'his',
#   'promotion',
#   'to',
#   'colonel',
#   'of',
#   'the',
#   '5th',
#   'Cavalry',
#   'Regiment',
#   '(United',
#   'States)',
#   'on',
#   'April',
#   '21,',
#   '1887'],
#  ['black-legged',
#   'parrot',
#   'Category:Birds',
#   'of',
#   'the',
#   'Amazon',
#   'Basin',
#   'Category:Birds',
#   'of',
#   'the',
#   'Peruvian',
#   'Amazon',
#   'Category:Birds',
#   'of',
#   'the',
#   'Bolivian',
#   'Amazon',
#   'black-legged',
#   'parrot'],
#  ['The',
#   'most',
#   'user',
#   'stable',
#   'and',
#   'friendly',
#   'firmware',
#   'at',
#   'present',
#   'is',
#   'the',
#   'V10P_00',
#   'and',
#   'V10F_00',
#   'which',
#   'are',
#   'both',
#   'open',
#   'and',
#   'not',
#   'locked',
#   'to',
#   'any',
#   'firmware',
#   'version,',
#   'it',
#   'is',
#   'now',
#   'possible',
#   'to',
#   'unlock',
#   'the',
#   'handset',
#   'to',
#   'use',
#   'on',
#   'any',
#   'network'],
#  ['The',
#   'auditorium',
#   'also',
#   'occasionally',
#   'also',
#   'doubles',
#   'as',
#   'a',
#   'gym',
#   'for',
#   'special',
#   'sports',
#   'events'],
#  ['Editions',
#   'There',
#   'is',
#   'a',
#   'freeware',
#   'and',
#   'a',
#   'shareware',
#   'edition',
#   'of',
#   'ProgDVB;',
#   'the',
#   'shareware',
#   'edition',
#   'adds:',
#   'Picture-in-picture',
#   'support',
#   'Recorder',
#   'and',
#   'Scheduler',
#   'Digital',
#   'Satellite',
#   'Equipment',
#   'Control',
#   'Starting',
#   'with',
#   'version',
#   '5'],
#  ['Specialising',
#   'in',
#   'fish',
#   'and',
#   'seafood',
#   'dishes',
#   'it',
#   'is',
#   'named',
#   '‘The',
#   'Oyster',
#   'Club’',
#   'and',
#   'the',
#   'Head',
#   'Chef',
#   'is',
#   'Rosanne',
#   'Moseley',
#   'who',
#   'worked',
#   'for',
#   'Stokes',
#   'at',
#   '‘Adam’s’',
#   'from',
#   'February',
#   '2014',
#   'until',
#   'she',
#   'took',
#   'up',
#   'her',
#   'post',
#   'at',
#   'the',
#   'new',
#   'restaurant'],
#  ['The',
#   'cow',
#   'is',
#   'considered',
#   '[poly-estrous],',
#   'which',
#   'means',
#   'that',
#   'she',
#   'will',
#   'continue',
#   'to',
#   'undergo',
#   'regular',
#   'estrous',
#   'cycles',
#   'until',
#   'death',
#   'unless',
#   'the',
#   'cycle',
#   'is',
#   'interrupted',
#   'by',
#   'a',
#   'pregnancy'],
#  ['The',
#   'hymn',
#   'was',
#   'printed',
#   'in',
#   'the',
#   'Erfurt',
#   'Enchiridion',
#   'in',
#   '1524,',
#   'and',
#   'was',
#   'also',
#   'published',
#   'the',
#   'same',
#   'year',
#   'in',
#   "Walter's",
#   'choral',
#   'Wittenberg',
#   'hymnal,',
#   'Eyn',
#   'geystlich',
#   'Gesangk',
#   'Buchleyn'],
#  ['1889',
#   '–',
#   'The',
#   'first',
#   'long-distance',
#   'electric',
#   'power',
#   'transmission',
#   'line',
#   'in',
#   'the',
#   'United',
#   'States',
#   'is',
#   'completed,',
#   'running',
#   'between',
#   'a',
#   'generator',
#   'at',
#   'Willamette',
#   'Falls',
#   'and',
#   'downtown',
#   'Portland,',
#   'Oregon'],
#  ['Total',
#   'polyethylene',
#   'weight',
#   'ranged',
#   'anywhere',
#   'from',
#   '7%',
#   'to',
#   '88%',
#   'of',
#   'total',
#   'weight',
#   'for',
#   'individual',
#   'devices',
#   'and',
#   'made',
#   'up',
#   '52%',
#   'of',
#   'total',
#   'weight',
#   'for',
#   'the',
#   'combined',
#   'average',
#   'of',
#   'the',
#   'seven',
#   'devices'],
#  ['However,',
#   'in',
#   'the',
#   '1990s',
#   'a',
#   'series',
#   'of',
#   'unrelated',
#   'food',
#   'crises',
#   'created',
#   'consumer',
#   'apprehension',
#   'about',
#   'food',
#   'safety',
#   'in',
#   'general',
#   'and',
#   'eroded',
#   'public',
#   'trust',
#   'in',
#   'government',
#   'oversight'],
#  ['The',
#   'windmills',
#   'for',
#   'which',
#   'the',
#   'point',
#   'were',
#   'named',
#   'were',
#   'used',
#   'by',
#   'two',
#   'brothers',
#   'to',
#   'pump',
#   'seawater',
#   'into',
#   'vats',
#   'to',
#   'be',
#   'used',
#   'for',
#   'harvesting',
#   'salt'],
#  ['Later',
#   'in',
#   'their',
#   'careers,',
#   'a',
#   'cutter,',
#   'another',
#   'yawl,',
#   'and',
#   'another',
#   'dinghy',
#   'were',
#   'added'],
#  ['Mendenhall,',
#   'became',
#   'a',
#   'professor',
#   'of',
#   'history',
#   'at',
#   'Yale',
#   'University,',
#   'and',
#   'served',
#   'as',
#   'the',
#   'sixth',
#   'president',
#   'of',
#   'Smith',
#   'College,',
#   'her',
#   'alma',
#   'mater'],
#  ['Some',
#   '150',
#   'of',
#   'the',
#   'tunes',
#   'were',
#   'drawn',
#   'from',
#   'Tom',
#   'Kennedy,',
#   'a',
#   'blind',
#   'piper',
#   'living',
#   'on',
#   'the',
#   'Dingle',
#   'Peninsula'],
#  ['The',
#   'gun',
#   'turret',
#   'was',
#   'shaped',
#   'like',
#   'a',
#   'rectangle',
#   'with',
#   'rounded',
#   'corners'],
#  ['Achievements',
#   'BWF',
#   'International',
#   'Challenge/Series',
#   "Men's",
#   'doubles',
#   'Mixed',
#   'doubles',
#   'BWF',
#   'International',
#   'Challenge',
#   'tournament',
#   'BWF',
#   'International',
#   'Series',
#   'tournament',
#   'BWF',
#   'Future',
#   'Series',
#   'tournament',
#   'References',
#   'External',
#   'links',
#   'Category:Living',
#   'people',
#   'Category:1995',
#   'births',
#   'Category:Indian',
#   'male',
#   'badminton',
#   'players'],
#  ['It',
#   'then',
#   'slowed',
#   'owing',
#   'to',
#   'the',
#   'effects',
#   'of',
#   'the',
#   'Great',
#   'Depression',
#   'and',
#   'many',
#   'areas',
#   'experienced',
#   'a',
#   'net',
#   'emigration'],
#  ['Side',
#   'effects',
#   'The',
#   'most',
#   'common',
#   'adverse',
#   'reactions',
#   'were',
#   'headache,',
#   'infusion',
#   'site',
#   'reactions',
#   'and',
#   'diarrhea'],
#  ['Elaine',
#   'Lefkowitz',
#   '(Dinah',
#   'Manoff)—daughter',
#   'of',
#   "Danny's",
#   'mob',
#   'under-boss,',
#   'her',
#   'obnoxious,',
#   'pushy',
#   'personality',
#   'makes',
#   'a',
#   'coerced',
#   'marriage',
#   'painful',
#   'for',
#   'Danny',
#   'at',
#   'first'],
#  ['There,',
#   'a',
#   'counterattack',
#   'was',
#   'planned',
#   'and',
#   'Manuel',
#   'Flores',
#   'was',
#   'a',
#   'member',
#   'of',
#   'the',
#   'party',
#   'that',
#   'pursued',
#   'the',
#   'army',
#   'of',
#   'Ráfael',
#   'Vásquez'],
#  ['Ralph',
#   'kidnapped',
#   'Kay',
#   'after',
#   'she',
#   'returned',
#   'from',
#   'chaperoning',
#   'at',
#   'the',
#   'prom,',
#   'and',
#   'tied',
#   'her',
#   'up',
#   'in',
#   'a',
#   'motel',
#   'room'],
#  ['The',
#   'New',
#   'York',
#   'Stock',
#   'Exchange',
#   'and',
#   'the',
#   'Chicago',
#   'Mercantile',
#   'Exchange',
#   'introduced',
#   'the',
#   'concept',
#   'of',
#   'a',
#   'circuit',
#   'breaker'],
#  ['A',
#   'brick',
#   'parapet',
#   'with',
#   'stone',
#   'trim',
#   'caps',
#   'the',
#   'structure,',
#   'and',
#   'decorative',
#   'brickwork',
#   'descends',
#   'from',
#   'the',
#   'cornice',
#   'on',
#   'the',
#   'corners'],
#  ['Allomorphy',
#   'is',
#   'common;',
#   'often,',
#   'a',
#   'single',
#   'affix',
#   'with',
#   'have',
#   'multiple',
#   'phonetic',
#   'realizations',
#   'due',
#   'to',
#   'stress',
#   'structure',
#   'or',
#   'the',
#   'phonology',
#   'of',
#   'the',
#   'word',
#   'it',
#   'is',
#   'being',
#   'added',
#   'to'],
#  ['The',
#   'lyrics',
#   'suggest',
#   'someone',
#   'down',
#   'on',
#   'his',
#   'luck,',
#   'standing',
#   'at',
#   'an',
#   'airport',
#   'fence',
#   'and',
#   'observing',
#   'the',
#   'thunderous',
#   'takeoff',
#   'of',
#   'a',
#   'Boeing',
#   '707',
#   'jetliner'],
#  ['Every',
#   'five',
#   'years',
#   'since',
#   '1997,',
#   'the',
#   'Klamath-Lake',
#   'District',
#   'conducts',
#   'a',
#   'pileated',
#   'woodpecker',
#   'survey',
#   'in',
#   'the',
#   'Sun',
#   'Pass',
#   'State',
#   'Forest',
#   'to',
#   'monitor',
#   'the',
#   'health',
#   'of',
#   'the',
#   'wildlife',
#   'habitat'],
#  ['Pat:',
#   'A',
#   'patient',
#   'suffering',
#   'from',
#   'fibroids',
#   'and',
#   'uterus',
#   'cancer'],
#  ...]

# %%
for i in tqdm(range(1,21,5)):
    print(i)
# Out:
# 100%|██████████| 4/4 [00:00<00:00, 4540.52it/s]
# 1
# 6
# 11
# 16

# %%
text_preprocessing(df_AP1_True[1])
# Out:
# 'members of the commission and the county mayor are elected to four year terms'

# %%
import re
import numpy as np  
from tqdm import tqdm
def text_preprocessing(
    text:list,
    punctuations = r'''!()-[]{};:'"\,<>./?@#$%^&*_“~''',
    stop_words=['and', 'a', 'is', 'the', 'in', 'be', 'will']
    )->list:
    """
    A method to preproces text
    """
    for x in text.lower(): 
        if x in punctuations: 
            text = text.replace(x, " ")

    # Removing words that have numbers in them
    text = re.sub(r'\w*\d\w*', '', text)

    # Removing digits
    text = re.sub(r'[0-9]+', '', text)

    # Cleaning the whitespaces
    text = re.sub(r'\s+', ' ', text).strip()

    # Setting every word to lower
    text = text.lower()

    # Converting all our text to a list 
#     text = text.split(' ')

    # Droping empty strings
#     text = [x for x in text if x!='']

    # Droping stop words
#     text = [x for x in text if x not in stop_words]

    return text

# %%
frames = [df_AP700_random_True, df_AP600_random_True, df_AP500_random_True, df_AP400_random_True, df_AP300_random_True, df_AP200_random_True, df_AP100_random_True]
frames = [df_AP700_random_False, df_AP600_random_False, df_AP500_random_False, df_AP400_random_False, df_AP300_random_False, df_AP200_random_False, df_AP100_random_False]
result = pd.concat(reversed(frames))
result
# Out:
#   Max Context  KL Score AP  COS Score AP
# 0     BERT100     0.763744      0.712988
# 1      EMP100     0.542697      0.727667
# 0     BERT200     0.763760      0.712988
# 1      EMP200     0.542695      0.727667
# 0     BERT300     0.763761      0.712988
# 1      EMP300     0.542694      0.727667
# 0     BERT400     0.763764      0.712988
# 1      EMP400     0.542692      0.727667
# 0     BERT500     0.763761      0.712988
# 1      EMP500     0.542692      0.727667
# 0     BERT600     0.763738      0.712988
# 1      EMP600     0.542691      0.727667
# 0     BERT700     0.763728      0.712988
# 1      EMP700     0.542692      0.727667

# %%
df_AP700_random_False
# Out:
#   Max Context  KL Score AP  COS Score AP
# 0     BERT700     0.763728      0.712988
# 1      EMP700     0.542692      0.727667

# %%
with open('../data_shared/df_curated100_diag_False.pickle', 'rb') as f:
    df_curated100_diag_False = pickle.load(f)

with open('../data_shared/df_curated100_diag_True.pickle', 'rb') as f:
    df_curated100_diag_True = pickle.load(f)
    
with open('../data_shared/df_curated200_diag_False.pickle', 'rb') as f:
    df_curated200_diag_False = pickle.load(f)

with open('../data_shared/df_curated200_diag_True.pickle', 'rb') as f:
    df_curated200_diag_True = pickle.load(f)

# %%
df_curated100_diag_True.compare(df_curated200_diag_True)
# Out:
#      bert KL score               bert COS score                  \
#               self        other            self           other
# 0       481.604614   481.604492             NaN             NaN
# 1       505.810303   505.810425  tensor(0.7130)  tensor(0.7130)
# 2       361.076416   361.076294  tensor(0.8394)  tensor(0.8394)
# 3       570.493286   570.492981  tensor(0.7287)  tensor(0.7287)
# 4       696.685730   696.685791  tensor(0.5654)  tensor(0.5654)
# ...            ...          ...             ...             ...
# 2765   1581.278564  1581.279175  tensor(0.6537)  tensor(0.6537)
# 2766    476.659668   476.658936             NaN             NaN
# 2767   1020.010010  1020.010620             NaN             NaN
# 2768    496.043884   496.043640  tensor(0.6218)  tensor(0.6218)
# 2769   1040.529297  1040.529175             NaN             NaN
#
#      empirical KL score
#                    self       other
# 0              0.860031    0.860001
# 1              0.491299    0.491291
# 2              2.680397    2.680443
# 3              4.122570    4.122612
# 4              1.545025    1.545029
# ...                 ...         ...
# 2765         116.322227  116.323227
# 2766         135.241302  135.237289
# 2767           9.908092    9.908138
# 2768          98.863403   98.862045
# 2769           0.273491    0.273499
#
# [2760 rows x 6 columns]

# %%
def import_baroni(neg_file, pos_file):
    results_neg_file, results_pos_file = [], []
    with open(neg_file) as f:
        for line in f:
            results_neg_file.append(line.replace("-n", "").replace("\n", "").strip("").split("\t"))
    with open(pos_file) as f:
        for line in f:
            results_pos_file.append(line.replace("-n", "").replace("\n", "").strip("").split("\t"))
    baroni = sum(results_neg_file, []) + sum(results_pos_file, [])
    print(baroni)
    baroni_set = set(baroni)

    return results_neg_file, results_pos_file, baroni, baroni_set

# %%
neg_file = "../data_shared/eacl2012-data/negative-examples.txtinput"
pos_file = "../data_shared/eacl2012-data/positive-examples.txtinput"
results_neg_file, results_pos_file, baroni, baroni_set = import_baroni(neg_file, pos_file)
# Out:
# ['adjective', 'document', 'adrenaline', 'integer', 'adult', 'anaesthetist', 'adult', 'gent', 'adult', 'instrument', 'adult', 'librarian', 'adult', 'nanny', 'adult', 'physician', 'adult', 'tree', 'advocate', 'spokeswoman', 'affection', 'organization', 'agony', 'adult', 'agony', 'anaesthetist', 'agony', 'decoration', 'agreement', 'rector', 'aircraft', 'astronomy', 'aircraft', 'biplane', 'aircraft', 'bomber', 'aircraft', 'insect', 'aircraft', 'letter', 'aircrew', 'playlist', 'airman', 'sociology', 'airplane', 'bomber', 'airplane', 'chalet', 'alcohol', 'container', 'alcohol', 'hotel', 'alcohol', 'liqueur', 'alcohol', 'psychology', 'alga', 'garment', 'algebra', 'athlete', 'algebra', 'potato', 'alloy', 'bronze', 'ancestor', 'motto', 'anger', 'lizard', 'animal', 'affidavit', 'animal', 'artillery', 'animal', 'bitterness', 'animal', 'bug', 'animal', 'bull', 'animal', 'calf', 'animal', 'cameraman', 'animal', 'chick', 'animal', 'color', 'animal', 'crow', 'animal', 'diabetes', 'animal', 'dorm', 'animal', 'feeder', 'animal', 'funeral', 'animal', 'furniture', 'animal', 'gasoline', 'animal', 'hawk', 'animal', 'immigration', 'animal', 'invertebrate', 'animal', 'kangaroo', 'animal', 'kestrel', 'animal', 'kickoff', 'animal', 'lamb', 'animal', 'lion', 'animal', 'maggot', 'animal', 'magpie', 'animal', 'organization', 'animal', 'panda', 'animal', 'psychotherapy', 'animal', 'python', 'animal', 'receptionist', 'animal', 'reindeer', 'animal', 'reptile', 'animal', 'robin', 'animal', 'ship', 'animal', 'snake', 'animal', 'toad', 'animal', 'turkey', 'animal', 'vertebrate', 'animal', 'vial', 'animal', 'waterfowl', 'anniversary', 'lingerie', 'anorexia', 'fixture', 'ant', 'spokeswoman', 'antibiotic', 'penicillin', 'antibody', 'nematode', 'apathy', 'magnitude', 'apathy', 'mammal', 'ape', 'book', 'apprehension', 'bird', 'apprehension', 'offspring', 'apprehension', 'skating', 'aqueduct', 'pianist', 'archbishop', 'garment', 'area', 'cameraman', 'aristocrat', 'baroness', 'aristocrat', 'relative', 'armament', 'cannon', 'armament', 'people', 'army', 'waterfowl', 'art', 'beard', 'art', 'cost', 'art', 'serpent', 'artillery', 'cannon', 'artist', 'beverage', 'artwork', 'integer', 'asp', 'invertebrate', 'asp', 'workplace', 'asthma', 'motel', 'asthma', 'tissue', 'athlete', 'cricketer', 'athlete', 'dancer', 'athlete', 'filly', 'athlete', 'spokeswoman', 'athlete', 'swimmer', 'attack', 'animal', 'attitude', 'bookshop', 'auto', 'trait', 'autobiography', 'feeling', 'badminton', 'kettle', 'bag', 'collagen', 'bag', 'review', 'bag', 'rucksack', 'bamboo', 'bear', 'ban', 'performer', 'baritone', 'adrenaline', 'barrier', 'fender', 'barrier', 'gate', 'barrier', 'psychotherapy', 'bead', 'decoration', 'bead', 'performer', 'bear', 'webcam', 'bed', 'insect', 'beech', 'artillery', 'beer', 'machine', 'beer', 'railway', 'benzene', 'cottage', 'benzene', 'tent', 'berry', 'diplomat', 'beverage', 'art', 'beverage', 'beer', 'beverage', 'list', 'beverage', 'panda', 'beverage', 'sherry', 'beverage', 'strut', 'beverage', 'symbol', 'beverage', 'tea', 'beverage', 'vehicle', 'beverage', 'whisky', 'bib', 'herb', 'bike', 'gate', 'bin', 'mail', 'binder', 'disease', 'binder', 'notary', 'binder', 'performer', 'bingo', 'fluid', 'biochemistry', 'enzymology', 'biplane', 'ale', 'bird', 'chick', 'bird', 'cookie', 'bird', 'disorder', 'bird', 'eagle', 'bird', 'entertainer', 'bird', 'freeway', 'bird', 'hawk', 'bird', 'penguin', 'bird', 'seabird', 'bird', 'snake', 'bird', 'turkey', 'bird', 'woman', 'bird', 'woodpecker', 'bishop', 'cardinal', 'bishop', 'valley', 'boar', 'spokesperson', 'boat', 'chair', 'boat', 'cost', 'boat', 'dinghy', 'boat', 'pontoon', 'boat', 'reformer', 'bonnet', 'hamster', 'bonnet', 'vehicle', 'book', 'fruit', 'bookmark', 'performer', 'border', 'feeling', 'bottle', 'throne', 'bourgeoisie', 'association', 'bourgeoisie', 'fabric', 'bowling', 'clothing', 'bread', 'toast', 'breeze', 'heroism', 'breeze', 'physiology', 'buggy', 'garment', 'building', 'castle', 'building', 'craftsman', 'building', ' ...

# %%
results_neg_file
# Out:
# [['adjective', 'document'],
#  ['adrenaline', 'integer'],
#  ['adult', 'anaesthetist'],
#  ['adult', 'gent'],
#  ['adult', 'instrument'],
#  ['adult', 'librarian'],
#  ['adult', 'nanny'],
#  ['adult', 'physician'],
#  ['adult', 'tree'],
#  ['advocate', 'spokeswoman'],
#  ['affection', 'organization'],
#  ['agony', 'adult'],
#  ['agony', 'anaesthetist'],
#  ['agony', 'decoration'],
#  ['agreement', 'rector'],
#  ['aircraft', 'astronomy'],
#  ['aircraft', 'biplane'],
#  ['aircraft', 'bomber'],
#  ['aircraft', 'insect'],
#  ['aircraft', 'letter'],
#  ['aircrew', 'playlist'],
#  ['airman', 'sociology'],
#  ['airplane', 'bomber'],
#  ['airplane', 'chalet'],
#  ['alcohol', 'container'],
#  ['alcohol', 'hotel'],
#  ['alcohol', 'liqueur'],
#  ['alcohol', 'psychology'],
#  ['alga', 'garment'],
#  ['algebra', 'athlete'],
#  ['algebra', 'potato'],
#  ['alloy', 'bronze'],
#  ['ancestor', 'motto'],
#  ['anger', 'lizard'],
#  ['animal', 'affidavit'],
#  ['animal', 'artillery'],
#  ['animal', 'bitterness'],
#  ['animal', 'bug'],
#  ['animal', 'bull'],
#  ['animal', 'calf'],
#  ['animal', 'cameraman'],
#  ['animal', 'chick'],
#  ['animal', 'color'],
#  ['animal', 'crow'],
#  ['animal', 'diabetes'],
#  ['animal', 'dorm'],
#  ['animal', 'feeder'],
#  ['animal', 'funeral'],
#  ['animal', 'furniture'],
#  ['animal', 'gasoline'],
#  ['animal', 'hawk'],
#  ['animal', 'immigration'],
#  ['animal', 'invertebrate'],
#  ['animal', 'kangaroo'],
#  ['animal', 'kestrel'],
#  ['animal', 'kickoff'],
#  ['animal', 'lamb'],
#  ['animal', 'lion'],
#  ['animal', 'maggot'],
#  ['animal', 'magpie'],
#  ['animal', 'organization'],
#  ['animal', 'panda'],
#  ['animal', 'psychotherapy'],
#  ['animal', 'python'],
#  ['animal', 'receptionist'],
#  ['animal', 'reindeer'],
#  ['animal', 'reptile'],
#  ['animal', 'robin'],
#  ['animal', 'ship'],
#  ['animal', 'snake'],
#  ['animal', 'toad'],
#  ['animal', 'turkey'],
#  ['animal', 'vertebrate'],
#  ['animal', 'vial'],
#  ['animal', 'waterfowl'],
#  ['anniversary', 'lingerie'],
#  ['anorexia', 'fixture'],
#  ['ant', 'spokeswoman'],
#  ['antibiotic', 'penicillin'],
#  ['antibody', 'nematode'],
#  ['apathy', 'magnitude'],
#  ['apathy', 'mammal'],
#  ['ape', 'book'],
#  ['apprehension', 'bird'],
#  ['apprehension', 'offspring'],
#  ['apprehension', 'skating'],
#  ['aqueduct', 'pianist'],
#  ['archbishop', 'garment'],
#  ['area', 'cameraman'],
#  ['aristocrat', 'baroness'],
#  ['aristocrat', 'relative'],
#  ['armament', 'cannon'],
#  ['armament', 'people'],
#  ['army', 'waterfowl'],
#  ['art', 'beard'],
#  ['art', 'cost'],
#  ['art', 'serpent'],
#  ['artillery', 'cannon'],
#  ['artist', 'beverage'],
#  ['artwork', 'integer'],
#  ['asp', 'invertebrate'],
#  ['asp', 'workplace'],
#  ['asthma', 'motel'],
#  ['asthma', 'tissue'],
#  ['athlete', 'cricketer'],
#  ['athlete', 'dancer'],
#  ['athlete', 'filly'],
#  ['athlete', 'spokeswoman'],
#  ['athlete', 'swimmer'],
#  ['attack', 'animal'],
#  ['attitude', 'bookshop'],
#  ['auto', 'trait'],
#  ['autobiography', 'feeling'],
#  ['badminton', 'kettle'],
#  ['bag', 'collagen'],
#  ['bag', 'review'],
#  ['bag', 'rucksack'],
#  ['bamboo', 'bear'],
#  ['ban', 'performer'],
#  ['baritone', 'adrenaline'],
#  ['barrier', 'fender'],
#  ['barrier', 'gate'],
#  ['barrier', 'psychotherapy'],
#  ['bead', 'decoration'],
#  ['bead', 'performer'],
#  ['bear', 'webcam'],
#  ['bed', 'insect'],
#  ['beech', 'artillery'],
#  ['beer', 'machine'],
#  ['beer', 'railway'],
#  ['benzene', 'cottage'],
#  ['benzene', 'tent'],
#  ['berry', 'diplomat'],
#  ['beverage', 'art'],
#  ['beverage', 'beer'],
#  ['beverage', 'list'],
#  ['beverage', 'panda'],
#  ['beverage', 'sherry'],
#  ['beverage', 'strut'],
#  ['beverage', 'symbol'],
#  ['beverage', 'tea'],
#  ['beverage', 'vehicle'],
#  ['beverage', 'whisky'],
#  ['bib', 'herb'],
#  ['bike', 'gate'],
#  ['bin', 'mail'],
#  ['binder', 'disease'],
#  ['binder', 'notary'],
#  ['binder', 'performer'],
#  ['bingo', 'fluid'],
#  ['biochemistry', 'enzymology'],
#  ['biplane', 'ale'],
#  ['bird', 'chick'],
#  ['bird', 'cookie'],
#  ['bird', 'disorder'],
#  ['bird', 'eagle'],
#  ['bird', 'entertainer'],
#  ['bird', 'freeway'],
#  ['bird', 'hawk'],
#  ['bird', 'penguin'],
#  ['bird', 'seabird'],
#  ['bird', 'snake'],
#  ['bird', 'turkey'],
#  ['bird', 'woman'],
#  ['bird', 'woodpecker'],
#  ['bishop', 'cardinal'],
#  ['bishop', 'valley'],
#  ['boar', 'spokesperson'],
#  ['boat', 'chair'],
#  ['boat', 'cost'],
#  ['boat', 'dinghy'],
#  ['boat', 'pontoon'],
#  ['boat', 'reformer'],
#  ['bonnet', 'hamster'],
#  ['bonnet', 'vehicle'],
#  ['book', 'fruit'],
#  ['bookmark', 'performer'],
#  ['border', 'feeling'],
#  ['bottle', 'throne'],
#  ['bourgeoisie', 'association'],
#  ['bourgeoisie', 'fabric'],
#  ['bowling', 'clothing'],
#  ['bread', 'toast'],
#  ['breeze', 'heroism'],
#  ['breeze', 'physiology'],
#  ['buggy', 'garment'],
#  ['building', 'castle'],
#  ['building', 'craftsman'],
#  ['building', 'envy'],
#  ['building', 'instrument'],
#  ['building', 'mosque'],
#  ['building', 'motel'],
#  ['building', 'observatory'],
#  ['building', 'potato'],
#  ['building', 'shrine'],
#  ['building', 'theater'],
#  ['building', 'transaction'],
#  ['bull', 'highway'],
#  ['bureau', 'leaf'],
#  ['business', 'disease'],
#  ['business', 'meal'],
#  ['businessman', 'tycoon'],
#  ['butterfly', 'vertebrate'],
#  ['cabbage', 'aspirin'],
#  ['cabbage', 'toast'],
#  ['calculation', 'temperature'],
#  ['calf', 'worker'],
#  ['camera', 'clinician'],
#  ['camera', 'magistrate'],
#  ['campsite', 'discipline'],
#  ['campsite', 'disease'],
#  ['cancer', 'drug'],
#  ['cancer', 'drummer'],
#  ['cancer', 'melanoma'],
#  ['cancer', 'mesothelioma'],
#  ['cannon', 'tree'],
#  ['captivity', 'internment'],
#  ['car', 'limousine'],
#  ['car', 'sedan'],
#  ['carbohydrate', 'cellulose'],
#  ['carbonate', 'worker'],
#  ['carcinoma', 'granny'],
#  ['care', 'radiotherapy'],
#  ['caring', 'bacterium'],
#  ['carnivore', 'dog'],
#  ['carnivore', 'ferret'],
#  ['carnivore', 'glider'],
#  ['cassette', 'therapy'],
#  ['cat', 'drone'],
#  ['cat', 'locomotive'],
#  ['catcher', 'psoriasis'],
#  ['caterpillar', 'aesthetic'],
#  ['cellist', 'puppy'],
#  ['cellist', 'vehicle'],
#  ['cellulose', 'mineral'],
#  ['ceremony', 'initiation'],
#  ['chair', 'armchair'],
#  ['chamber', 'animal'],
#  ['chamber', 'house'],
#  ['chamber', 'objectivity'],
#  ['champagne', 'batsman'],
#  ['champagne', 'etching'],
#  ['chancellor', 'basket'],
#  ['chant', 'boss'],
#  ['cheese', 'kettle'],
#  ['chemical', 'benzene'],
#  ['chemical', 'carbonate'],
#  ['chemical', 'food'],
#  ['chemical', 'rat'],
#  ['chemistry', 'liquid'],
#  ['chemotherapy', 'rum'],
#  ['chick', 'seed'],
#  ['chick', 'smuggler'],
#  ['child', 'sherry'],
#  ['church', 'fence'],
#  ['classroom', 'music'],
#  ['cleaning', 'animal'],
#  ['cleaning', 'shaving'],
#  ['clergyman', 'archbishop'],
#  ['clergyman', 'vicar'],
#  ['clinician', 'software'],
#  ['clothing', 'denim'],
#  ['clothing', 'karaoke'],
#  ['clothing', 'kilt'],
#  ['clothing', 'shirt'],
#  ['clothing', 'tie'],
#  ['clubhouse', 'poem'],
#  ['coaching', 'chart'],
#  ['cockroach', 'alcohol'],
#  ['cocktail', 'affection'],
#  ['collagen', 'shopkeeper'],
#  ['collection', 'parasite'],
#  ['color', 'green'],
#  ['color', 'record'],
#  ['combustion', 'blaze'],
#  ['commerce', 'importation'],
#  ['commodity', 'annals'],
#  ['commodity', 'car'],
#  ['commodity', 'dryer'],
#  ['commodity', 'geek'],
#  ['commodity', 'kilt'],
#  ['commodity', 'staple'],
#  ['commodity', 'stocking'],
#  ['commodity', 'sweater'],
#  ['communicator', 'cradle'],
#  ['communicator', 'storyteller'],
#  ['communicator', 'writer'],
#  ['compensation', 'publication'],
#  ['competitiveness', 'dentistry'],
#  ['competitiveness', 'screenwriter'],
#  ['competitiveness', 'tumor'],
#  ['computer', 'catastrophe'],
#  ['computer', 'laptop'],
#  ['computer', 'pc'],
#  ['computer', 'vertebrate'],
#  ['concept', 'gastropod'],
#  ['condominium', 'gymnasium'],
#  ['conduit', 'aqueduct'],
#  ['conduit', 'writer'],
#  ['conservatism', 'mesothelioma'],
#  ['consistency', 'fly'],
#  ['consistency', 'hardness'],
#  ['consumer', 'drinker'],
#  ['container', 'disease'],
#  ['container', 'garment'],
#  ['container', 'kettle'],
#  ['container', 'lamb'],
#  ['container', 'pc'],
#  ['container', 'pouch'],
#  ['container', 'room'],
#  ['container', 'spokeswoman'],
#  ['container', 'spoon'],
#  ['container', 'teacher'],
#  ['container', 'technician'],
#  ['container', 'terminal'],
#  ['container', 'tip'],
#  ['contest', 'final'],
#  ['contest', 'vertebrate'],
#  ['contestant', 'building'],
#  ['contestant', 'winner'],
#  ['contract', 'musician'],
#  ['contractor', 'declaration'],
#  ['cook', 'point'],
#  ['cosmology', 'relief'],
#  ['cost', 'overhead'],
#  ['cost', 'vegetable'],
#  ['counterattack', 'seafood'],
#  ['coupe', 'pc'],
#  ['covenant', 'vehicle'],
#  ['cow', 'chocolate'],
#  ['crab', 'illness'],
#  ['cradle', 'airplane'],
#  ['crew', 'aircrew'],
#  ['criminal', 'bird'],
#  ['criminal', 'documentary'],
#  ['criminal', 'drone'],
#  ['criminology', 'sherry'],
#  ['crusade', 'therapy'],
#  ['crystal', 'ice'],
#  ['crystal', 'leader'],
#  ['crystal', 'malaria'],
#  ['crystal', 'turquoise'],
#  ['curve', 'feeling'],
#  ['curve', 'publication'],
#  ['curve', 'spiral'],
#  ['dad', 'animal'],
#  ['dad', 'milk'],
#  ['dagger', 'dolphin'],
#  ['dancer', 'autobiography'],
#  ['dart', 'motorway'],
#  ['day', 'tomorrow'],
#  ['dealership', 'terrier'],
#  ['dean', 'signal'],
#  ['deer', 'aromatherapy'],
#  ['dentistry', 'piracy'],
#  ['depth', 'roadway'],
#  ['dermatitis', 'tumor'],
#  ['descendent', 'housing'],
#  ['diabetes', 'corridor'],
#  ['diabetes', 'furniture'],
#  ['digit', 'iv'],
#  ['digit', 'ix'],
#  ['dimension', 'castle'],
#  ['dioxide', 'military'],
#  ['dioxin', 'package'],
#  ['diplomat', 'ambassador'],
#  ['disability', 'hare'],
#  ['disability', 'math'],
#  ['discipline', 'acoustics'],
#  ['discipline', 'anatomy'],
#  ['discipline', 'ceremony'],
#  ['discipline', 'geology'],
#  ['discipline', 'geometry'],
#  ['discipline', 'housing'],
#  ['discipline', 'limb'],
#  ['discipline', 'logic'],
#  ['discipline', 'neuroscience'],
#  ['discipline', 'pharmacy'],
#  ['discipline', 'psychotherapy'],
#  ['disease', 'animal'],
#  ['disease', 'colt'],
#  ['disease', 'diabetes'],
#  ['disease', 'flu'],
#  ['disease', 'gall'],
#  ['disease', 'herpes'],
#  ['disease', 'housing'],
#  ['disease', 'lupus'],
#  ['disease', 'worm'],
#  ['dish', 'integer'],
#  ['disorder', 'hysteria'],
#  ['disorder', 'insomnia'],
#  ['disorder', 'laboratory'],
#  ['disorder', 'symbol'],
#  ['doctrine', 'aesthetic'],
#  ['doctrine', 'privateer'],
#  ['document', 'affidavit'],
#  ['document', 'covenant'],
#  ['document', 'deity'],
#  ['document', 'solid'],
#  ['dog', 'annals'],
#  ['dog', 'bulldog'],
#  ['dog', 'greyhound'],
#  ['dog', 'kingfisher'],
#  ['dog', 'word'],
#  ['dogma', 'ship'],
#  ['dove', 'people'],
#  ['dragonfly', 'oil'],
#  ['drift', 'economist'],
#  ['drug', 'anaesthetic'],
#  ['drug', 'benzodiazepine'],
#  ['drug', 'hall'],
#  ['drug', 'jurisprudence'],
#  ['drummer', 'tree'],
#  ['dryer', 'cottage'],
#  ['dryer', 'parent'],
#  ['dwelling', 'chateau'],
#  ['dwelling', 'convent'],
#  ['dwelling', 'conversion'],
#  ['dyke', 'vertebrate'],
#  ['eagle', 'tip'],
#  ['eater', 'vegan'],
#  ['ecstasy', 'sport'],
#  ['editor', 'movie'],
#  ['eel', 'kingfisher'],
#  ['electrician', 'granny'],
#  ['electronics', 'professional'],
#  ['emotion', 'anger'],
#  ['emotion', 'animosity'],
#  ['emotion', 'displeasure'],
#  ['emotion', 'fright'],
#  ['emotion', 'resentment'],
#  ['empress', 'chemical'],
#  ['enclosure', 'cage'],
#  ['encyclopedia', 'ale'],
#  ['end', 'inn'],
#  ['endurance', 'reindeer'],
#  ['energy', 'heat'],
#  ['entertainer', 'artiste'],
#  ['entertainer', 'biologist'],
#  ['entertainer', 'cellist'],
#  ['entertainer', 'comic'],
#  ['entertainer', 'leg'],
#  ['entertainer', 'penguin'],
#  ['entertainer', 'piper'],
#  ['entertainer', 'trumpeter'],
#  ['entertainer', 'warbler'],
#  ['environmentalist', 'entertainer'],
#  ['enzyme', 'animal'],
#  ['enzyme', 'chick'],
#  ['equipment', 'attorney'],
#  ['equipment', 'camera'],
#  ['equipment', 'parachute'],
#  ['equipment', 'princess'],
#  ['equipment', 'reel'],
#  ['equipment', 'roofing'],
#  ['equipment', 'sherry'],
#  ['era', 'perseverance'],
#  ['era', 'pine'],
#  ['etching', 'discipline'],
#  ['excuse', 'physician'],
#  ['explanation', 'biplane'],
#  ['explanation', 'excuse'],
#  ['explanation', 'spore'],
#  ['explosive', 'aircraft'],
#  ['explosive', 'dynamite'],
#  ['fabric', 'sunshine'],
#  ['fabric', 'velvet'],
#  ['facade', 'outpost'],
#  ['facility', 'chalet'],
#  ['falcon', 'calculation'],
#  ['fallacy', 'produce'],
#  ['falsehood', 'flea'],
#  ['farmhouse', 'bargain'],
#  ['fear', 'ecologist'],
#  ['fear', 'suitcase'],
#  ['feeling', 'animosity'],
#  ['feeling', 'artillery'],
#  ['feeling', 'benzodiazepine'],
#  ['feeling', 'compassion'],
#  ['feeling', 'desire'],
#  ['feeling', 'doctrine'],
#  ['feeling', 'envy'],
#  ['feeling', 'insect'],
#  ['feeling', 'jealousy'],
#  ['feeling', 'longing'],
#  ['feeling', 'love'],
#  ['feeling', 'military'],
#  ['feeling', 'nostalgia'],
#  ['feeling', 'passion'],
#  ['feeling', 'relief'],
#  ['feeling', 'resignation'],
#  ['feeling', 'rum'],
#  ['feeling', 'serviceman'],
#  ['feeling', 'surprise'],
#  ['feeling', 'terror'],
#  ['feeling', 'weapon'],
#  ['felony', 'panda'],
#  ['fiber', 'entertainer'],
#  ['fillet', 'antibiotic'],
#  ['fillet', 'glider'],
#  ['final', 'cotton'],
#  ['firm', 'carnivore'],
#  ['firm', 'publisher'],
#  ['fish', 'kestrel'],
#  ['fish', 'shark'],
#  ['fluid', 'alcohol'],
#  ['fluid', 'beverage'],
#  ['fluid', 'cider'],
#  ['fluid', 'record'],
#  ['fluid', 'rum'],
#  ['fluid', 'whiskey'],
#  ['fluorescence', 'sausage'],
#  ['fly', 'grandchild'],
#  ['folly', 'dealer'],
#  ['folly', 'tent'],
#  ['food', 'candy'],
#  ['food', 'gun'],
#  ['food', 'honey'],
#  ['food', 'margarine'],
#  ['food', 'pizza'],
#  ['food', 'reimbursement'],
#  ['food', 'sandwich'],
#  ['food', 'spaghetti'],
#  ['food', 'woman'],
#  ['football', 'fixture'],
#  ['football', 'hamlet'],
#  ['forearm', 'merchant'],
#  ['foundry', 'typhoon'],
#  ['fragrance', 'leader'],
#  ['freeway', 'district'],
#  ['fruit', 'illness'],
#  ['fruit', 'melon'],
#  ['fruit', 'olive'],
#  ['fruit', 'pear'],
#  ['fruit', 'pizza'],
#  ['frustration', 'terror'],
#  ['fuel', 'tumor'],
#  ['fullback', 'baronetcy'],
#  ['funeral', 'carnivore'],
#  ['furniture', 'desk'],
#  ['furniture', 'shark'],
#  ['furniture', 'soprano'],
#  ['furniture', 'throne'],
#  ['furniture', 'word'],
#  ['game', 'bowling'],
#  ['game', 'netball'],
#  ['game', 'reelection'],
#  ['game', 'snooker'],
#  ['garment', 'eater'],
#  ['garment', 'jean'],
#  ['garment', 'lingerie'],
#  ['gasoline', 'hymn'],
#  ['gastropod', 'music'],
#  ['gate', 'violinist'],
#  ['gathering', 'seminar'],
#  ['gemstone', 'mammal'],
#  ['gent', 'entertainer'],
#  ['gent', 'playing'],
#  ['geology', 'charcoal'],
#  ['geometry', 'emotion'],
#  ['goalkeeper', 'documentary'],
#  ['golfer', 'tower'],
#  ['goose', 'victim'],
#  ['governor', 'drift'],
#  ['grandchild', 'drug'],
#  ['grandparent', 'grandfather'],
#  ['graveyard', 'transaction'],
#  ['greyhound', 'collection'],
#  ['greyhound', 'eatery'],
#  ['greyhound', 'symbol'],
#  ['greyhound', 'symphony'],
#  ['gun', 'crusade'],
#  ['gym', 'panda'],
#  ['hair', 'beard'],
#  ['hair', 'desire'],
#  ['hamlet', 'condominium'],
#  ['hamster', 'science'],
#  ['handgun', 'chick'],
#  ['handgun', 'worker'],
#  ['handset', 'phenomenon'],
#  ['hare', 'fillet'],
#  ['heat', 'armchair'],
#  ['heat', 'ticket'],
#  ['height', 'quarterback'],
#  ['helicopter', 'courthouse'],
#  ['herb', 'osteoarthritis'],
#  ['herb', 'rue'],
#  ['herb', 'vehicle'],
#  ['heroism', 'melanoma'],
#  ['herring', 'feeling'],
#  ['heterogeneity', 'discipline'],
#  ['heterogeneity', 'vertebrate'],
#  ['highway', 'machine'],
#  ['holly', 'official'],
#  ['horse', 'bear'],
#  ['horse', 'science'],
#  ['horse', 'stallion'],
#  ['host', 'hostess'],
#  ['hostel', 'lingerie'],
#  ['hound', 'greyhound'],
#  ['hound', 'python'],
#  ['house', 'castle'],
#  ['house', 'chalet'],
#  ['house', 'monastery'],
#  ['house', 'priory'],
#  ['house', 'serviceman'],
#  ['housewife', 'hawk'],
#  ['housing', 'criminal'],
#  ['housing', 'guesthouse'],
#  ['housing', 'manor'],
#  ['housing', 'monastery'],
#  ['housing', 'percussionist'],
#  ['housing', 'supper'],
#  ['husband', 'competitiveness'],
#  ['hydrocarbon', 'gasoline'],
#  ['hydrocarbon', 'statement'],
#  ['icon', 'disease'],
#  ['idea', 'fender'],
#  ['idea', 'value'],
#  ['illness', 'asylum'],
#  ['illness', 'digit'],
#  ['illness', 'document'],
#  ['illness', 'mesothelioma'],
#  ['illness', 'smallpox'],
#  ['illness', 'tumor'],
#  ['illness', 'tumour'],
#  ['illustration', 'milk'],
#  ['immunology', 'investment'],
#  ['infant', 'investor'],
#  ['inference', 'vehicle'],
#  ['inference', 'yearning'],
#  ['influenza', 'staple'],
#  ['information', 'corporation'],
#  ['information', 'disease'],
#  ['information', 'documentation'],
#  ['information', 'pine'],
#  ['information', 'playlist'],
#  ['information', 'propaganda'],
#  ['information', 'surgeon'],
#  ['information', 'waitress'],
#  ['infusion', 'animal'],
#  ['inhabitant', 'islander'],
#  ['inhabitant', 'resident'],
#  ['insect', 'ant'],
#  ['insect', 'cricket'],
#  ['insect', 'drone'],
#  ['insect', 'fencing'],
#  ['insect', 'illness'],
#  ['insect', 'librarian'],
#  ['insomnia', 'dictionary'],
#  ['institution', 'produce'],
#  ['institution', 'seminary'],
#  ['instrument', 'animal'],
#  ['instrument', 'gauge'],
#  ['instrument', 'missile'],
#  ['instrument', 'motorcycle'],
#  ['instrument', 'radar'],
#  ['instrument', 'royalty'],
#  ['instrument', 'telescope'],
#  ['instrument', 'voice'],
#  ['instrument', 'zebra'],
#  ['integer', 'animal'],
#  ['integer', 'ecstasy'],
#  ['integer', 'eleven'],
#  ['integer', 'fish'],
#  ['integer', 'rodent'],
#  ['integer', 'ten'],
#  ['integer', 'twenty'],
#  ['interoperability', 'height'],
#  ['intestine', 'equipment'],
#  ['intranet', 'negation'],
#  ['invertebrate', 'ant'],
#  ['invertebrate', 'gastropod'],
#  ['invertebrate', 'science'],
#  ['invertebrate', 'soprano'],
#  ['jam', 'trait'],
#  ['jelly', 'chapel'],
#  ['jewel', 'gunboat'],
#  ['jewel', 'invitation'],
#  ['jewelry', 'computer'],
#  ['jewelry', 'drummer'],
#  ['jewelry', 'freeware'],
#  ['jigsaw', 'alga'],
#  ['jigsaw', 'handgun'],
#  ['jigsaw', 'worker'],
#  ['joint', 'change'],
#  ['joint', 'knuckle'],
#  ['journalist', 'columnist'],
#  ['kangaroo', 'castle'],
#  ['karaoke', 'merchant'],
#  ['kestrel', 'liquor'],
#  ['kestrel', 'netball'],
#  ['kestrel', 'worker'],
#  ['keyboardist', 'cricket'],
#  ['kilt', 'monoclonal'],
#  ['kindergarten', 'symbol'],
#  ['knife', 'raven'],
#  ['laborer', 'solid'],
#  ['lactose', 'pony'],
#  ['lactose', 'writer'],
#  ['laptop', 'ice'],
#  ['larva', 'caterpillar'],
#  ['larva', 'maggot'],
#  ['leader', 'boss'],
#  ['leader', 'pope'],
#  ['leader', 'rider'],
#  ['leader', 'science'],
#  ['leader', 'statesman'],
#  ['leader', 'vehicle'],
#  ['leaf', 'petal'],
#  ['lecturer', 'rate'],
#  ['leg', 'microorganism'],
#  ['lemon', 'humanist'],
#  ['lemon', 'throne'],
#  ['leprosy', 'kestrel'],
#  ['lesbian', 'crowd'],
#  ['lesbian', 'dyke'],
#  ['librarian', 'document'],
#  ['light', 'resident'],
#  ['limb', 'leg'],
#  ['limousine', 'workbook'],
#  ['lingerie', 'payer'],
#  ['lingerie', 'remorse'],
#  ['liqueur', 'feeling'],
#  ['liqueur', 'ten'],
#  ['liquid', 'beer'],
#  ['liquid', 'beverage'],
#  ['liquid', 'jewelry'],
#  ['liquid', 'liquor'],
#  ['liquid', 'pet'],
#  ['liquid', 'progenitor'],
#  ['liquid', 'road'],
#  ['liquid', 'sherry'],
#  ['liquid', 'standing'],
#  ['liquid', 'vintage'],
#  ['liquor', 'odyssey'],
#  ['list', 'chapel'],
#  ['list', 'enumeration'],
#  ['lizard', 'entertainer'],
#  ['logic', 'crime'],
#  ['logic', 'mammal'],
#  ['logo', 'squid'],
#  ['machine', 'biochemistry'],
#  ['machine', 'pc'],
#  ['maggot', 'muse'],
#  ['magnitude', 'beverage'],
#  ['magnitude', 'radius'],
#  ['magnitude', 'size'],
#  ['magpie', 'science'],
#  ['maid', 'bench'],
#  ['mail', 'postcard'],
#  ['mailbox', 'crusade'],
#  ['mammal', 'biochemistry'],
#  ['mammal', 'bitterness'],
#  ['mammal', 'boar'],
#  ['mammal', 'cat'],
#  ['mammal', 'chimpanzee'],
#  ['mammal', 'disease'],
#  ['mammal', 'enzyme'],
#  ['mammal', 'fox'],
#  ['mammal', 'goat'],
#  ['mammal', 'horse'],
#  ['mammal', 'illness'],
#  ['mammal', 'intranet'],
#  ['mammal', 'machine'],
#  ['mammal', 'mankind'],
#  ['mammal', 'rat'],
#  ['mammal', 'vegetable'],
#  ['man', 'pronoun'],
#  ['manor', 'archbishop'],
#  ['manual', 'servant'],
#  ['mariner', 'ruler'],
#  ['marker', 'bookmark'],
#  ['massage', 'petroleum'],
#  ['mater', 'range'],
#  ['mater', 'turret'],
#  ['meal', 'dinner'],
#  ['meal', 'reptile'],
#  ['meal', 'sport'],
#  ['meal', 'supper'],
#  ['meat', 'clown'],
#  ['meat', 'vertebrate'],
#  ['medium', 'animal'],
#  ['medium', 'invertebrate'],
#  ['meeting', 'convention'],
#  ['meeting', 'leader'],
#  ['meeting', 'orchid'],
#  ['melanoma', 'note'],
#  ['member', 'regent'],
#  ['memo', 'vehicle'],
#  ['memorandum', 'racing'],
#  ['merchant', 'shopkeeper'],
#  ['mesothelioma', 'ambassador'],
#  ['mesothelioma', 'maker'],
#  ['message', 'asylum'],
#  ['message', 'occupation'],
#  ['midwife', 'alcohol'],
#  ['migraine', 'staple'],
#  ['migrant', 'feeling'],
#  ['migration', 'organization'],
#  ['militia', 'leader'],
#  ['mime', 'fairytale'],
#  ['miner', 'arthritis'],
#  ['miner', 'officer'],
#  ['mischief', 'collagen'],
#  ['mischief', 'hydrocarbon'],
#  ['mischief', 'vandalism'],
#  ['misfortune', 'calamity'],
#  ['misfortune', 'catastrophe'],
#  ['misfortune', 'mom'],
#  ['mishap', 'symposium'],
#  ['missile', 'vole'],
#  ['molecule', 'cancer'],
#  ['molecule', 'carbohydrate'],
#  ['molecule', 'lipid'],
#  ['molecule', 'locomotive'],
#  ['molecule', 'monoclonal'],
#  ['molecule', 'toast'],
#  ['molecule', 'vehicle'],
#  ['mollusc', 'business'],
#  ['moratorium', 'valley'],
#  ['mortar', 'insecticide'],
#  ['mosque', 'castle'],
#  ['mother', 'food'],
#  ['motorcycle', 'karaoke'],
#  ['motorist', 'firearm'],
#  ['motto', 'logo'],
#  ['movie', 'documentary'],
#  ['murderer', 'competitiveness'],
#  ['murderer', 'eleven'],
#  ['music', 'concerto'],
#  ['music', 'monarch'],
#  ['music', 'reggae'],
#  ['musician', 'piper'],
#  ['musician', 'road'],
#  ['musician', 'soloist'],
#  ['musket', 'player'],
#  ['musket', 'rate'],
#  ['name', 'gent'],
#  ['narrative', 'fairytale'],
#  ['narrative', 'wine'],
#  ['netball', 'sport'],
#  ['netball', 'vehicle'],
#  ['nickname', 'disability'],
#  ['nipple', 'heterogeneity'],
#  ['nostalgia', 'integer'],
#  ['nostalgia', 'offspring'],
#  ['note', 'cockroach'],
#  ['note', 'memorandum'],
#  ['note', 'vehicle'],
#  ['nurse', 'amphibian'],
#  ['objectivity', 'visualisation'],
#  ['obstruction', 'performer'],
#  ['occupation', 'cleaning'],
#  ['occupation', 'pharmacy'],
#  ['occupation', 'professorship'],
#  ['occupation', 'vertebrate'],
#  ['officer', 'daughter'],
#  ['official', 'cardinal'],
#  ['official', 'grandmother'],
#  ['official', 'science'],
#  ['offspring', 'arithmetic'],
#  ['offspring', 'granddaughter'],
#  ['offspring', 'son'],
#  ['ointment', 'smallpox'],
#  ['oncology', 'skating'],
#  ['opening', 'feeling'],
#  ['opening', 'leak'],
#  ['ore', 'clown'],
#  ['organ', 'animal'],
#  ['organ', 'barrier'],
#  ['organ', 'intestine'],
#  ['organ', 'nipple'],
#  ['organ', 'penis'],
#  ['organ', 'uterus'],
#  ['organist', 'enzymology'],
#  ['organization', 'bear'],
#  ['organization', 'bureau'],
#  ['organization', 'church'],
#  ['organization', 'club'],
#  ['organization', 'department'],
#  ['organization', 'directorate'],
#  ['organization', 'galley'],
#  ['organization', 'math'],
#  ['organization', 'militia'],
#  ['osteoarthritis', 'catcher'],
#  ['overpayment', 'therapist'],
#  ['oxide', 'list'],
#  ['oyster', 'science'],
#  ['palace', 'electrician'],
#  ['pancreas', 'coach'],
#  ['panda', 'woodpecker'],
#  ['parapet', 'insect'],
#  ['parasite', 'adjective'],
#  ['parasite', 'emotion'],
#  ['parasite', 'flea'],
#  ['parent', 'daddy'],
#  ['parrot', 'food'],
#  ['passageway', 'corridor'],
#  ['patience', 'ceremony'],
#  ['payment', 'hostess'],
#  ['payment', 'overpayment'],
#  ['payment', 'royalty'],
#  ['payment', 'solid'],
#  ['payment', 'wage'],
#  ['pc', 'food'],
#  ['pear', 'weapon'],
#  ['penis', 'color'],
#  ['penis', 'larva'],
#  ['people', 'bourgeoisie'],
#  ['people', 'gentry'],
#  ['people', 'vicar'],
#  ['performer', 'artiste'],
#  ['performer', 'comedian'],
#  ['performer', 'comic'],
#  ['performer', 'commodity'],
#  ['performer', 'disease'],
#  ['performer', 'drummer'],
#  ['performer', 'food'],
#  ['performer', 'geek'],
#  ['performer', 'mime'],
#  ['performer', 'physiotherapy'],
#  ['performer', 'saxophonist'],
#  ['performer', 'soprano'],
#  ['performer', 'spear'],
#  ['performer', 'vocalist'],
#  ['pesticide', 'beard'],
#  ['pesticide', 'cabbage'],
#  ['pesticide', 'girlfriend'],
#  ['pesticide', 'insecticide'],
#  ['petal', 'neurology'],
#  ['petal', 'vehicle'],
#  ['petroleum', 'payment'],
#  ['pew', 'glider'],
#  ['pharmacology', 'man'],
#  ['phenomenon', 'compensation'],
#  ['phenomenon', 'fluorescence'],
#  ['phenomenon', 'gale'],
#  ['phenomenon', 'mishap'],
#  ['phenomenon', 'polarization'],
#  ['phenomenon', 'rain'],
#  ['phenomenon', 'traction'],
#  ['physician', 'shelter'],
#  ['physiology', 'calculation'],
#  ['pig', 'science'],
#  ['pilgrimage', 'crew'],
#  ['piper', 'illness'],
#  ['piracy', 'feeling'],
#  ['pirate', 'adult'],
#  ['pistol', 'athlete'],
#  ['plant', 'rector'],
#  ['platter', 'publication'],
#  ['player', 'batsman'],
#  ['player', 'goalkeeper'],
#  ['player', 'instrument'],
#  ['player', 'physiotherapy'],
#  ['player', 'quarterback'],
#  ['playlist', 'bat'],
#  ['pocket', 'vehicle'],
#  ['polarization', 'emotion'],
#  ['policeman', 'theft'],
#  ['polygon', 'rectangle'],
#  ['polymer', 'oil'],
#  ['polymerase', 'treatment'],
#  ['porter', 'panic'],
#  ['post', 'rabbit'],
#  ['postgraduate', 'water'],
#  ['potato', 'foreman'],
#  ['pram', 'greyhound'],
#  ['preamble', 'meal'],
#  ['preconception', 'laboratory'],
#  ['prefecture', 'musician'],
#  ['priest', 'pocket'],
#  ['priest', 'secretariat'],
#  ['priory', 'tycoon'],
#  ['procedure', 'melon'],
#  ['produce', 'music'],
#  ['produce', 'raisin'],
#  ['professional', 'anaesthetist'],
#  ['professional', 'craftsman'],
#  ['professional', 'liquor'],
#  ['professional', 'ruler'],
#  ['professional', 'surgeon'],
#  ['professional', 'teacher'],
#  ['professorship', 'misfortune'],
#  ['progenitor', 'dad'],
#  ['progenitor', 'father'],
#  ['progenitor', 'mother'],
#  ['projectile', 'limb'],
#  ['prosecutor', 'magnitude'],
#  ['protein', 'collagen'],
#  ['protein', 'kilt'],
#  ['pseudonym', 'dwelling'],
#  ['pseudonym', 'golf'],
#  ['psychiatry', 'clinician'],
#  ['psychoanalysis', 'cow'],
#  ['psychotherapy', 'dinner'],
#  ['publication', 'bestseller'],
#  ['publication', 'linguist'],
#  ['publication', 'manual'],
#  ...]

# %%
df_curated10_True
# Out:
#                        Wordpair  True label  bert KL score  bert COS score  \
# 0        [abstraction, concept]           1     543.199585  tensor(0.7519)
# 1       [accusation, statement]           1     655.894958  tensor(0.6887)
# 2                  [ache, pain]           1     481.972351  tensor(0.8344)
# 3              [acid, chemical]           1     654.676636  tensor(0.7228)
# 4       [acoustics, discipline]           1    1073.539673  tensor(0.5213)
# ...                         ...         ...            ...             ...
# 2765        [writer, dramatist]           0    2922.197266  tensor(0.6249)
# 2766             [writer, poet]           0     749.144287  tensor(0.8043)
# 2767          [yellow, protein]           0    1219.188354  tensor(0.5060)
# 2768    [yesterday, discipline]           0     913.976318  tensor(0.5464)
# 2769  [yesterday, subcommittee]           0    1664.571167  tensor(0.4136)
#
#       empirical KL score  empirical COS score
# 0               0.861984             0.469579
# 1               0.497814             0.614132
# 2               2.674484             0.792009
# 3               4.105728             0.668829
# 4               1.551239             0.216910
# ...                  ...                  ...
# 2765          116.870781             0.694186
# 2766          135.247009             0.798863
# 2767            9.886383             0.333175
# 2768           98.800735            -0.018511
# 2769            0.274990             0.263668
#
# [2770 rows x 6 columns]

# %%
df_curated10_False
# Out:
#                        Wordpair  True label  bert KL score  bert COS score  \
# 0        [abstraction, concept]           1     543.199585  tensor(0.7519)
# 1       [accusation, statement]           1     655.894958  tensor(0.6887)
# 2                  [ache, pain]           1     481.972351  tensor(0.8344)
# 3              [acid, chemical]           1     654.676636  tensor(0.7228)
# 4       [acoustics, discipline]           1    1073.539673  tensor(0.5213)
# ...                         ...         ...            ...             ...
# 2765        [writer, dramatist]           0    2922.197266  tensor(0.6249)
# 2766             [writer, poet]           0     749.144287  tensor(0.8043)
# 2767          [yellow, protein]           0    1219.188354  tensor(0.5060)
# 2768    [yesterday, discipline]           0     913.976318  tensor(0.5464)
# 2769  [yesterday, subcommittee]           0    1664.571167  tensor(0.4136)
#
#       empirical KL score  empirical COS score
# 0               0.861984             0.469579
# 1               0.497814             0.614132
# 2               2.674484             0.792009
# 3               4.105728             0.668829
# 4               1.551239             0.216910
# ...                  ...                  ...
# 2765          116.870781             0.694186
# 2766          135.247009             0.798863
# 2767            9.886383             0.333175
# 2768           98.800735            -0.018511
# 2769            0.274990             0.263668
#
# [2770 rows x 6 columns]
